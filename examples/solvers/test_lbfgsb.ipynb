# %% [markdown]
# - import some functions from stochopy to test the code

# %%
# python lbfgsb works with numpy arrays
import numpy as np
from pyrtid.inverse import minimize_lbfgsb
from scipy.optimize import minimize

# %% [markdown]
# - First example: min x^{\mathrm{T}}x such that x>=1. Optimal solution hits the boundary.

# %%
def quad(x):
    # return x.dot(x)
    return 10 * x[0] ** 2 + x[1] ** 2


def grad_quad(x):
    return np.array([20 * x[0], 2 * x[1]])


def fun_and_grad(x):
    return quad(x), grad_quad(x)


ftol = 1e-5
gtol = 1e-5
l = np.array([1.0, 1.0])
u = np.array([np.inf, np.inf])
bounds = np.array((l, u)).T
x0 = np.array([5, 5])

# %%
bounds[0]
# Out:
# array([ 1., inf])

# %% [markdown]
# ### New implementation

# %%
print("====================== Quadratic example ======================")
opt_quad = minimize_lbfgsb(
    x0=x0, fun=quad, jac=grad_quad, bounds=bounds, ftol=ftol, gtol=gtol, iprint=101
)
print("")
print("")
xOpt = np.array([1, 1])
theoOpt = {"x": xOpt, "f": quad(xOpt), "df": grad_quad(xOpt)}
print("Theoretical optimal value: ")
print(theoOpt)
print("Optimal value found: ")
print(opt_quad)
# Out:
# ====================== Quadratic example ======================
# RUNNING THE L-BFGS-B CODE
#            * * *
# Machine precision = 2.220446049250313e-16
# N = 	2	M = 	10
# At X0, 0 variables are exactly at the bounds
# At iterate 0 , f= 275.0 , |proj g|= 4.0
#
# ITERATION 1
#
# ---------------- CAUCHY entered-------------------
# There are 2 breakpoints
# Piece    , 1,  --f1, f2 at start point , -10100.0 , 10100.0
# Distance to the next break point =  0.04
# Distance to the stationary point =  1.0
# Variable  1 is fixed.
# Piece    , 2,  --f1, f2 at start point , -96.0 , 1.0100000000000002e-26
# Distance to the next break point =  0.36000000000000004
# Distance to the stationary point =  9.504950495049504e+27
# Variable  2 is fixed.
# GCP found in this segment
# Cauchy X =  [1. 1.]
# ---------------- exit CAUCHY----------------------
# 0 variables are free at GCP, iter = 1
# LINE SEARCH  0 times; norm of step = 0.17677669529663687
# Iteration #0 (max: 50): ||x||=4.293e+00, f(x)=2.027e+02, ||jac(x)||=8.586e+01, cdt_arret=3.293e+00 (eps=1.000e-05)
# At iterate 1 , f= 202.71825406947974 , |proj g|= 4.0
#
# ITERATION 2
#
# ---------------- CAUCHY entered-------------------
# There are 2 breakpoints
# Piece    , 1,  --f1, f2 at start point , -7445.288604006348 , 191546.97044852684
# Distance to the next break point =  0.038352843303700916
# Distance to the stationary point =  0.038869257950530055
# Variable  1 is fixed.
# Piece    , 2,  --f1, f2 at start point , -255.42808423090082 , 1.367225725462983e-25
# Distance to the next break point =  0.3451755897333083
# Distance to the stationary point =  1.8682217535396747e+27
# Variable  2 is fixed.
# GCP found in this segment
# Cauchy X =  [1. 1.]
# ---------------- exit CAUCHY----------------------
# Variables leaving the free variables set = []
# Variables entering the free variables set = []
# N variables leaving = 0 	, N variables entering = 0
# 0 variables are free at GCP, iter = 2
# LINE SEARCH  0 times; norm of step = 1.0
# Iteration #1 (max: 50): ||x||=1.000e+00, f(x)=1.100e+01, ||jac(x)||=2.000e+01, cdt_arret=0.000e+00 (eps=1.000e-05)
# At iterate 2 , f= 11.0 , |proj g|= 4.0
# Iteration #2 (max: 50): ||x||=1.000e+00, f(x)=1.100e+01, ||jac(x)||=2.000e+01, cdt_arret=0.000e+00 (eps=1.000e-05)
#
#
# Theoretical optimal value:
# {'x': array([1, 1]), 'f': 11, 'df': array([20,  2])}
# Optimal value found:
#   message: CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#   success: True
#    status: 1
#       fun: 11.0
#         x: [ 1.000e+00  1.000e+00]
#       nit: 2
#       jac: [ 2.000e+01  2.000e+00]
#      nfev: 3
#      njev: 3
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>

# %% [markdown]
# ### Scipy

# %%
minimize(
    quad,
    x0,
    jac=grad_quad,
    bounds=bounds,
    method="l-bfgs-b",
    options={"gtol": gtol, "ftol": ftol, "disp": 200, "iprint": 200},
)
# Out:
# RUNNING THE L-BFGS-B CODE
#   message: CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#   success: True
#    status: 0
#       fun: 11.0
#         x: [ 1.000e+00  1.000e+00]
#       nit: 2
#       jac: [ 2.000e+01  2.000e+00]
#      nfev: 3
#      njev: 3
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
#  L =  1.0000D+00  1.0000D+00
#
# X0 =  5.0000D+00  5.0000D+00
#
#  U =  0.0000D+00  0.0000D+00
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.75000D+02    |proj g|=  4.00000D+00
#
#
# ITERATION     1
#
# ---------------- CAUCHY entered-------------------
#  There are            2   breakpoints
#
# Piece      1 --f1, f2 at start point  -1.0100D+04  1.0100D+04
# Distance to the next break point =   4.0000D-02
# Distance to the stationary point =   1.0000D+00
#  Variable             1   is fixed.
#
# Piece      2 --f1, f2 at start point  -9.6000D+01  1.0000D+02
# Distance to the next break point =   3.6000D-01
# Distance to the stationary point =   9.6000D-01
#  Variable             2   is fixed.
# Cauchy X =
#       1.0000D+00  1.0000D+00
#
# ---------------- exit CAUCHY----------------------
#
#            0  variables are free at GCP            1
#  LINE SEARCH           0  times; norm of step =    1.0000000000000000
#
# At iterate    1    f=  2.02718D+02    |proj g|=  3.29289D+00
#
#  X =  4.2929D+00  4.2929D+00
#
#  G =  8.5858D+01  8.5858D+00
#
#
# ITERATION     2
#
# ---------------- CAUCHY entered-------------------
#  There are            2   breakpoints
#
# Piece      1 --f1, f2 at start point  -7.4453D+03  1.9155D+05
# Distance to the next break point =   3.8353D-02
# Distance to the stationary point =   3.8869D-02
#  Variable             1   is fixed.
#
# Piece      2 --f1, f2 at start point  -2.5543D+02  6.9025D+02
# Distance to the next break point =   3.4518D-01
# Distance to the stationary point =   3.7005D-01
#  Variable             2   is fixed.
# Cauchy X =
#       1.0000D+00  1.0000D+00
#
# ---------------- exit CAUCHY----------------------
#
#            0  variables leave;            0  variables enter
#            0  variables are free at GCP            2
#  LINE SEARCH           0  times; norm of step =    4.6568542494923797
#
# At iterate    2    f=  1.10000D+01    |proj g|=  0.00000D+00
#
#  X =  1.0000D+00  1.0000D+00
#
#  G =  2.0000D+01  2.0000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      3      4     0     2   0.000D+00   1.100D+01
#
#  X =  1.0000D+00  1.0000D+00
#   F =   11.000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL

# %% [markdown]
# ## Second example : min Rosenbrock function

# %%
def rosenbrock(x):
    return 100 * (x[1] - x[0] ** 2) ** 2 + (1 - x[0]) ** 2


def grad_rosenbrock(x):
    g = np.empty(x.size)
    g[0] = 400 * x[0] * (x[0] ** 2 - x[1]) + 2 * (x[0] - 1)
    g[1] = 200 * (-x[0] ** 2 + x[1])
    return g


l = np.array([-2, -2])
u = np.array([2, 2])
bounds = np.array((l, u)).T
# x0 = np.array([0.12, 0.12])
x0 = np.array([-0.8, -1])

# %% [markdown]
# ### New implementation

# %%
np.finfo(1.0).resolution * 1e7
# Out:
# 1e-08

# %%
opt_rosenbrock = minimize_lbfgsb(
    x0=x0,
    fun=rosenbrock,
    jac=grad_rosenbrock,
    bounds=bounds,
    maxcor=5,
    ftol=ftol,
    gtol=gtol,
    iprint=101,
    ftol_linesearch=1e-3,
    gtol_linesearch=0.9,
    xtol_linesearch=0.1,
)
print("")
print("")
theoOpt = {"x": np.array([1, 1]), "f": 0, "df": grad_rosenbrock(np.array([1, 1]))}
print("Theoretical optimal value: ")
print(theoOpt)
print("Optimal value found: ")
# Out:
# RUNNING THE L-BFGS-B CODE
#            * * *
# Machine precision = 2.220446049250313e-16
# N = 	2	M = 	5
# At X0, 0 variables are exactly at the bounds
# At iterate 0 , f= 272.20000000000005 , |proj g|= 3.0
#
# ITERATION 1
#
# ---------------- CAUCHY entered-------------------
# There are 2 breakpoints
# Piece    , 1,  --f1, f2 at start point , -386790.5600000001 , 386790.5600000001
# Distance to the next break point =  0.00529901589704769
# Distance to the stationary point =  1.0
# Variable  1 is fixed.
# Piece    , 2,  --f1, f2 at start point , -107013.91067373205 , 3.8679056000000014e-25
# Distance to the next break point =  0.0038473255663669433
# Distance to the stationary point =  2.7667146445800543e+29
# Variable  2 is fixed.
# GCP found in this segment
# Cauchy X =  [2. 2.]
# ---------------- exit CAUCHY----------------------
# 0 variables are free at GCP, iter = 1
# LINE SEARCH  0 times; norm of step = 0.24368508941428965
# Iteration #0 (max: 50): ||x||=2.689e-01, f(x)=9.246e+00, ||jac(x)||=5.656e+01, cdt_arret=2.269e+00 (eps=1.000e-05)
# At iterate 1 , f= 9.246441637455497 , |proj g|= 3.0
#
# ITERATION 2
#
# ---------------- CAUCHY entered-------------------
# There are 2 breakpoints
# GCP found in this segment
# Cauchy X =  [-0.08072223 -0.13449091]
# ---------------- exit CAUCHY----------------------
# Variables leaving the free variables set = []
# Variables entering the free variables set = [0 1]
# N variables leaving = 0 	, N variables entering = 2
# 2 variables are free at GCP, iter = 2
# [[336698.32088614]]
# K = [[-1.09673473e+03 -5.48367366e+02]
#  [-5.48367366e+02 -1.36335695e-13]]
# K2 = [[-1096.73473129  -580.25711619]
#  [ -580.25711619     0.        ]]
# LINE SEARCH  0 times; norm of step = 1.0
# Iteration #1 (max: 50): ||x||=1.308e-01, f(x)=3.115e+00, ||jac(x)||=2.777e+01, cdt_arret=2.131e+00 (eps=1.000e-05)
# At iterate 2 , f= 3.114552532239802 , |proj g|= 3.0
#
# ITERATION 3
#
# ---------------- CAUCHY entered-------------------
# There are 2 breakpoints
# GCP found in this segment
# Cauchy X =  [-0.05611024 -0.00122302]
# ---------------- exit CAUCHY----------------------
# Variables leaving the free variables set = []
# Variables entering the free variables set = []
# N variables leaving = 0 	, N variables entering = 0
# 2 variables are free at GCP, iter = 3
# [[336698.32088614  12122.7166244 ]
#  [ 12122.7166244     899.47870749]]
# K = [[-2.12552966e+03 -5.67852300e+01 -5.48367366e+02 -1.01862830e-15]
#  [-5.67852300e+01 -8.42667645e+00 -2.67789257e+01 -4.21333822e+00]
#  [-5.48367366e+02 -2.67789257e+01  2.16110818e-14  6.92617502e-15]
#  [ 2.76882188e-15 -4.21333822e+00  1.18516238e-15  2.27906143e-15]]
# K2 = [[-2125.52966344   -56.78523004  -580.25711619     0.        ]
#  [  -56.78523004    -8.42667645   -20.89197407   -21.51753069]
#  [ -580.25711619   -20.89197407     0.             0.        ]
#  [    0.           -21.51753069     0.             0.        ]]
# LINE SEARCH  0 times; norm of step = 1.0
# Iteration #2 (max: 50): ||x||=6.476e-02, f(x)=1.134e+00, ||jac(x)||=2.182e+00, cdt_arret=2.065e+00 (eps=1.000e-05)
# At iterate 3 , f= 1.1341258669327527 , |proj g|= 3.0
#
# ITERATION 4
#
# ---------------- CAUCHY entered-------------------
# There are 2 breakpoints
# GCP found in this segment
# Cauchy X =  [-0.05852474  0.00332358]
# ---------------- exit CAUCHY----------------------
# Variables leaving the free variables set = []
# Variables entering the free variables set = []
# N variables leaving = 0 	, N variables entering = 0
# 2 variables are free at GCP, iter = 4
# [[336698.32088614  12122.7166244    9973.74226648]
#  [ 12122.7166244     899.47870749    829.47648492]
#  [  9973.74226648    829.47648492    773.30741748]]
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 opt_rosenbrock = minimize_lbfgsb(
#       2     x0=x0,
#       3     fun=rosenbrock,
#       4     jac=grad_rosenbrock,
#       5     bounds=bounds,
#       6     maxcor=5,
#       7     ftol=ftol,
#       8     gtol=gtol,
#       9     iprint=101,
#      10     ftol_linesearch=1e-3,
#      11     gtol_linesearch=0.9,
#      12     xtol_linesearch=0.1,
#      13 )
#      14 print("")
#      15 print("")
#
# File ~/workspace/pyrtid/pyrtid/inverse/solvers/lbfgsb/lbfgsb.py:357, in minimize_lbfgsb(x0, fun, args, jac, update_fun_def, bounds, maxcor, gtol, ftol, max_iter, eps, maxfun, iprint, callback, maxls, finite_diff_rel_step, max_steplength, ftol_linesearch, gtol_linesearch, xtol_linesearch, eps_SY)
#     354 free_vars, Z, A = freev(dictCP["xc"], lb, ub, iprint, n_iterations, free_vars)
#     356 # subspace minimization: find the search direction for the minimization problem
# --> 357 xbar: NDArrayFloat = direct_primal_subspace_minimization(
#     358     X,
#     359     G,
#     360     x,
#     361     dictCP["xc"],
#     362     free_vars,
#     363     Z,
#     364     A,
#     365     dictCP["c"],
#     366     grad,
#     367     lb,
#     368     ub,
#     369     W,
#     370     invMfactors,
#     371     theta,
#     372 )
#     373 d = xbar - x
#     375 steplength = line_search(
#     376     x,
#     377     f0,
#    (...)
#     391     dsave,
#     392 )
#
# File ~/workspace/pyrtid/pyrtid/inverse/solvers/lbfgsb/subspacemin.py:352, in direct_primal_subspace_minimization(X, G, x, xc, free_vars, Z, A, c, grad, lb, ub, W, invMfactors, theta)
#     349 v = WTZ.dot(rHat)
#     351 # Factorization of M^{-1}(I - 1/theta M WT Z @ ZT @ W))
# --> 352 LK: Optional[NDArrayFloat] = formk(X, G, Z, A, WTZ, invMfactors, theta)
#     354 if LK is not None:
#     355     # LK is the lowest triangle of the cholesky factorization
#     356     # of (I - 1/theta M WT Z @ ZT @ W)^{-1} M.
#     357     v = sp.linalg.solve_triangular(LK, v, lower=True)
#
# File ~/workspace/pyrtid/pyrtid/inverse/solvers/lbfgsb/subspacemin.py:207, in formk(X, G, Z, A, WTZ, invMfactors, theta, is_assert_correct)
#     195 """Form mk
#     196
#     197 Form  the LEL^T factorization of the indefinite
#    (...)
#     204 ----------
#     205 """
#     206 K = form_k_from_wm(WTZ, invMfactors, theta)
# --> 207 K2 = form_k_from_xgza(X, G, Z, A, theta)
#     209 # np.testing.assert_allclose(K, K2, atol=1e-8)
#     210 print(f"K = {K}")
#
# File ~/workspace/pyrtid/pyrtid/inverse/solvers/lbfgsb/subspacemin.py:141, in form_k_from_xgza(X, G, Z, A, theta)
#     139     YTZZTY = Y.T @ Z @ Z.T @ Y
#     140     print(YTZZTY)
# --> 141     RZ = sp.linalg.cholesky(
#     142         YTZZTY, lower=False, overwrite_a=False
#     143     )  # np.triu(YTZZTY)
#     145 # 2) LA is the strict lower triangle of S^{T}AA^{T}S
#     146 if A.size == 0:
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/linalg/_decomp_cholesky.py:89, in cholesky(a, lower, overwrite_a, check_finite)
#      45 def cholesky(a, lower=False, overwrite_a=False, check_finite=True):
#      46     """
#      47     Compute the Cholesky decomposition of a matrix.
#      48
#    (...)
#      87
#      88     """
# ---> 89     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
#      90                          check_finite=check_finite)
#      91     return c
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/linalg/_decomp_cholesky.py:37, in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      35 c, info = potrf(a1, lower=lower, overwrite_a=overwrite_a, clean=clean)
#      36 if info > 0:
# ---> 37     raise LinAlgError("%d-th leading minor of the array is not positive "
#      38                       "definite" % info)
#      39 if info < 0:
#      40     raise ValueError('LAPACK reported an illegal value in {}-th argument'
#      41                      'on entry to "POTRF".'.format(-info))
#
# LinAlgError: 3-th leading minor of the array is not positive definite

# %%
print(opt_rosenbrock)
# Out:
#   message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 1.7818523593938084e-06
#         x: [ 9.999e-01  9.999e-01]
#       nit: 23
#       jac: [-5.341e-02  2.659e-02]
#      nfev: 29
#      njev: 29
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>

# %% [markdown]
# ### Scipy

# %%
opt_rosenbrock_sp = minimize(
    rosenbrock,
    x0,
    jac=grad_rosenbrock,
    bounds=bounds,
    method="l-bfgs-b",
    options={"gtol": gtol, "ftol": ftol, "iprint": 100, "maxcor": 5},
)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =            5
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.72200D+02    |proj g|=  3.00000D+00
#
#
# ITERATION     1
#
# ---------------- CAUCHY entered-------------------
#  There are            2   breakpoints
#
# Piece      1 --f1, f2 at start point  -3.8679D+05  3.8679D+05
# Distance to the next break point =   5.2990D-03
# Distance to the stationary point =   1.0000D+00
#  Variable             1   is fixed.
#
# Piece      2 --f1, f2 at start point  -1.0701D+05  1.0758D+05
# Distance to the next break point =   3.8473D-03
# Distance to the stationary point =   9.9470D-01
#  Variable             2   is fixed.
#
# ---------------- exit CAUCHY----------------------
#
#            0  variables are free at GCP            1
#  LINE SEARCH           1  times; norm of step =    2.0052498411651980
#
# At iterate    1    f=  2.23351D+00    |proj g|=  2.46595D+00
#
#
# ITERATION     2
#
# ---------------- CAUCHY entered-------------------
#  There are            2   breakpoints
#
# Piece      1 --f1, f2 at start point  -1.9333D+03  6.3184D+05
# Distance to the next break point =   4.2890D-02
# Distance to the stationary point =   3.0597D-03
#
#  GCP found in this segment
# Piece      1 --f1, f2 at start point  -1.9333D+03  6.3184D+05
# Distance to the stationary point =   3.0597D-03
#
# ---------------- exit CAUCHY----------------------
#
#  Variable            2  enters the set of free variables
#  Variable            1  enters the set of free variables
#            0  variables leave;            2  variables enter
#            2  variables are free at GCP            2
#
# ----------------SUBSM entered-----------------
#
#
# ----------------exit SUBSM --------------------
#
#  LINE SEARCH           0  times; norm of step =   0.14209770645794761
#
# At iterate    2    f=  6.99053D-01    |proj g|=  2.65616D+00
#
#
# ITERATION     3
#
# ---------------- CAUCHY entered-------------------
#  There are            2   breakpoints
#
# Piece      1 --f1, f2 at start point  -6.0540D+02  3.0847D+05
# Distance to the next break point =   1.0797D-01
# Distance to the stationary point =   1.9626D-03
#
#  GCP found in this segment
# Piece      1 --f1, f2 at start point  -6.0540D+02  3.0847D+05
# Distance to the stationary point =   1.9626D-03
#
# ---------------- exit CAUCHY----------------------
#
#            0  variables leave;            0  variables enter
#            2  variables are free at GCP            3
#
# ----------------SUBSM entered-----------------
#
#
# ----------------exit SUBSM --------------------
#
#  LINE SEARCH           0  times; norm of step =    5.0286766021136374E-002
#
# At iterate    3    f=  1.43335D-01    |proj g|=  1.37662D+00
#
#
# ITERATION     4
#
# ---------------- CAUCHY entered-------------------
#  There are            2   breakpoints
#
# Piece      1 --f1, f2 at start point  -3.5446D+00  1.9992D+03
# Distance to the next break point =   8.0186D-01
# Distance to the stationary point =   1.7730D-03
#
#  GCP found in this segment
# Piece      1 --f1, f2 at start point  -3.5446D+00  1.9992D+03
# Distance to the stationary point =   1.7730D-03
#
# ---------------- exit CAUCHY----------------------
#
#            0  variables leave;            0  variables enter
#            2  variables are free at GCP            4
#
# ----------------SUBSM entered-----------------
#
#
# ----------------exit SUBSM --------------------
#
#  LINE SEARCH           0  times; norm of step =    3.3385258116703804E-003
#
# At iterate    4    f=  1.39714D-01    |proj g|=  4.22455D-01
#
#
# ITERATION     5
#
# ---------------- CAUCHY entered-------------------
#  There are            2   breakpoints
#
# Piece      1 --f1, f2 at start point  -2.4562D-01  5.9809D+01
# Distance to the next break point =   3.2514D+00
# Distance to the stationary point =   4.1067D-03
#
#  GCP found in this segment
# Piece      1 --f1, f2 at start point  -2.4562D-01  5.9809D+01
# Distance to the stationary point =   4.1067D-03
#
# ---------------- exit CAUCHY----------------------
#
#            0  variables leave;            0  variables enter
#            2  variables are free at GCP            5
#
# ----------------SUBSM entered-----------------
#
#
# ----------------exit SUBSM --------------------
#
#  LINE SEARCH           0  times; norm of step =    2.0600016410621202E-003
#
# At iterate    5    f=  1.38783D-01    |proj g|=  4.42650D-01
#
#
# ITERATION     6
#
# ---------------- CAUCHY entered-------------------
#  There are            2   breakpoints
#
# Piece      1 --f1, f2 at start point  -2.3116D-01  4.2675D+01
# Distance to the next break point =   3.6319D+00
# Distance to the stationary point =   5.4168D-03
#
#  GCP found in this segment
# Piece      1 --f1, f2 at start point  -2.3116D-01  4.2675D+01
# Distance to the stationary point =   5.4168D-03
#
# ---------------- exit CAUCHY----------------------
#
#            0  variables leave;            0  variables enter
#            2  variables are free at GCP            6
#
# ----------------SUBSM entered-----------------
#
#
# ----------------exit SUBSM --------------------
#
#  LINE SEARCH           0  times; norm of step =    1.9998704863266079E-002
#
# At iterate    6    f=  1.32239D-01    |proj g|=  1.33608D+00
#
#
# ITERATION     7
#
# ---------------- CAUCHY entered-------------------
#  There are            2   breakpoints
#
# Piece      1 --f1, f2 at start point  -2.7892D+00  4.0717D+03
# Distance to the next break point =   1.1929D+00
# Distance to the stationary point =   6.8502D-04
#
#  GCP found in this segment
# Piece      1 --f1, f2 at start point  -2.7892D+00  4.0717D+03
# Distance to the stationary point =   6.8502D-04
#
# ---------------- exit CAUCHY----------------------
#
#            0  variables leave;            0  variables enter
#            2  variables are free at GCP            7
#
# ----------------SUBSM entered-----------------
#
#
# ----------------exit SUBSM --------------------
#
#  LINE SEARCH           0  times; norm of step =    3.4175095332980306E-002
#
# At iterate    7    f=  1.23523D-01    |proj g|=  2.17372D+00
#
#
# ITERATION     8
#
# ---------------- CAUCHY entered-------------------
#  There are            2   breakpoints
#
# Piece      1 --f1, f2 at start point  -9.2930D+00  1.4722D+04
# Distance to the next break point =   7.3375D-01
# Distance to the stationary point =   6.3125D-04
#
#  GCP found in this segment
# Piece      1 --f1, f2 at start point  -9.2930D+00  1.4722D+04
# Distance to the stationary point =   6.3125D-04
#
# ---------------- exit CAUCHY----------------------
#
#            0  variables leave;            0  variables enter
#            2  variables are free at GCP            8
#
# ----------------SUBSM entered-----------------
#
#
# ----------------exit SUBSM --------------------
#
#  LINE SEARCH           0  times; norm of step =    5.8815573719827423E-002
#
# At iterate    8    f=  1.08917D-01    |proj g|=  2.70151D+00
#
#
# ITERATION     9
#
# ---------------- CAUCHY entered-------------------
#  There are            2   breakpoints
#
# Piece      1 --f1, f2 at start point  -1.9174D+01  2.4563D+04
# Distance to the next break point =   5.4053D-01
# Distance to the stationary point =   7.8061D-04
#
#  GCP found in this segment
# Piece      1 --f1, f2 at start point  -1.9174D+01  2.4563D+04
# Distance to the stationary point =   7.8061D-04
#
# ---------------- exit CAUCHY----------------------
#
#            0  variables leave;            0  variables enter
#            2  variables are free at GCP            9
#
# ----------------SUBSM entered-----------------
#
#
# ----------------exit SUBSM --------------------
#
#  LINE SEARCH           0  times; norm of step =    7.6186297073751089E-002
#
# At iterate    9    f=  8.43112D-02    |proj g|=  2.74473D+00
#
#
# ITERATION    10
#
# ---------------- CAUCHY entered-------------------
#  There are            2   breakpoints
#
# Piece      1 --f1, f2 at start point  -2.0700D+01  8.0555D+03
# Distance to the next break point =   5.2729D-01
# Distance to the stationary point =   2.5697D-03
#
#  GCP found in this segment
# Piece      1 --f1, f2 at start point  -2.0700D+01  8.0555D+03
# Distance to the stationary point =   2.5697D-03
#
# ---------------- exit CAUCHY----------------------
#
#            0  variables leave;            0  variables enter
#            2  variables are free at GCP           10
#
# ----------------SUBSM entered-----------------
#
#
# ----------------exit SUBSM --------------------
#
#  LINE SEARCH           0  times; norm of step =   0.10734218713148758
#
# At iterate   10    f=  4.31610D-02    |proj g|=  1.20492D+00
#
#
# ITERATION    11
#
# ---------------- CAUCHY entered-------------------
#  There are            2   breakpoints
#
# Piece      1 --f1, f2 at start point  -2.7107D+00  1.8477D+03
# Distance to the next break point =   8.0457D-01
# Distance to the stationary point =   1.4671D-03
#
#  GCP found in this segment
# Piece      1 --f1, f2 at start point  -2.7107D+00  1.8477D+03
# Distance to the stationary point =   1.4671D-03
#
# ---------------- exit CAUCHY----------------------
#
#            0  variables leave;            0  variables enter
#            2  variables are free at GCP           11
#
# ----------------SUBSM entered-----------------
#
#
# ----------------exit SUBSM --------------------
#
#  LINE SEARCH           1  times; norm of step =    8.3117571102299184E-002
#
# At iterate   11    f=  2.58161D-02    |proj g|=  4.53520D-01
#
#
# ITERATION    12
#
# ---------------- CAUCHY entered-------------------
#  There are            2   breakpoints
#
# Piece      1 --f1, f2 at start point  -4.0338D-01  4.3206D+02
# Distance to the next break point =   2.8557D+00
# Distance to the stationary point =   9.3360D-04
#
#  GCP found in this segment
# Piece      1 --f1, f2 at start point  -4.0338D-01  4.3206D+02
# Distance to the stationary point =   9.3360D-04
#
# ---------------- exit CAUCHY----------------------
#
#            0  variables leave;            0  variables enter
#            2  variables are free at GCP           12
#
# ----------------SUBSM entered-----------------
#
#
# ----------------exit SUBSM --------------------
#
#  LINE SEARCH           1  times; norm of step =    7.0328306240502417E-002
#
# At iterate   12    f=  1.91216D-02    |proj g|=  2.05171D+00
#
#
# ITERATION    13
#
# ---------------- CAUCHY entered-------------------
#  There are            2   breakpoints
#
# Piece      1 --f1, f2 at start point  -5.9178D+00  8.8115D+03
# Distance to the next break point =   9.4523D-01
# Distance to the stationary point =   6.7160D-04
#
#  GCP found in this segment
# Piece      1 --f1, f2 at start point  -5.9178D+00  8.8115D+03
# Distance to the stationary point =   6.7160D-04
#
# ---------------- exit CAUCHY----------------------
#
#            0  variables leave;            0  variables enter
#            2  variables are free at GCP           13
#
# ----------------SUBSM entered-----------------
#
#
# ----------------exit SUBSM --------------------
#
#  LINE SEARCH           0  times; norm of step =    4.9304414172265970E-002
#
# At iterate   13    f=  1.32430D-02    |proj g|=  1.98506D+00
#
#
# ITERATION    14
#
# ---------------- CAUCHY entered-------------------
#  There are            2   breakpoints
#
# Piece      1 --f1, f2 at start point  -5.4017D+00  3.5942D+03
# Distance to the next break point =   9.8633D-01
# Distance to the stationary point =   1.5029D-03
#
#  GCP found in this segment
# Piece      1 --f1, f2 at start point  -5.4017D+00  3.5942D+03
# Distance to the stationary point =   1.5029D-03
#
# ---------------- exit CAUCHY----------------------
#
#            0  variables leave;            0  variables enter
#            2  variables are free at GCP           14
#
# ----------------SUBSM entered-----------------
#
#
# ----------------exit SUBSM --------------------
#
#  LINE SEARCH           0  times; norm of step =    7.9508314120968177E-002
#
# At iterate   14    f=  3.92946D-03    |proj g|=  1.73137D-01
#
#
# ITERATION    15
#
# ---------------- CAUCHY entered-------------------
#  There are            2   breakpoints
#
# Piece      1 --f1, f2 at start point  -5.5135D-02  3.9185D+01
# Distance to the next break point =   7.0693D+00
# Distance to the stationary point =   1.4070D-03
#
#  GCP found in this segment
# Piece      1 --f1, f2 at start point  -5.5135D-02  3.9185D+01
# Distance to the stationary point =   1.4070D-03
#
# ---------------- exit CAUCHY----------------------
#
#            0  variables leave;            0  variables enter
#            2  variables are free at GCP           15
#
# ----------------SUBSM entered-----------------
#
#
# ----------------exit SUBSM --------------------
#
#  LINE SEARCH           0  times; norm of step =    8.8254983794303493E-002
#
# At iterate   15    f=  2.06046D-03    |proj g|=  1.55648D+00
#
#
# ITERATION    16
#
# ---------------- CAUCHY entered-------------------
#  There are            2   breakpoints
#
# Piece      1 --f1, f2 at start point  -3.0862D+00  3.2511D+03
# Distance to the next break point =   1.2813D+00
# Distance to the stationary point =   9.4927D-04
#
#  GCP found in this segment
# Piece      1 --f1, f2 at start point  -3.0862D+00  3.2511D+03
# Distance to the stationary point =   9.4927D-04
#
# ---------------- exit CAUCHY----------------------
#
#            0  variables leave;            0  variables enter
#            2  variables are free at GCP           16
#
# ----------------SUBSM entered-----------------
#
#
# ----------------exit SUBSM --------------------
#
#  LINE SEARCH           0  times; norm of step =    2.6491051000780306E-003
#
# At iterate   16    f=  4.42870D-04    |proj g|=  1.34219D-01
#
#
# ITERATION    17
#
# ---------------- CAUCHY entered-------------------
#  There are            2   breakpoints
#
# Piece      1 --f1, f2 at start point  -2.6027D-02  2.4906D+01
# Distance to the next break point =   1.1631D+01
# Distance to the stationary point =   1.0450D-03
#
#  GCP found in this segment
# Piece      1 --f1, f2 at start point  -2.6027D-02  2.4906D+01
# Distance to the stationary point =   1.0450D-03
#
# ---------------- exit CAUCHY----------------------
#
#            0  variables leave;            0  variables enter
#            2  variables are free at GCP           17
#
# ----------------SUBSM entered-----------------
#
#
# ----------------exit SUBSM --------------------
#
#  LINE SEARCH           0  times; norm of step =    2.9015300657978783E-002
#
# At iterate   17    f=  5.97777D-05    |proj g|=  5.03409D-02
#
#
# ITERATION    18
#
# ---------------- CAUCHY entered-------------------
#  There are            2   breakpoints
#
# Piece      1 --f1, f2 at start point  -3.6214D-03  3.0844D+00
# Distance to the next break point =   3.0789D+01
# Distance to the stationary point =   1.1741D-03
#
#  GCP found in this segment
# Piece      1 --f1, f2 at start point  -3.6214D-03  3.0844D+00
# Distance to the stationary point =   1.1741D-03
#
# ---------------- exit CAUCHY----------------------
#
#            0  variables leave;            0  variables enter
#            2  variables are free at GCP           18
#
# ----------------SUBSM entered-----------------
#
#
# ----------------exit SUBSM --------------------
#
#  LINE SEARCH           0  times; norm of step =    1.5430538351715956E-002
#
# At iterate   18    f=  2.25453D-06    |proj g|=  5.29740D-02
#
#
# ITERATION    19
#
# ---------------- CAUCHY entered-------------------
#  There are            2   breakpoints
#
# Piece      1 --f1, f2 at start point  -3.5432D-03  4.4320D-01
# Distance to the next break point =   3.6890D+01
# Distance to the stationary point =   7.9945D-03
#
#  GCP found in this segment
# Piece      1 --f1, f2 at start point  -3.5432D-03  4.4320D-01
# Distance to the stationary point =   7.9945D-03
#
# ---------------- exit CAUCHY----------------------
#
#            0  variables leave;            0  variables enter
#            2  variables are free at GCP           19
#
# ----------------SUBSM entered-----------------
#
#
# ----------------exit SUBSM --------------------
#
#  LINE SEARCH           1  times; norm of step =    1.7708046774439736E-004
#
# At iterate   19    f=  3.87387D-07    |proj g|=  1.60319D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     19     24     20     0     0   1.603D-03   3.874D-07
#
#  X =  9.9938D-01  9.9876D-01
#   F =   3.8738696320307411E-007
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
opt_rosenbrock_sp
# Out:
#   message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 3.873869632030741e-07
#         x: [ 9.994e-01  9.988e-01]
#       nit: 19
#       jac: [-1.603e-03  1.794e-04]
#      nfev: 24
#      njev: 24
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>

# %% [markdown]
# ## Third example : min Beale function

# %%
def beale(x):
    return (
        (1.5 - x[0] + x[0] * x[1]) ** 2
        + (2.25 - x[0] + x[0] * x[1] ** 2) ** 2
        + (2.625 - x[0] + x[0] * x[1] ** 3) ** 2
    )


def grad_beale(x):
    y1 = x[1]
    y2 = y1 * y1
    y3 = y2 * y1
    f1 = 1.5 - x[0] + x[0] * y1
    f2 = 2.25 - x[0] + x[0] * y2
    f3 = 2.625 - x[0] + x[0] * y3

    return np.array(
        [
            2 * (y1 - 1) * f1 + 2 * (y2 - 1) * f2 + 2 * (y3 - 1) * f3,
            2 * x[0] * f1 + 4 * x[0] * y1 * f2 + 6 * x[0] * y2 * f3,
        ]
    )


ftol = 1e-14
gtol = 1e-10
l = -4.5 * np.ones(2)
u = -l
bounds = np.array((l, u)).T
x0 = np.array([2.5, -1.3])

# %% [markdown]
# ### New implementation

# %%
opt_beale = minimize_lbfgsb(
    x0=x0, fun=beale, jac=grad_beale, bounds=bounds, ftol=ftol, gtol=gtol
)
print("")
print("")
theoOpt = {
    "x": np.array([3, 0.5]),
    "f": beale(np.array([3, 0.5])),
    "df": grad_beale(np.array([3, 0.5])),
}
print("Theoretical optimal value: ")
print(theoOpt)
print("Optimal value found: ")
# Out:
# K11     = [[343.56344264]]
# K11 bis = [[343.56344264]]
# K11     = [[1.42585345e+03 7.88450811e+00]
#  [7.88450811e+00 1.04522466e-01]]
# K11 bis = [[1.42585345e+03 7.88450811e+00]
#  [7.88450811e+00 1.04522466e-01]]
# K11     = [[2.05761871e+03 1.18564964e+01 3.77709427e+01]
#  [1.18564964e+01 1.30850171e-01 2.53574081e-01]
#  [3.77709427e+01 2.53574081e-01 1.64120549e+00]]
# K11 bis = [[2.05761871e+03 1.18564964e+01 3.77709427e+01]
#  [1.18564964e+01 1.30850171e-01 2.53574081e-01]
#  [3.77709427e+01 2.53574081e-01 1.64120549e+00]]
# K11     = [[4.75668398e+03 2.88258623e+01 9.18298250e+01 3.35917898e+01]
#  [2.88258623e+01 2.43328967e-01 6.16496752e-01 2.20218062e-01]
#  [9.18298250e+01 6.16496752e-01 2.81567623e+00 7.08713559e-01]
#  [3.35917898e+01 2.20218062e-01 7.08713559e-01 5.08779599e-01]]
# K11 bis = [[4.75668398e+03 2.88258623e+01 9.18298250e+01 3.35917898e+01]
#  [2.88258623e+01 2.43328967e-01 6.16496752e-01 2.20218062e-01]
#  [9.18298250e+01 6.16496752e-01 2.81567623e+00 7.08713559e-01]
#  [3.35917898e+01 2.20218062e-01 7.08713559e-01 5.08779599e-01]]
# K11     = [[8.20173757e+03 5.04853514e+01 1.60829915e+02 5.88323532e+01
#   5.72613941e+01]
#  [5.04853514e+01 3.86895514e-01 1.07972677e+00 3.85687898e-01
#   3.35978960e-01]
#  [1.60829915e+02 1.07972677e+00 4.31475618e+00 1.24123444e+00
#   1.05122132e+00]
#  [5.88323532e+01 3.85687898e-01 1.24123444e+00 6.99925766e-01
#   3.97489114e-01]
#  [5.72613941e+01 3.35978960e-01 1.05122132e+00 3.97489114e-01
#   8.83703820e-01]]
# K11 bis = [[8.20173757e+03 5.04853514e+01 1.60829915e+02 5.88323532e+01
#   5.72613941e+01]
#  [5.04853514e+01 3.86895514e-01 1.07972677e+00 3.85687898e-01
#   3.35978960e-01]
#  [1.60829915e+02 1.07972677e+00 4.31475618e+00 1.24123444e+00
#   1.05122132e+00]
#  [5.88323532e+01 3.85687898e-01 1.24123444e+00 6.99925766e-01
#   3.97489114e-01]
#  [5.72613941e+01 3.35978960e-01 1.05122132e+00 3.97489114e-01
#   8.83703820e-01]]
#   -1.28762848e-08]
#  [ 2.94447729e-06 -7.44014458e-07 -9.93920875e-07  2.51589820e-06
#   -8.87862592e-07  1.00467313e-06 -1.71633384e-07  2.16751275e-09
#    5.19306316e-11]
#  [ 2.01908485e-07 -7.63071869e-08 -8.13458111e-08  1.84279561e-07
#   -6.79490115e-08  7.48760538e-08 -1.28762848e-08  5.19306316e-11
#    7.62136965e-12]]
# K11 bis = [[ 4.60958378e-02  4.35983648e-03 -1.05451879e-03  9.89475299e-03
#   -2.51758027e-03  3.52110418e-03 -5.73190493e-04  2.94447729e-06
#    2.01908485e-07]
#  [ 4.35983648e-03  9.02615166e-02  6.62127263e-03 -3.48963746e-03
#    3.02092582e-03 -2.18358283e-03  4.25078771e-04 -7.44014458e-07
#   -7.63071869e-08]
#  [-1.05451879e-03  6.62127263e-03  1.83755363e-02 -3.85610299e-03
#    2.09373686e-03 -1.86345241e-03  3.39660110e-04 -9.93920875e-07
#   -8.13458111e-08]
#  [ 9.89475299e-03 -3.48963746e-03 -3.85610299e-03  1.51719714e-02
#   -3.26009189e-03  3.61025957e-03 -6.20077859e-04  2.51589820e-06
#    1.84279561e-07]
#  [-2.51758027e-03  3.02092582e-03  2.09373686e-03 -3.26009189e-03
#    2.80771897e-03 -1.42328800e-03  2.51147183e-04 -8.87862592e-07
#   -6.79490115e-08]
#  [ 3.52110418e-03 -2.18358283e-03 -1.86345241e-03  3.61025957e-03
#   -1.42328800e-03  1.77167626e-03 -2.61885974e-04  1.00467313e-06
#    7.48760538e-08]
#  [-5.73190493e-04  4.25078771e-04  3.39660110e-04 -6.20077859e-04
#    2.51147183e-04 -2.61885974e-04  5.25878991e-05 -1.71633384e-07
#   -1.28762848e-08]
#  [ 2.94447729e-06 -7.44014458e-07 -9.93920875e-07  2.51589820e-06
#   -8.87862592e-07  1.00467313e-06 -1.71633384e-07  2.16751275e-09
#    5.19306316e-11]
#  [ 2.01908485e-07 -7.63071869e-08 -8.13458111e-08  1.84279561e-07
#   -6.79490115e-08  7.48760538e-08 -1.28762848e-08  5.19306316e-11
#    7.62136965e-12]]
#
#
# Theoretical optimal value:
# {'x': array([3. , 0.5]), 'f': 0.0, 'df': array([-0.,  0.])}
# Optimal value found:

# %%
print(opt_beale)
# Out:
#   message: CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#   success: True
#    status: 1
#       fun: 6.910751138008978e-24
#         x: [ 3.000e+00  5.000e-01]
#       nit: 16
#       jac: [-5.141e-12  2.368e-11]
#      nfev: 19
#      njev: 19
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>

# %% [markdown]
# ### Scipy

# %%
opt_beale_sp = minimize(
    beale,
    x0,
    jac=grad_beale,
    bounds=bounds,
    method="l-bfgs-b",
    options={"gtol": gtol, "ftol": ftol},
)

# %%
opt_beale_sp
# Out:
#   message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 1.4337068336583181e-21
#         x: [ 3.000e+00  5.000e-01]
#       nit: 16
#       jac: [-7.089e-11  1.797e-10]
#      nfev: 20
#      njev: 20
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>

# %% [markdown]
# - Comparision of convergence
