# %% [markdown]
# # pyPCGA modflow inversion example
#
# ## Crosswell tomography
#
# We test:
# - true
# - no regularization (no_reg)
# - gradient smoothing (gs)
# - tikonov adaptative (tka)
# - gradient smoothing + tikhonov adaptative (gstka)
# - tv
# - sigmoid
# - sigmoid + tv
#
# - Adapted from Application 1 of Lee and Kitanids [WRR 2014]
#
# (https://agupubs.onlinelibrary.wiley.com/doi/full/10.1002/2014WR015483)
#
# ***
#
# > We first generated 870 head observations using crosswell pumping tests (ln 9) from the reference log K field (ln 11) with USGS MODFLOW Flopy python interface.
#
# > In specific, we extracted groundwater at a well and observed 29 stready-state hydraulic heads at the remaining monitoring wells. We repeated these crosswell pumping tests for all 30 well locations (ln 11).
#
# > Then add the noise (std = 0.5) to observations. Using observations with MODFLOW, can we reconstruct the reference field (ln 11)?
#
# Note the example is not exactly same as Application 1 in Lee and Kitanidis [2014]
#
# Also, the number of MODFLOW simulations is higher than what they reported because we turned on Levenberg-Marquardt and Line Search options in this example. Those additional optimization routines increases the inversion time, but usually results in a very accurate inverse solution even for highly nonlinear problems.
#
# ***
#
# - Parameters
#
# |Description           |                      |   Value |
# |----------------------|:----------------------------------:|:---------------------------:|
# |*Geomteric parameters*                          | |       |
# | Lx, Ly        | Domain length and width [m]        |        1000, 750|
# | Q             | Pumping rates (m^2/d)              |            25 |
# | Rch           | Recharge rates (m/d)               |           0.001|
# | dx, dy        | Grid size [m]                      |            10|
# |*Geostatistical parameters*     ||                      |
# | reference mean(logK)    | mean for the reference log K (ln m/d) |            2.5  |
# | reference q(x,x')       | Covariance kernel for the reference log K                  | q(x,x') = 0.002^3 (x-x')^3 |
# | q(x,x')            | Covariance kernel used in inversion | q(x,x') = exp(-x/250) |
# |*Measurement Error* ||  |
# | nobs | Number of measurement | 870 |
# | R | Variance of measurement error [m] | 0.5^2 |

# %%
import os
import logging
import copy
from pathlib import Path
from typing import List, Tuple, Iterable, Dict, Any
import matplotlib.pyplot as plt
from matplotlib.animation import HTMLWriter
from matplotlib.colors import LogNorm, SymLogNorm
from IPython.display import HTML
import nested_grid_plotter as ngp
import pyrtid
import pyrtid.forward as dmfwd
import pyrtid.inverse as dminv
from pyrtid.utils import (
    indices_to_node_number,
    GaussianFilter,
    extract_hess_inv_diag,
)
from pyrtid.inverse.params import (
    get_gridded_archived_gradients,
)
from pyrtid.inverse.regularization import (
    GeostatisticalRegularizator,
    FFTCovarianceMatrix,
    eigen_factorize_cov_mat,
    MeanPriorTerm,
)
import numpy as np
from pyrtid.utils.types import NDArrayFloat
import scipy as sp
from scipy.sparse import csc_array
import gstlearn as gl
from pyrtid.utils import sparse_cholesky
from pyrtid.utils import extract_hess_inv_diag

# %% [markdown]
# - Set-up logging level

# %%
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logging.info("this is a logging test")
print("This is a print test")
# Out:
# INFO:root:this is a logging test
# This is a print test

# %% [markdown]
# - Check package/software versions

# %%
pyrtid.utils.show_versions()
# Out:
# INFO:root:Current version = 0.1.0
#
# INFO:root:Used packages version:
#
# INFO:root:iterative_ensemble_smoother = 0.1.1
# INFO:root:gstools                     = 1.5.1
# INFO:root:matplotlib                  = 3.9.0
# INFO:root:nested_grid_plotter         = 2.0.0
# INFO:root:numdiftools                 = 0.9.41
# INFO:root:numpy                       = 1.25.2
# INFO:root:pyesmda                     = 0.4.3
# INFO:root:lbfgsb                      = 0.1.1
# INFO:root:scipy                       = 1.13.1
# INFO:root:sksparse                    = 0.4.13
# INFO:root:stochopy                    = 2.3.0

# %% [markdown]
# - Create a directory to store the exported figures

# %%
ipynb_path = os.path.dirname(os.path.realpath("__file__"))
fig_save_path = Path(ipynb_path, "exported_figures")
fig_save_path.mkdir(parents=True, exist_ok=True)  # make sure that the directory exists

# %% [markdown]
# - Define some configurations for the plots

# %%
pyrtid.plot.apply_default_rc_params()

# %% [markdown]
# ## Forward problem

# %% [markdown]
# - Grid definition

# %%
nx = 100
ny = 75
nz = 1
dx = 10  # m
dy = 10  # m
dz = 1

# %% [markdown]
# - Location of pumping wells (obs_locmat)

# %%
obs_locmat = np.zeros((nz, ny, nx), dtype=bool)
obs_locs: List[Tuple[int, int]] = []
for i in range(5, 71, 16):  # y
    for j in range(9, 96, 16):  # x
        obs_locmat[0, i, j] = 1
        obs_locs.append((j, i))

Q_locs_idx = np.where(obs_locmat == True)
Q_locs = []
for Q_loc in zip(Q_locs_idx[0], Q_locs_idx[1], Q_locs_idx[2]):
    Q_locs.append(Q_loc)

# %% [markdown]
# - x,y coordinates for plotting

# %%
x = np.linspace(0.0 + dx / 2.0, nx * dx - dx / 2.0, nx)
y = np.linspace(0.0 + dy / 2.0, ny * dy - dy / 2.0, ny)
XX, YY = np.meshgrid(x, y)
pts = np.hstack((XX.ravel()[:, np.newaxis], YY.ravel()[:, np.newaxis]))

# %% [markdown]
# - Pumping/monitoring well locations

# %%
plotter = ngp.NestedGridPlotter()
ax = plotter.axes[0]
idx = np.where(obs_locmat == 1)
for i, j in zip(idx[1], idx[2]):
    ax.plot(x[j], y[i], "ko")
ax.set_xlim(0, nx * dx)
ax.set_ylim(0, ny * dy)
ax.set_ylabel("Constant head = 120 m")
ax2 = ax.twinx()
ax2.set_ylabel("Constant head = 110 m")
# ax.set_ylabel("Y [m]", fontweight="bold")
ngp.hide_axis_ticklabels(ax2)
plotter.fig.supxlabel("No flow")
plotter.fig.suptitle("No flow")

fname = "well_locations"
for format in ["png", "pdf"]:
    plt.savefig(str(fig_save_path.joinpath(f"{fname}.{format}")), format=format)

# %% [markdown]
# - This example is Hydraulic tomography - crosswell pumping test setting
# - Load reference value for comparison purpose with its plot
#
# Note: in the demonstrator, we can adjust the permeability (m/s), so we need to convert these values to permeability ones

# %%
def log_transmitivity_to_permeability(x: NDArrayFloat) -> NDArrayFloat:
    """Convert a transmitivity in ln[m2/d] to a permeability in [m/s]."""
    return np.exp(x) / 3600 / 24


def permeability_to_log_transmitivity(x: NDArrayFloat) -> NDArrayFloat:
    """Convert a permeability in [m/s] to a transmitivity in ln[m2/d]."""
    return np.log(x * 3600 * 24)


logT_reference: NDArrayFloat = np.loadtxt("../../data/reference_logK.txt")
perm_reference = log_transmitivity_to_permeability(logT_reference)
perm_reference_2d = perm_reference.reshape(ny, nx).T
logT_reference_3d = logT_reference.reshape(nz, ny, nx)
logT_reference_2d = logT_reference_3d[0, :, :].T

plotter = ngp.NestedGridPlotter(
    plt.figure(constrained_layout=True, figsize=(15, 5)),
    builder=ngp.SubplotsMosaicBuilder(
        mosaic=[["ax1-1", "ax1-2"]], sharey=True, sharex=True
    ),
)

# Plot the permeability
ngp.multi_imshow(
    axes=[plotter.get_axis("ax1-1")],
    fig=plotter.fig,
    data={"reference logK": logT_reference_2d},
    cbar_title="Transmitivity field (logK), $ln[m2/d]$",
    imshow_kwargs={"cmap": plt.get_cmap("jet"), "extent": [0.0, nx * dx, 0.0, ny * dy]},
    xlabel="X [m]",
    ylabel="Y [m]",
)

ngp.multi_imshow(
    axes=[plotter.get_axis("ax1-2")],
    fig=plotter.fig,
    data={"reference permeability": perm_reference_2d},
    cbar_title="Permeability field $[m/s]$",
    imshow_kwargs={
        "cmap": plt.get_cmap("jet"),
        "norm": LogNorm(vmin=1e-5, vmax=1e-3),
        "extent": [0.0, nx * dx, 0.0, ny * dy],
    },
    xlabel="X [m]",
    ylabel="Y [m]",
)

# %% [markdown]
# - Load observations (head) -> 30 wells = 30 pumping tests with 29 observations because we do no measure at the pumping well

# %%
obs_data: NDArrayFloat = np.loadtxt("../../data/obs.txt").reshape(30, -1)
obs_data.shape
# Out:
# (30, 29)

# %%
grid_obs = np.full((len(obs_locs), nx, ny), fill_value=np.nan, dtype=float)
for i, obs_loc in enumerate(obs_locs):
    j = 0
    for obs_loc2 in obs_locs:
        if obs_loc2 != obs_loc:
            grid_obs[i][obs_loc2] = obs_data[i][j]
            j += 1

# %% [markdown]
# # Forward Model with PyRTID

# %% [markdown]
# - Creation of a base model

# %%
duration_in_days = 31
duration_in_s = duration_in_days * 3600 * 24
dt_init = 3600 * 12  # timestep in seconds
dt_min = dt_init
dt_max = dt_init

# Simulation on 31 days. We use a 4h timestep.
time_params = dmfwd.TimeParameters(
    duration=duration_in_s, dt_init=dt_init, dt_max=dt_max, dt_min=dt_min
)

geometry = dmfwd.Geometry(nx=nx, ny=ny, dx=dx, dy=dy)
fl_params = dmfwd.FlowParameters(
    permeability=8.0e-5,
    storage_coefficient=1e-6,
    regime=dmfwd.FlowRegime.STATIONARY,
    crank_nicolson=1.0,
)
tr_params = dmfwd.TransportParameters(is_numerical_acceleration=True, is_skip_rt=True)

base_model = dmfwd.ForwardModel(geometry, time_params, fl_params, tr_params)

# %% [markdown]
# - Add boundary conditions and regional recharge

# %%
# Add a regional recharge -> 1000 m3/d = 1000 / 3600 / 24 m3/s
flw_reg = 1000.0 / 3600 / 24
recharge_source = dmfwd.SourceTerm(
    "aquifer_recharge",
    node_ids=np.arange(nx * ny),  # -> on the full domain
    times=np.arange(time_params.nt) * time_params.dt,
    flowrates=np.repeat(flw_reg, time_params.nt),
    concentrations=np.repeat(0.0, time_params.nt),
)
base_model.add_src_term(recharge_source)

# Boundary conditions
# Left border (x = 0) at 120 m
base_model.add_boundary_conditions(dmfwd.ConstantHead(span=(slice(0, 1), slice(None))))
base_model.fl_model.set_initial_head(120.0, span=(slice(0, 1), slice(None)))
# Right border (x = xmax) at 110 m
base_model.add_boundary_conditions(
    dmfwd.ConstantHead(span=(slice(nx - 1, nx), slice(None)))
)
base_model.fl_model.set_initial_head(110.0, span=(slice(nx - 1, nx), slice(None)))

# %% [markdown]
# - Create the source terms for the pumping: one pumping test per day at -25 m3/h

# %%
flowrates = np.array([-25.0 / 3600, 0.0])
for day in range(1, int(duration_in_days)):
    ix, iy = obs_locs[day - 1]
    source_term = dmfwd.SourceTerm(
        "well pumping test # {day}",
        node_ids=np.array(
            indices_to_node_number(ix=ix, nx=nx, iy=iy, ny=ny)
        ),  # -> on the full domain
        times=np.array([day * 3600 * 24, (day + 0.5) * 3600 * 24]),
        flowrates=flowrates,
        concentrations=np.zeros((2,)),
    )
    base_model.add_src_term(source_term)

# %% [markdown]
# - Create two models with different permeabilities

# %%
# copy the base model
model_reference = copy.deepcopy(base_model)
# update permeability
model_reference.fl_model.permeability = perm_reference_2d
# solve the flow problem
dmfwd.ForwardSolver(model_reference).solve(is_verbose=True)

# %%
# copy the base model
model_estimate = copy.deepcopy(base_model)
# update permeability
model_estimate.fl_model.permeability[:, :] = log_transmitivity_to_permeability(1.0)
# solve the flow problem
dmfwd.ForwardSolver(model_estimate).solve()

# %% [markdown]
# - Check pumping

# %%
model_estimate.time_params.times
# Out:
# array([      0,   43200,   86400,  129600,  172800,  216000,  259200,
#         302400,  345600,  388800,  432000,  475200,  518400,  561600,
#         604800,  648000,  691200,  734400,  777600,  820800,  864000,
#         907200,  950400,  993600, 1036800, 1080000, 1123200, 1166400,
#        1209600, 1252800, 1296000, 1339200, 1382400, 1425600, 1468800,
#        1512000, 1555200, 1598400, 1641600, 1684800, 1728000, 1771200,
#        1814400, 1857600, 1900800, 1944000, 1987200, 2030400, 2073600,
#        2116800, 2160000, 2203200, 2246400, 2289600, 2332800, 2376000,
#        2419200, 2462400, 2505600, 2548800, 2592000, 2635200, 2678400])

# %%
fl_sources = model_estimate.fl_model.unitflow

fig, ax = plt.subplots()
for i in range(len(obs_locs)):
    ix, iy = obs_locs[i]
    ax.plot(model_estimate.time_params.times, fl_sources[ix, iy, :])
ax.set_xlabel("time #", fontweight="bold")
ax.set_ylabel("flowrates [m3/s]", fontweight="bold")
# Out:
# Text(0, 0.5, 'flowrates [m3/s]')

# %% [markdown]
# - Plot one time step

# %%
plotter = ngp.NestedGridPlotter(
    plt.figure(constrained_layout=True, figsize=(15, 5)),
    builder=ngp.SubplotsMosaicBuilder(
        mosaic=[["ax1-1", "ax1-2", "ax1-3"]], sharey=True, sharex=True
    ),
)


well_id = 2
ngp.multi_imshow(
    axes=[plotter.get_axis(ax_name) for ax_name in ["ax1-1", "ax1-2", "ax1-3"]],
    data={
        # Warning: observation 0 matches sample 1
        "Observations (MODFLOW)": grid_obs[well_id],
        "Reference (HYTEC)": model_reference.fl_model.head[:, :, well_id + 1],
        "Initial guess (HYTEC)": model_estimate.fl_model.head[:, :, well_id + 1],
    },
    fig=plotter.fig,
    cbar_title="Head [m]",
    imshow_kwargs={"vmin": 100, "vmax": 150, "extent": [0.0, nx * dx, 0.0, ny * dy]},
    xlabel="X [m]",
    ylabel="Y [m]",
)

plotter.fig.suptitle("Head field [m]", fontweight="bold")
plotter.fig.supxlabel("X [m]", fontweight="bold")

fname = "head_field_reference_vs_initial_guess"
for format in ["png", "pdf"]:
    plotter.savefig(str(fig_save_path.joinpath(f"{fname}.{format}")), format=format)

# %% [markdown]
# - Make an animated version

# %%
# plotter = ngp.AnimatedPlotter(
#     plt.figure(constrained_layout=True, figsize=(15, 5)),
#     builder=ngp.SubplotsMosaicBuilder((
#         "fig0": dict(mosaic=[["ax1-1", "ax1-2", "ax1-3"]], sharey=True, sharex=True)
#     },
# )

# nb_frames = grid_obs.shape[0]
# plotter.animated_multi_imshow(
#     ax_names=["ax1-1", "ax1-2", "ax1-3"],
#     data={
#         # Warning: observation 0 matches sample 1
#         "Observations (MODFLOW)": np.transpose(grid_obs, axes=(1, 2, 0)),
#         "Reference (HYTEC)": model_reference.fl_model.head[:, :, 3::2],
#         "Initial guess (HYTEC)": model_estimate.fl_model.head[:, :, 3::2],
#     },
#     cbar_title="Head [m]",
#     nb_frames=nb_frames,
#     imshow_kwargs={"vmin": 100, "vmax": 150, "extent": [0.0, nx * dx, 0.0, ny * dy]},
#     xlabel="X [m]",
#     ylabel="Y [m]",
# )

# plotter.fig.suptitle("Head field [m]", fontweight="bold")

# plotter.close()
# plotter.animate(nb_frames=nb_frames)

# # Save the animation locally on the computer
# fname_html = fig_save_path.joinpath(
#     "head_field_reference_vs_initial_guess_animated.html"
# )
# writer = HTMLWriter(fps=5, embed_frames=True)
# writer.frame_format = "svg"  # Ensure svg format
# plotter.animation.save(str(fname_html), writer=writer)

# # Display the animation
# HTML(fname_html.read_text())

# %%
# def get_frame_time_label(
#     nb_frames: int, ltimes: Union[List[float], NDArrayFloat]
# ) -> Generator[str, None, None]:
#     """
#     Generator of time labels (in d).

#     Parameters
#     ----------
#     nb_frames : int
#         Number of frames in the animation.
#     ltimes : List[float]
#         List of times. The length of the list must be equal or greater than `nb_frames`.
#         Times are expected in seconds.

#     Yields
#     ------
#     Generator[str, None, None]
#     """
#     # subtract -1 to nb_steps and _nb_frames so that when
#     # frame_index = 0, we get the first element of ltimes, and when
#     # frame_index = _nb_frames - 1, we get the last element of ltimes.
#     ts_btw_frames = (len(ltimes) - 1) / (nb_frames - 1)
#     for frame in range(nb_frames):
#         yield f"time = {ltimes[int(ts_btw_frames * frame)] / 3600 / 24:.1f} d"


# plotter = ngp.AnimatedPlotter(
#     plt.figure(constrained_layout=True, figsize=(7, 12)},
#     builder=ngp.SubplotsMosaicBuilder((
#         "fig0": dict(
#             mosaic=[[f"ax{i+1}-{j+1}" for j in range(2)] for i in range(5)],
#             sharey=True,
#             sharex=True,
#         )
#     },
# )

# nb_frames = min(model_estimate.time_params.nt, 5)
# _times = list(get_frame_time_label(nb_frames, model_reference.time_params.times))


# def get_frame_id(frame_index: int):
#     return int((model_estimate.time_params.nt - 1) / (nb_frames - 1) * frame_index)


# cbar = ngp.multi_imshow(
#     axes=plotter.axes[::2],
#     fig=plotter.fig,
#     data={
#         f"{_times[index]}": model_reference.fl_model.head[:, :, get_frame_id(index)]
#         for index in range(nb_frames)
#     },
#     imshow_kwargs={
#         "extent": [0.0, nx * dx, 0.0, ny * dy],
#         "vmin": 100.0,
#         "vmax": 150.0,
#         "aspect": "equal",
#         # "cmap": plt.get_cmap("jet"),
#     },
#     # cbar_kwargs={"orientation":None, "location":"bottom", "shrink": 0.5, "pad":0.0},
#     cbar_kwargs={"shrink": 0.4},
#     cbar_title="Uranium",
# )
# # no need to duplicate cbars
# cbar.remove()

# cbar = ngp.multi_imshow(
#     axes=plotter.axes[1::2],
#     fig=plotter.fig,
#     data={
#         f"{_times[index]}": model_estimate.fl_model.head[:, :, get_frame_id(index)]
#         for index in range(nb_frames)
#     },
#     imshow_kwargs={
#         "extent": [0.0, nx * dx, 0.0, ny * dy],
#         "vmin": 100.0,
#         "vmax": 150.0,
#         "aspect": "equal",
#         # "cmap": plt.get_cmap("jet"),
#     },
#     # cbar_kwargs={"orientation":None, "location":"bottom", "shrink": 0.5, "pad":0.0},
#     cbar_kwargs={"shrink": 0.4},
#     cbar_title="Head [m]",
# )
# # cbar.ax.get_xaxis().labelpad = 00
# # cbar.ax.set_xlabel("H2SO4 [g/l]", rotation=0)

# plotter.fig.supxlabel("X [m]", fontweight="bold")
# plotter.fig.supylabel("Y [m]", fontweight="bold")
# # plotter.fig.suptitle("Uranium: Reference (left) vs. Initial Guess (right)", fontweight="bold")

# # Save the animation locally on the computer
# fname = fig_save_path.joinpath("head_reference_vs_ig_map")
# for format in ["png", "pdf"]:
#     plotter.savefig((fig_save_path.joinpath(f"{fname}.{format}")), format=format)

# %% [markdown]
# - Compare the data from HYTEC with the one from MODFLOW for the "reference" model

# %%
pumping_test_id = 5  # index of the well pumping test

dat_modflow: NDArrayFloat = np.zeros(len(obs_locs))
dat_pyrtid_reference: NDArrayFloat = np.zeros(len(obs_locs))
dat_pyrtid_estimate: NDArrayFloat = np.zeros(len(obs_locs))

for i, obs_loc in enumerate(obs_locs):
    dat_modflow[i] = grid_obs[pumping_test_id][obs_loc[0], obs_loc[1]]
    dat_pyrtid_reference[i] = model_reference.fl_model.head[
        :, :, (pumping_test_id + 1)
    ][obs_loc[0], obs_loc[1]]
    dat_pyrtid_estimate[i] = model_estimate.fl_model.head[:, :, (pumping_test_id + 1)][
        obs_loc[0], obs_loc[1]
    ]

plt.plot(dat_modflow, label="modflow")
plt.plot(dat_pyrtid_reference, label="pyrtid reference")
plt.plot(dat_pyrtid_estimate, label="pyrtid estimate")
plt.legend()

fname = f"heads_modflow_vs_hytec_for_pumping_test_{pumping_test_id}"
for format in ["png", "pdf"]:
    plt.savefig(str(fig_save_path.joinpath(f"{fname}.{format}")), format=format)

# %% [markdown]
# - Compare the same data but looked at a specific well location

# %%
np.transpose(grid_obs, axes=(1, 2, 0)).shape
# Out:
# (100, 75, 30)

# %%
well_id = 15  # index of the well pumping test
obs_loc = obs_locs[well_id]
ix, iy = obs_loc

dat_modflow = np.transpose(grid_obs, axes=(1, 2, 0))[ix, iy, :]
dat_pyrtid_reference = model_reference.fl_model.head[
    ix, iy, 1:
].copy()  # We do not count time 0
dat_pyrtid_reference[well_id] = np.nan  # Exclude the day of pumping
dat_pyrtid_estimate = model_estimate.fl_model.head[
    ix, iy, 1:
].copy()  # We do not count time 0
dat_pyrtid_estimate[well_id] = np.nan  # Exclude the day of pumping

plt.plot(dat_modflow, label="modflow")
plt.plot(dat_pyrtid_reference, label="pyrtid reference")
plt.plot(dat_pyrtid_estimate, label="pyrtid estimate")
plt.legend()

# %%
noise_std = 0.5  # This is an absolute value


def get_white_noise(shape: Iterable[int]) -> NDArrayFloat:
    """
    Return the input with some added white noise.

    Note
    ----
    The parameters are hardcoded to be consistent in the notebook.
    Change the function directly.
    """
    mean_noise = 0.0  # mean
    return np.random.default_rng(2021).normal(
        mean_noise, noise_std, size=np.array(shape)
    )


obs_noise: NDArrayFloat = get_white_noise((len(obs_locs), 29))

# %% [markdown]
# # Inversion

# %% [markdown]
# - Define observables

# %%
observables: List[dminv.Observable] = []
for count, (ix, iy) in enumerate(obs_locs):
    vals = model_reference.fl_model.head[ix, iy, 3::2]  # 30 measures from day 1 to 30
    times = model_reference.time_params.times[3::2]
    # Remove the pumping day
    vals = np.delete(vals, count)
    times = np.delete(times, count)

    observables.append(
        dminv.Observable(
            state_variable=dminv.StateVariable.HEAD,
            node_indices=np.array(indices_to_node_number(ix=ix, nx=nx, iy=iy, ny=ny)),
            times=times,
            values=vals + obs_noise[count],
            uncertainties=noise_std,
        )
    )

# %% [markdown]
# - Create a simulation for inversion based

# %% [markdown]
# - true
# - no regularization (no_reg)
# - gradient smoothing (gs)
# - tikonov adaptative (tka)
# - gradient smoothing + tikhonov adaptative (gstka)
# - tv (tva)
# - sigmoid (sg)
# - sigmoid + tv (gstv)

# %%
solver_config = dminv.LBFGSBSolverConfig(
    maxfun=3,
    maxiter=30,
    ftol=1e-7,
    gtol=1e-7,
    is_check_gradient=False,
    is_adj_numerical_acceleration=True,
    afpi_eps=1e-10,
)

# %%
# dict to store results
params: Dict[str, dminv.AdjustableParameter] = {}
adjusted_models: Dict[str, dmfwd.ForwardModel] = {}
inverse_models: Dict[str, dminv.InverseModel] = {}
executors: Dict[str, dminv.LBFGSBInversionExecutor] = {}

# %%
case = "no_reg"
params[case] = dminv.AdjustableParameter(
    name=dminv.ParameterName.PERMEABILITY,
    lbounds=1e-6,
    ubounds=0.1,
    preconditioner=dminv.LogTransform(),
)

case = "gs"
params[case] = dminv.AdjustableParameter(
    name=dminv.ParameterName.PERMEABILITY,
    lbounds=1e-6,
    ubounds=0.1,
    preconditioner=dminv.LogTransform(),
    filters=[GaussianFilter(sigmas=2.5)],
)

case = "tka"
params[case] = dminv.AdjustableParameter(
    name=dminv.ParameterName.PERMEABILITY,
    lbounds=1e-6,
    ubounds=0.1,
    preconditioner=dminv.LogTransform(),
    regularizators=dminv.regularization.TikhonovRegularizator(
        dx, dy, preconditioner=dminv.LogTransform()
    ),
    reg_weight_update_strategy=dminv.regularization.AdaptiveUCRegweight(),
)

case = "gstka"
params[case] = dminv.AdjustableParameter(
    name=dminv.ParameterName.PERMEABILITY,
    lbounds=1e-6,
    ubounds=0.1,
    preconditioner=dminv.LogTransform(),
    filters=[GaussianFilter(sigmas=2.5)],
    regularizators=dminv.regularization.TikhonovRegularizator(
        dx, dy, preconditioner=dminv.LogTransform()
    ),
    reg_weight_update_strategy=dminv.regularization.AdaptiveUCRegweight(),
)

case = "tva"
params[case] = dminv.AdjustableParameter(
    name=dminv.ParameterName.PERMEABILITY,
    lbounds=1e-6,
    ubounds=0.1,
    preconditioner=dminv.LogTransform(),
    regularizators=dminv.regularization.TVRegularizator(
        dx, dy, preconditioner=dminv.LogTransform()
    ),
    reg_weight_update_strategy=dminv.regularization.AdaptiveUCRegweight(),
)

case = "sg"
params[case] = dminv.AdjustableParameter(
    name=dminv.ParameterName.PERMEABILITY,
    lbounds=1e-6,
    ubounds=0.1,
    preconditioner=dminv.SigmoidRescalerBounded(
        old_lbound=1e-9, old_ubound=1e-4, rate=2.0, is_log10=True
    ),
)

case = "sgtva"
params[case] = dminv.AdjustableParameter(
    name=dminv.ParameterName.PERMEABILITY,
    lbounds=1e-6,
    ubounds=0.1,
    preconditioner=dminv.SigmoidRescalerBounded(
        old_lbound=1e-6, old_ubound=1e-2, rate=2.0, is_log10=True
    ),
    regularizators=dminv.regularization.TVRegularizator(
        dx, dy, preconditioner=dminv.LogTransform()
    ),
    reg_weight_update_strategy=dminv.regularization.AdaptiveUCRegweight(),
)
# Antoine 24/07/2024: this is not necessary in the end.
params.pop(case)

# %% [markdown]
# Add three cases with SPDE:
# - "spde_prior": "Bayesian (SPDE prior)",
# - "spde_prior_adaptive": "Adaptive Bayesian (SPDE prior)",
# - "gdncs": "Gradual deformation + SPDE",

# %%
def get_exp_kernel_precision_matrix() -> csc_array:
    param = 0.5  # alpha for exponential kernel
    sill = (
        1.0
    ) ** 2  # variance corrected (ask nicolas why the variance is not correct)
    nugget = 0.0  # no nugget effect

    # We use gstlearn
    model_spde = gl.Model.createFromParam(
        gl.ECov.BESSEL_K, param=param, ranges=[250.0, 250.0], sill=sill
    )
    model_spde.addCovFromParam(gl.ECov.NUGGET, sill=nugget)
    grid_spde = gl.DbGrid.create([nx, ny], [dx, dy])
    mesh_spde = gl.MeshETurbo(grid_spde)
    exp_spde = gl.SPDE(
        model=model_spde,
        domain=grid_spde,
        data=None,
        calcul=gl.ESPDECalcMode.SIMUNONCOND,
        mesh=mesh_spde,
    )
    return exp_spde.getPrecisionOpCs().getQToTriplet().toTL()


# Buidl the precision matrix
Q = get_exp_kernel_precision_matrix()

# Decompose with cholesky
cholQ = sparse_cholesky(Q)


# Create a preconditioner with the gradual deformation method couple with
# Non-conditional SPDE simulations
ne = 100
gdpncs = dminv.GDPNCS(
    ne,
    Q_nc=Q,
    estimated_mean=float(0.0),
    cholQ_nc=cholQ,
    random_state=2024,
    is_update_mean=True,  # update the mean as well
)

# We apply three successive preconditionning:
# 1) A first one to convert m/s to m/d
# 2) A second one to log
# 3) A third one to convert ppm to white noise linear combinaison weights through the
# gradual deformation + SPDE approach
pcd_gdpncs = dminv.ChainedTransforms(
    [
        dminv.LinearTransform(slope=1.0 * 3600.0 * 24.0, y_intercept=0.0),
        dminv.LogTransform(),
        gdpncs,
    ]
)

# Generate an initial permeability field
estimate_perm = pcd_gdpncs.backtransform(
    np.hstack((gdpncs.theta, gdpncs.estimated_mean))
).reshape(nx, ny, order="F")

# %%
plotter = ngp.NestedGridPlotter(
    plt.figure(constrained_layout=True, figsize=(15, 5)),
    builder=ngp.SubplotsMosaicBuilder(
        mosaic=[["ax1-1", "ax1-2"]], sharey=True, sharex=True
    ),
)

# Plot the permeability
ngp.multi_imshow(
    axes=[plotter.get_axis("ax1-1")],
    fig=plotter.fig,
    data={
        "SPDE initial estimate logK": permeability_to_log_transmitivity(estimate_perm)
    },
    cbar_title="Transmitivity field (logK), $ln[m2/d]$",
    imshow_kwargs={"cmap": plt.get_cmap("jet"), "extent": [0.0, nx * dx, 0.0, ny * dy]},
    xlabel="X [m]",
    ylabel="Y [m]",
)

ngp.multi_imshow(
    axes=[plotter.get_axis("ax1-2")],
    fig=plotter.fig,
    data={"SPDE initial estimate": estimate_perm},
    cbar_title="Permeability field $[m/s]$",
    imshow_kwargs={
        "cmap": plt.get_cmap("jet"),
        "norm": LogNorm(vmin=1e-5, vmax=1e-3),
        "extent": [0.0, nx * dx, 0.0, ny * dy],
    },
    xlabel="X [m]",
    ylabel="Y [m]",
)

fname = fig_save_path.joinpath("GDPNCS_initial_perm")
for format in ["png", "pdf"]:
    plotter.savefig((fig_save_path.joinpath(f"{fname}.{format}")), format=format)

# %%
case = "spde_prior"
pcd = dminv.ChainedTransforms(
    [
        dminv.LinearTransform(slope=1.0 * 3600.0 * 24.0, y_intercept=0.0),
        dminv.LogTransform(),
    ]
)
params[case] = dminv.AdjustableParameter(
    name=dminv.ParameterName.PERMEABILITY,
    lbounds=1e-6,
    ubounds=0.1,
    preconditioner=pcd,
    regularizators=dminv.regularization.GeostatisticalRegularizator(
        cov_m=dminv.regularization.SparseInvCovarianceMatrix(Q),
        prior=dminv.regularization.MeanPriorTerm(),
        preconditioner=pcd,
    ),
    reg_weight_update_strategy=dminv.regularization.ConstantRegWeight(1.0),
)

case = "spde_prior_adaptive"
params[case] = copy.copy(params["spde_prior"])
params[case].reg_weight_update_strategy = dminv.regularization.AdaptiveUCRegweight(1.0)

# %%
case = "gdncs"
params[case] = dminv.AdjustableParameter(
    name=dminv.ParameterName.PERMEABILITY,
    lbounds=1e-6,
    ubounds=0.1,
    preconditioner=pcd_gdpncs,
)

# %%
params
# Out:
# {'no_reg': <pyrtid.inverse.params.AdjustableParameter at 0x7322c0cb89a0>,
#  'gs': <pyrtid.inverse.params.AdjustableParameter at 0x7322dd24e3e0>,
#  'tka': <pyrtid.inverse.params.AdjustableParameter at 0x7322c0cb8360>,
#  'gstka': <pyrtid.inverse.params.AdjustableParameter at 0x7322c0cb8860>,
#  'tva': <pyrtid.inverse.params.AdjustableParameter at 0x7322c0b37b00>,
#  'sg': <pyrtid.inverse.params.AdjustableParameter at 0x7322c0b37e20>,
#  'spde_prior': <pyrtid.inverse.params.AdjustableParameter at 0x7322c0d42020>,
#  'spde_prior_adaptive': <pyrtid.inverse.params.AdjustableParameter at 0x7322c2397740>,
#  'gdncs': <pyrtid.inverse.params.AdjustableParameter at 0x7322bf1b09a0>}

# %%
np.mean(estimate_perm)
# Out:
# 1.305137392834844e-05

# %% [markdown]
# ## Run inversions

# %% [markdown]
# - Function to create the inversion executor for a given case

# %%
def create_executor(_case: str) -> None:
    adjusted_models[_case] = copy.deepcopy(model_estimate)
    inverse_models[_case] = dminv.InverseModel(params[_case], observables)
    executors[_case] = dminv.LBFGSBInversionExecutor(
        adjusted_models[_case], inverse_models[_case], solver_config
    )


for case in params.keys():
    create_executor(case)

# %% [markdown]
# - Function to compute the observations LS loss function and regularization term (should be zero)

# %%
def get_loss_ls(_case) -> float:
    return executors[case].eval_scaled_loss(
        params[case].preconditioner(params[case].values), is_save_state=False
    )


# Test with the first case
first_case = list(params.keys())[0]
loss_ls = get_loss_ls(first_case)
assert loss_ls == 1.0  # should be one because of the scaling
# Out:
# INFO:root:- Running forward model # 1
# INFO:root:- Run # 1 over
# INFO:root:Loss (obs fit)        = 10520769.071057878
# INFO:root:Loss (obs fit) / Nobs = 12092.838012710205
# INFO:root:Loss (regularization) = 0.0
# INFO:root:Scaling factor        = 9.505008552568188e-08
# INFO:root:Loss (scaled)         = 1.0

# %% [markdown]
# - Compute the LS loss gradient with respect to the parameters

# %%
# Test with the first case as well
grad_ls = executors[case].eval_scaled_loss_gradient(
    params[first_case].preconditioner(params[first_case].values),
    is_verbose=True,
    is_save_state=False,
)
# Out:
# INFO:root:- Running gradient # 1
# INFO:root:- Gradient eval # 1 over

# %% [markdown]
# - Plot the adjoint sources and head

# %%
# plotter = ngp.AnimatedPlotter(
#     plt.figure(constrained_layout=True, figsize=(15, 5)},
#     builder=ngp.SubplotsMosaicBuilder((
#         "fig0": dict(mosaic=[["ax1-1", "ax1-2"]], sharey=True, sharex=True)
#     },
# )

# nb_frames = grid_obs.shape[0]
# plotter.animated_multi_imshow(
#     ax_names=["ax1-1"],
#     data={
#         "Adjoint sources": executor.adj_model.a_fl_model.a_head_sources.toarray().reshape(
#             (nx, ny, -1), order="F"
#         ),
#     },
#     cbar_title="Head error [m]",
#     nb_frames=nb_frames + 1,
#     imshow_kwargs={"extent": [0.0, nx * dx, 0.0, ny * dy]},
#     xlabel="X [m]",
#     ylabel="Y [m]",
# )

# plotter.animated_multi_imshow(
#     ax_names=["ax1-2"],
#     data={
#         "Adjoint head": executor.adj_model.a_fl_model.a_head,
#     },
#     cbar_title="Adjoit head",
#     nb_frames=nb_frames,
#     imshow_kwargs={"extent": [0.0, nx * dx, 0.0, ny * dy]},
#     xlabel="X [m]",
#     ylabel="Y [m]",
# )

# plotter.fig.suptitle("Adjoint sources and head", fontweight="bold")

# plotter.close()
# plotter.animate(nb_frames=nb_frames)

# # Save the animation locally on the computer
# fname_html = fig_save_path.joinpath(
#     "head_field_reference_vs_initial_guess_animated.html"
# )
# writer = HTMLWriter(fps=5, embed_frames=True)
# writer.frame_format = "svg"  # Ensure svg format
# plotter.animation.save(str(fname_html), writer=writer)

# # Display the animation
# HTML(fname_html.read_text())

# %%
# plt.imshow(
#     grad_ls.reshape(nx, ny, order="F").T, origin="lower", cmap="bwr", aspect="equal"
# )
# plt.colorbar()

# %%
res_list: Dict[str, Any] = {}

# %%
res_list[first_case] = executors[first_case].run()
logging.info(res_list[first_case])
# Out:
# INFO:root:============================= Inversion Parameters =============================
# INFO:root:Method                                            : L-BFGS-B (PyRTID)
# INFO:root:
# INFO:root:Number of adjusted parameters                     : 1
# INFO:root:Number of unknowns (adjusted values)              : 7500
# INFO:root:Number of observables                             : 30
# INFO:root:Number of observation data points (values)        : 870
# INFO:root:================================================================================
# INFO:root:- Running forward model # 1
# INFO:root:- Run # 1 over
# INFO:root:Loss (obs fit)        = 723563.8257920151
# INFO:root:Loss (obs fit) / Nobs = 831.6825583816266
# INFO:root:Loss (regularization) = 0.0
# INFO:root:Scaling factor        = 1.38204808526103e-06
# INFO:root:Loss (scaled)         = 0.9999999999999999
#
# INFO:root:- Running gradient # 1
# INFO:root:- Gradient eval # 1 over
#
# INFO:root:- Running forward model # 2
# INFO:root:- Run # 2 over
# INFO:root:Loss (obs fit)        = 722851.6160476662
# INFO:root:Loss (obs fit) / Nobs = 830.8639264915703
# INFO:root:Loss (regularization) = 0.0
# INFO:root:Scaling factor        = 1.38204808526103e-06
# INFO:root:Loss (scaled)         = 0.9990156918865183
#
# INFO:root:- Running gradient # 2
# INFO:root:- Gradient eval # 2 over
#
# INFO:root:- Running forward model # 3
# INFO:root:- Run # 3 over
# INFO:root:Loss (obs fit)        = 230077.65561340353
# INFO:root:Loss (obs fit) / Nobs = 264.4570754177052
# INFO:root:Loss (regularization) = 0.0
# INFO:root:Scaling factor        = 1.38204808526103e-06
# INFO:root:Loss (scaled)         = 0.31797838340185103
#
# INFO:root:- Running gradient # 3
# INFO:root:- Gradient eval # 3 over
#
# INFO:root:  message: STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
#   success: True
#    status: 1
#       fun: 0.31797838340185103
#         x: [-1.004e+01 -9.860e+00 ... -9.767e+00 -9.936e+00]
#       nit: 2
#       jac: [-9.778e-05 -1.601e-04 ... -2.170e-04 -1.305e-04]
#      nfev: 3
#      njev: 3
#  hess_inv: <7500x7500 LbfgsInvHessProduct with dtype=float64>

# %%
import matplotlib.ticker as ticker


def plot_inv_animation_case(_case: str) -> HTML:
    plotter = ngp.AnimatedPlotter(
        plt.figure(constrained_layout=True, figsize=(12.5, 8.0)),
        builder=ngp.SubfigsBuilder(nrows=2, ncols=2),
    )

    # 1 frame per solver iteration
    nb_frames: int = inverse_models[_case].nb_f_calls

    aligned_adjoint_gradients = get_gridded_archived_gradients(
        params[_case], is_adjoint=True
    )

    # 1) Gradient evolution
    plotter.animated_multi_imshow(
        ax_names=["subfig_1_ax1-1"],
        data={
            "Gradient": aligned_adjoint_gradients,
        },
        # cbar_title="Adjoit head",
        nb_frames=nb_frames,
        imshow_kwargs={
            "extent": [0.0, nx * dx, 0.0, ny * dy],
            "aspect": "equal",
            "norm": SymLogNorm(linthresh=0.5),
        },
        xlabel="X [m]",
        ylabel="Y [m]",
    )
    plotter.get_axis("subfig_1_ax1-1").set_title("Gradient", fontweight="bold")

    # 2) Parameter evolution
    plotter.animated_multi_imshow(
        ax_names=["subfig_2_ax1-1"],
        data={
            "Permeability": np.transpose(
                np.array(params[_case].archived_values), axes=[1, 2, 0]
            ),
        },
        nb_frames=nb_frames,
        imshow_kwargs={
            "extent": [0.0, nx * dx, 0.0, ny * dy],
            "aspect": "equal",
            "norm": LogNorm(vmin=1e-5, vmax=1e-3),
            "cmap": plt.get_cmap("jet"),
        },
        cbar_title="Permeability field $[m/s]$",
        xlabel="X [m]",
        ylabel="Y [m]",
    )

    # 3) Objective function
    vals = inverse_models[_case].loss_scaled_history
    obj_fun_vals = np.full((len(vals), nb_frames), fill_value=np.nan)
    for i in range(len(vals)):
        obj_fun_vals[: i + 1, i] = vals[: i + 1]

    plotter.animated_multi_plot(
        ax_name="subfig_3_ax1-1",
        data={
            "Obj fun": {
                "x": np.arange(len(obj_fun_vals)) + 1,
                "y": obj_fun_vals,
                "kwargs": {"c": "r", "linestyle": "--"},
            },
        },
        nb_frames=nb_frames,
        title="Objective function",
        xlabel="Nb. function eval#",
    )
    ax = plotter.ax_dict["subfig_3_ax1-1"]
    ax.set_yscale("log")
    # Remove non-integer ticks:
    ax.set_xticks([tick for tick in ax.get_xticks() if tick % 1 == 0])

    # 4) Observation vs predicted values
    head_obs = dminv.get_observables_values_as_1d_vector(observables)
    head_pred = np.array(executors[_case].inv_model.list_d_pred).T

    pyrtid.plot.plot_observed_vs_simulated(
        plotter.ax_dict["subfig_4_ax1-1"],
        obs_vector=head_obs,
        pred_vector_initial=head_pred[:, 0],
        units="m",
    )
    plotter.animated_multi_plot(
        ax_name="subfig_4_ax1-1",
        data={
            "current": {
                "x": head_obs,
                "y": head_pred,
                "kwargs": {"c": "b", "linestyle": "none", "marker": ".", "zorder": 2},
            },
        },
        nb_frames=nb_frames,
    )
    plotter.get_axis("subfig_4_ax1-1").legend(loc="upper left")

    plotter.close()
    plotter.animate(nb_frames=nb_frames)
    # Save the animation locally on the computer
    fname_html = fig_save_path.joinpath(f"m_j_g_animation_{_case}.html")
    writer = HTMLWriter(fps=2, embed_frames=True)
    writer.frame_format = "svg"  # Ensure svg format
    plotter.animation.save(str(fname_html), writer=writer)

    # Extract the svg from the html file (for animation in Latex)
    ngp.extract_frames_from_embedded_html_animation(fname_html)

    # Display the animation
    return HTML(fname_html.read_text())


plot_inv_animation_case(first_case)
# Out:
# INFO:matplotlib.animation:Animation.save using <class 'matplotlib.animation.HTMLWriter'>
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img561e0bdf27234456887121d3add01997">
#   <div class="anim-controls">
#     <input id="_anim_slider561e0bdf27234456887121d3add01997" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim561e0bdf27234456887121d3add01997.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim561e0bdf27234456887121d3add01997.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim561e0bdf27234456887121d3add01997.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim561e0bdf27234456887121d3add01997.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim561e0bdf27234456887121d3add01997.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim561e0bdf27234456887121d3add01997.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim561e0bdf27234456887121d3add01997.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim561e0bdf27234456887121d3add01997.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim561e0bdf27234456887121d3add01997.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim561e0bdf27234456887121d3add01997.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select561e0bdf27234456887121d3add01997"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_561e0bdf27234456887121d3add01997"
#              >
#       <label for="_anim_radio1_561e0bdf27234456887121d3add01997">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_561e0bdf27234456887121d3add01997"
#              checked>
#       <label for="_anim_radio2_561e0bdf27234456887121d3add01997">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_561e0bdf27234456887121d3add01997"
#              >
#       <label for="_anim_radio3_561e0bdf27234456887121d3add01997">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img561e0bdf27234456887121d3add01997";
#     var slider_id = "_anim_slider561e0bdf27234456887121d3add01997";
#     var loop_select_id = "_anim_loop_select561e0bdf27234456887121d3add01997";
#     var frames = new Array(3);
#
#   frames[0] = "...\
# RE9DVFlQRSBzdmcgUFVCTElDICItLy9XM0MvL0RURCBTVkcgMS4xLy9FTiIKICAiaHR0cDovL3d3\
# dy53My5vcmcvR3JhcGhpY3

# %% [markdown]
# - Repeat for all other cases

# %%
for case in list(params.keys())[1:]:
    logger.info(f"Running case = {case}\n")
    res_list[case] = executors[case].run()
    # plot_inv_animation_case(case)
# Out:
# INFO:root:Running case = gs
#
# INFO:root:============================= Inversion Parameters =============================
# INFO:root:Method                                            : L-BFGS-B (PyRTID)
# INFO:root:
# INFO:root:Number of adjusted parameters                     : 1
# INFO:root:Number of unknowns (adjusted values)              : 7500
# INFO:root:Number of observables                             : 30
# INFO:root:Number of observation data points (values)        : 870
# INFO:root:================================================================================
# INFO:root:- Running forward model # 1
# INFO:root:- Run # 1 over
# INFO:root:Loss (obs fit)        = 723563.8257920151
# INFO:root:Loss (obs fit) / Nobs = 831.6825583816266
# INFO:root:Loss (regularization) = 0.0
# INFO:root:Scaling factor        = 1.38204808526103e-06
# INFO:root:Loss (scaled)         = 0.9999999999999999
#
# INFO:root:- Running gradient # 1
# INFO:root:- Gradient eval # 1 over
#
# INFO:root:- Running forward model # 2
# INFO:root:- Run # 2 over
# INFO:root:Loss (obs fit)        = 722867.8940867977
# INFO:root:Loss (obs fit) / Nobs = 830.8826368813767
# INFO:root:Loss (regularization) = 0.0
# INFO:root:Scaling factor        = 1.38204808526103e-06
# INFO:root:Loss (scaled)         = 0.9990381889193318
#
# INFO:root:- Running gradient # 2
# INFO:root:- Gradient eval # 2 over
#
# INFO:root:- Running forward model # 3
# INFO:root:- Run # 3 over
# INFO:root:Loss (obs fit)        = 230108.7804805383
# INFO:root:Loss (obs fit) / Nobs = 264.49285112705553
# INFO:root:Loss (regularization) = 0.0
# INFO:root:Scaling factor        = 1.38204808526103e-06
# INFO:root:Loss (scaled)         = 0.3180213994648786
#
# INFO:root:- Running gradient # 3
# INFO:root:- Gradient eval # 3 over
#
# INFO:root:Running case = tka
#
# INFO:root:============================= Inversion Parameters =============================
# INFO:root:Method                                            : L-BFGS-B (PyRTID)
# INFO:root:
# INFO:root:Number of adjusted parameters                     : 1
# INFO:root:Number of unknowns (adjusted values)              : 7500
# INFO:root:Number of observables                             : 30
# INFO:root:Number of observation data points (values)        : 870
# INFO:root:================================================================================
# INFO:root:- Running forward model # 1
# INFO:root:- Run # 1 over
# INFO:root:Loss (obs fit)        = 723563.8257920151
# INFO:root:Loss (obs fit) / Nobs = 831.6825583816266
# INFO:root:Loss (regularization) = 0.0
# INFO:root:Scaling factor        = 1.38204808526103e-06
# INFO:root:Loss (scaled)         = 0.9999999999999999
#
# INFO:root:- Running gradient # 1
# INFO:root:- Gradient eval # 1 over
#
# INFO:root:- Running forward model # 2
# INFO:root:- Run # 2 over
# INFO:root:Loss (obs fit)        = 722851.6160476662
# INFO:root:Loss (obs fit) / Nobs = 830.8639264915703
# INFO:root:Loss (regularization) = 1.6583273916390745e-07
# INFO:root:Scaling factor        = 1.38204808526103e-06
# INFO:root:Loss (scaled)         = 0.9990156918867474
#
# INFO:root:- Running gradient # 2
# INFO:root:- Gradient eval # 2 over
#
# INFO:root:- Updating regularization weights # 1
# INFO:root:Old reg weight (permeability)   = 1.0
# INFO:root:New reg weight (permeability)   = 572830282.1228365
# INFO:root:New loss regularization   = 94.99401476046386
# INFO:root:New loss (scaled)         = 0.9991469781827292
#
# INFO:root:- Updating regularization weights # 1 over
# INFO:root:- Running forward model # 3
# INFO:root:- Run # 3 over
# INFO:root:Loss (obs fit)        = 718291.9242012443
# INFO:root:Loss (obs fit) / Nobs = 825.6229013807405
# INFO:root:Loss (regularization) = 1887.8417726763141
# INFO:root:Scaling factor        = 1.38204808526103e-06
# INFO:root:Loss (scaled)         = 0.9953230666079936
#
# INFO:root:- Running gradient # 3
# INFO:root:- Gradient eval # 3 over
#
# INFO:root:- Updating regularization weights # 2
# INFO:root:Old reg weight (permeability)   = 572830282.1228365
# INFO:root:New reg weight (permeability)   = 116615037.95253667
# INFO:root:New loss regularization   = 384.3210578064793
# INFO:root:New loss (scaled)         = 0.9932451286828575
#
# INFO:root:- Updating regularization weights # 2 over
# INFO:root:Running case = gstka
#
# INFO:root:============================= Inversion Parameters =============================
# INFO:root:Method                                            : L-BFGS-B (PyRTID)
# INFO:root:
# INFO:root:Number of adjusted parameters                     : 1
# INFO:root:Number of unknowns (adjusted values)              : 7500
# INFO:root:Number of observables                             : 30
# INFO:root:Number of observation data points (values)        : 870
# INFO:root:================================================================================
# INFO:root:- Running forward model # 1
# INFO:root:- Run # 1 over
# INFO:root:Loss (obs fit)        = 723563.8257920151
# INFO:root:Loss (obs fit) / Nobs = 831.6825583816266
# INFO:root:Loss (regularization) = 0.0
# INFO:root:Scaling factor        = 1.38204808526103e-06
# INFO:root:Loss (scaled)         = 0.9999999999999999
#
# INFO:root:- Running gradient # 1
# INFO:root:- Gradient eval # 1 over
#
# INFO:root:- Running forward model # 2
# INFO:root:- Run # 2 over
# INFO:root:Loss (obs fit)        = 722867.8940867977
# INFO:root:Loss (obs fit) / Nobs = 830.8826368813767
# INFO:root:Loss (regularization) = 5.7206604293519975e-09
# INFO:root:Scaling factor        = 1.38204808526103e-06
# INFO:root:Loss (scaled)         = 0.9990381889193397
#
# INFO:root:- Running gradient # 2
# INFO:root:- Gradient eval # 2 over
#
# INFO:root:- Updating regularization weights # 1
# INFO:root:Old reg weight (permeability)   = 1.0
# INFO:root:New reg weight (permeability)   = 4716509694.799907
# INFO:root:New loss regularization   = 26.981550375696894
# INFO:root:New loss (scaled)         = 0.999075478719366
#
# INFO:root:- Updating regularization weights # 1 over
# INFO:root:- Running forward model # 3
# INFO:root:- Run # 3 over
# INFO:root:Loss (obs fit)        = 706268.0485786309
# INFO:root:Loss (obs fit) / Nobs = 811.8023546880816
# INFO:root:Loss (regularization) = 16485.381919956784
# INFO:root:Scaling factor        = 1.38204808526103e-06
# INFO:root:Loss (scaled)         = 0.9988799947364141
#
# INFO:root:- Running gradient # 3
# INFO:root:- Gradient eval # 3 over
#
# INFO:root:- Running forward model # 4
# INFO:root:- Run # 4 over
# INFO:root:Loss (obs fit)        = 714450.7262674702
# INFO:root:Loss (obs fit) / Nobs = 821.2077313419197
# INFO:root:Loss (regularization) = 4369.516720773954
# INFO:root:Scaling factor        = 1.38204808526103e-06
# INFO:root:Loss (scaled)         = 0.9934441404687712
#
# INFO:root:- Running gradient # 4
# INFO:root:- Gradient eval # 4 over
#
# INFO:root:- Updating regularization weights # 2
# INFO:root:Old reg weight (permeability)   = 4716509694.799907
# INFO:root:New reg weight (permeability)   = 259936015.7159295
# INFO:root:New loss regularization   = 240.81255854395107
# INFO:root:New loss (scaled)         = 0.987738072786752
#
# INFO:root:- Updating regularization weights # 2 over
# INFO:root:Running case = tva
#
# INFO:root:============================= Inversion Parameters =============================
# INFO:root:Method                                            : L-BFGS-B (PyRTID)
# INFO:root:
# INFO:root:Number of adjusted parameters                     : 1
# INFO:root:Number of unknowns (adjusted values)              : 7500
# INFO:root:Number of observables                             : 30
# INFO:root:Number of observation data points (values)        : 870
# INFO:root:================================================================================
# INFO:root:- Running forward model # 1
# INFO:root:- Run # 1 over
# INFO:root:Loss (obs fit)        = 723563.8257920151
# INFO:root:Loss (obs fit) / Nobs = 831.6825583816266
# INFO:root:Loss (regularization) = 7.500000000000001e-07
# INFO:root:Scaling factor        = 1.3820480852595977e-06
# INFO:root:Loss (scaled)         = 1.0
#
# INFO:root:- Running gradient # 1
# INFO:root:- Gradient eval # 1 over
#
# INFO:root:- Running forward model # 2
# INFO:root:- Run # 2 over
# INFO:root:Loss (obs fit)        = 722851.6160479018
# INFO:root:Loss (obs fit) / Nobs = 830.8639264918412
# INFO:root:Loss (regularization) = 0.021635352336766493
# INFO:root:Scaling factor        = 1.3820480852595977e-06
# INFO:root:Loss (scaled)         = 0.9990157217869058
#
# INFO:root:- Running gradient # 2
# INFO:root:- Gradient eval # 2 over
#
# INFO:root:- Updating regularization weights # 1
# INFO:root:Old reg weight (permeability)   = 1.0
# INFO:root:New reg weight (permeability)   = 3770.2288790813677
# INFO:root:New loss regularization   = 81.57023018917758
# INFO:root:New loss (scaled)         = 0.9991284258662556
#
# INFO:root:- Updating regularization weights # 1 over
# INFO:root:- Running forward model # 3
# INFO:root:- Run # 3 over
# INFO:root:Loss (obs fit)        = 711434.676412525
# INFO:root:Loss (obs fit) / Nobs = 817.7410073707184
# INFO:root:Loss (regularization) = 1299.119835278624
# INFO:root:Scaling factor        = 1.3820480852595977e-06
# INFO:root:Loss (scaled)         = 0.9850323784040812
#
# INFO:root:- Running gradient # 3
# INFO:root:- Gradient eval # 3 over
#
# INFO:root:- Running forward model # 4
# INFO:root:- Run # 4 over
# INFO:root:Loss (obs fit)        = 667430.2597563725
# INFO:root:Loss (obs fit) / Nobs = 767.161218110773
# INFO:root:Loss (regularization) = 6225.428615527784
# INFO:root:Scaling factor        = 1.3820480852595977e-06
# INFO:root:Loss (scaled)         = 0.9310245542386211
#
# INFO:root:- Running gradient # 4
# INFO:root:- Gradient eval # 4 over
#
# INFO:root:- Updating regularization weights # 2
# INFO:root:Old reg weight (permeability)   = 3770.2288790813677
# INFO:root:New reg weight (permeability)   = 1862.9268506145727
# INFO:root:New loss regularization   = 3076.078003857633
# INFO:root:New loss (scaled)         = 0.9266720002559512
#
# INFO:root:- Updating regularization weights # 2 over
# INFO:root:Running case = sg
#
# INFO:root:============================= Inversion Parameters =============================
# INFO:root:Method                                            : L-BFGS-B (PyRTID)
# INFO:root:
# INFO:root:Number of adjusted parameters                     : 1
# INFO:root:Number of unknowns (adjusted values)              : 7500
# INFO:root:Number of observables                             : 30
# INFO:root:Number of observation data points (values)        : 870
# INFO:root:================================================================================
# INFO:root:- Running forward model # 1
# INFO:root:- Run # 1 over
# INFO:root:Loss (obs fit)        = 723563.8257837789
# INFO:root:Loss (obs fit) / Nobs = 831.6825583721596
# INFO:root:Loss (regularization) = 0.0
# INFO:root:Scaling factor        = 1.3820480852767616e-06
# INFO:root:Loss (scaled)         = 0.9999999999999999
#
# INFO:root:- Running gradient # 1
# INFO:root:- Gradient eval # 1 over
#
# INFO:root:- Running forward model # 2
# INFO:root:- Run # 2 over
# INFO:root:Loss (obs fit)        = 711361.8511782866
# INFO:root:Loss (obs fit) / Nobs = 817.6573002049271
# INFO:root:Loss (regularization) = 0.0
# INFO:root:Scaling factor        = 1.3820480852767616e-06
# INFO:root:Loss (scaled)         = 0.9831362843598836
#
# INFO:root:- Running gradient # 2
# INFO:root:- Gradient eval # 2 over
#
# INFO:root:- Running forward model # 3
# INFO:root:- Run # 3 over
# INFO:root:Loss (obs fit)        = 349687.50162121584
# INFO:root:Loss (obs fit) / Nobs = 401.93965703588026
# INFO:root:Loss (regularization) = 0.0
# INFO:root:Scaling factor        = 1.3820480852767616e-06
# INFO:root:Loss (scaled)         = 0.4832849420608158
#
# INFO:root:- Running gradient # 3
# INFO:root:- Gradient eval # 3 over
#
# INFO:root:Running case = spde_prior
#
# INFO:root:============================= Inversion Parameters =============================
# INFO:root:Method                                            : L-BFGS-B (PyRTID)
# INFO:root:
# INFO:root:Number of adjusted parameters                     : 1
# INFO:root:Number of unknowns (adjusted values)              : 7500
# INFO:root:Number of observables                             : 30
# INFO:root:Number of observation data points (values)        : 870
# INFO:root:================================================================================
# INFO:root:- Running forward model # 1
# INFO:root:- Run # 1 over
# INFO:root:Loss (obs fit)        = 723563.825778743
# INFO:root:Loss (obs fit) / Nobs = 831.6825583663713
# INFO:root:Loss (regularization) = 0.0
# INFO:root:Scaling factor        = 1.3820480852863805e-06
# INFO:root:Loss (scaled)         = 1.0
#
# INFO:root:- Running gradient # 1
# INFO:root:- Gradient eval # 1 over
#
# INFO:root:- Running forward model # 2
# INFO:root:- Run # 2 over
# INFO:root:Loss (obs fit)        = 722851.616046798
# INFO:root:Loss (obs fit) / Nobs = 830.8639264905723
# INFO:root:Loss (regularization) = 0.0007820704748720442
# INFO:root:Scaling factor        = 1.3820480852863805e-06
# INFO:root:Loss (scaled)         = 0.9990156929845019
#
# INFO:root:- Running gradient # 2
# INFO:root:- Gradient eval # 2 over
#
# INFO:root:- Running forward model # 3
# INFO:root:- Run # 3 over
# INFO:root:Loss (obs fit)        = 230120.61897408369
# INFO:root:Loss (obs fit) / Nobs = 264.50645859090076
# INFO:root:Loss (regularization) = 502.00304615804924
# INFO:root:Scaling factor        = 1.3820480852863805e-06
# INFO:root:Loss (scaled)         = 0.31873155318679974
#
# INFO:root:- Running gradient # 3
# INFO:root:- Gradient eval # 3 over
#
# INFO:root:Running case = spde_prior_adaptive
#
# INFO:root:============================= Inversion Parameters =============================
# INFO:root:Method                                            : L-BFGS-B (PyRTID)
# INFO:root:
# INFO:root:Number of adjusted parameters                     : 1
# INFO:root:Number of unknowns (adjusted values)              : 7500
# INFO:root:Number of observables                             : 30
# INFO:root:Number of observation data points (values)        : 870
# INFO:root:================================================================================
# INFO:root:- Running forward model # 1
# INFO:root:- Run # 1 over
# INFO:root:Loss (obs fit)        = 723563.825778743
# INFO:root:Loss (obs fit) / Nobs = 831.6825583663713
# INFO:root:Loss (regularization) = 0.0
# INFO:root:Scaling factor        = 1.3820480852863805e-06
# INFO:root:Loss (scaled)         = 1.0
#
# INFO:root:- Running gradient # 1
# INFO:root:- Gradient eval # 1 over
#
# INFO:root:- Running forward model # 2
# INFO:root:- Run # 2 over
# INFO:root:Loss (obs fit)        = 722851.616046798
# INFO:root:Loss (obs fit) / Nobs = 830.8639264905723
# INFO:root:Loss (regularization) = 0.0007820704748720442
# INFO:root:Scaling factor        = 1.3820480852863805e-06
# INFO:root:Loss (scaled)         = 0.9990156929845019
#
# INFO:root:- Running gradient # 2
# INFO:root:- Gradient eval # 2 over
#
# INFO:root:- Updating regularization weights # 1
# INFO:root:Old reg weight (permeability)   = 1.0
# INFO:root:New reg weight (permeability)   = 71220.42111236198
# INFO:root:New loss regularization   = 55.69938855993189
# INFO:root:New loss (scaled)         = 0.9990926711369538
#
# INFO:root:- Updating regularization weights # 1 over
# INFO:root:- Running forward model # 3
# INFO:root:- Run # 3 over
# INFO:root:Loss (obs fit)        = 714583.9602987077
# INFO:root:Loss (obs fit) / Nobs = 821.3608739065606
# INFO:root:Loss (regularization) = 3800.884611766947
# INFO:root:Scaling factor        = 1.3820480852863805e-06
# INFO:root:Loss (scaled)         = 0.9928423994072748
#
# INFO:root:- Running gradient # 3
# INFO:root:- Gradient eval # 3 over
#
# INFO:root:- Updating regularization weights # 2
# INFO:root:Old reg weight (permeability)   = 71220.42111236198
# INFO:root:New reg weight (permeability)   = 7316.773399790367
# INFO:root:New loss regularization   = 390.4808619310707
# INFO:root:New loss (scaled)         = 0.9881290574347608
#
# INFO:root:- Updating regularization weights # 2 over
# INFO:root:Running case = gdncs
#
# INFO:root:============================= Inversion Parameters =============================
# INFO:root:Method                                            : L-BFGS-B (PyRTID)
# INFO:root:
# INFO:root:Number of adjusted parameters                     : 1
# INFO:root:Number of unknowns (adjusted values)              : 100
# INFO:root:Number of observables                             : 30
# INFO:root:Number of observation data points (values)        : 870
# INFO:root:================================================================================
# INFO:root:- Running forward model # 1
# INFO:root:- Run # 1 over
# INFO:root:Loss (obs fit)        = 10520769.071058083
# INFO:root:Loss (obs fit) / Nobs = 12092.838012710441
# INFO:root:Loss (regularization) = 0.0
# INFO:root:Scaling factor        = 9.505008552568003e-08
# INFO:root:Loss (scaled)         = 1.0
#
# INFO:root:- Running gradient # 1
# INFO:root:- Gradient eval # 1 over
#
# INFO:root:- Running forward model # 2
# INFO:root:- Run # 2 over
# INFO:root:Loss (obs fit)        = 73632.95153091344
# INFO:root:Loss (obs fit) / Nobs = 84.6355764723143
# INFO:root:Loss (regularization) = 0.0
# INFO:root:Scaling factor        = 9.505008552568003e-08
# INFO:root:Loss (scaled)         = 0.006998818340521575
#
# INFO:root:- Running gradient # 2
# INFO:root:- Gradient eval # 2 over
#
# INFO:root:- Running forward model # 3
# INFO:root:- Run # 3 over
# INFO:root:Loss (obs fit)        = 70499.86754869657
# INFO:root:Loss (obs fit) / Nobs = 81.03433051574318
# INFO:root:Loss (regularization) = 0.0
# INFO:root:Scaling factor        = 9.505008552568003e-08
# INFO:root:Loss (scaled)         = 0.006701018440052722
#
# INFO:root:- Running gradient # 3
# INFO:root:- Gradient eval # 3 over
#
# INFO:root:- Running forward model # 4
# INFO:root:- Run # 4 over
# INFO:root:Loss (obs fit)        = 59132.74444514173
# INFO:root:Loss (obs fit) / Nobs = 67.96867177602498
# INFO:root:Loss (regularization) = 0.0
# INFO:root:Scaling factor        = 9.505008552568003e-08
# INFO:root:Loss (scaled)         = 0.005620572416878902
#
# INFO:root:- Running gradient # 4
# INFO:root:- Gradient eval # 4 over

# %%
params.keys()
# Out:
# dict_keys(['no_reg', 'gs', 'tka', 'gstka', 'tva', 'sg', 'spde_prior', 'spde_prior_adaptive', 'gdncs'])

# %%
labels = {
    "no_reg": "No regularization",
    "gs": "Gradient smoothing (GS)",
    "tka": "Adaptive Tikhonov",
    "gstka": "Adaptive Tikhonov + GS",
    "tva": "Adaptive TV",
    "sg": "Sigmoid rescaling",
    "spde_prior": "Bayesian (SPDE prior)",
    "spde_prior_adaptive": "Adaptive Bayesian (SPDE prior)",
    "gdncs": "Gradual deformation + SPDE",
}


data = {
    "Reference": perm_reference_2d,
    **{
        labels[case]: param.values.reshape(nx, ny, order="F")
        for case, param in params.items()
    },
}
nrows = int(len(data.values()) / 2) + len(data.values()) % 2

plotter = ngp.NestedGridPlotter(
    plt.figure(constrained_layout=True, figsize=(12.0, nrows * 4.2)),
    builder=ngp.SubplotsMosaicBuilder(
        mosaic=[[f"ax{i + 1}-{j + 1}" for j in range(2)] for i in range(nrows)],
        sharey=True,
        sharex=True,
    ),
)

# Plot the permeability
ngp.multi_imshow(
    axes=plotter.axes[: len(data.values())],
    fig=plotter.fig,
    data=data,
    cbar_title="Permeability field $[m/s]$",
    imshow_kwargs={
        "cmap": plt.get_cmap("jet"),
        "extent": [0.0, nx * dx, 0.0, ny * dy],
        "aspect": "equal",
        "norm": LogNorm(vmin=1e-5, vmax=1e-3),
    },
    xlabel="X [m]",
    ylabel="Y [m]",
    cbar_kwargs={"shrink": 0.4},
)

if len(data.values()) % 2 != 0:
    plotter.axes[-1].axis("off")

fname = fig_save_path.joinpath("bench_inversed_perm_with_reg")
for format in ["png", "pdf"]:
    plotter.savefig((fig_save_path.joinpath(f"{fname}.{format}")), format=format)

# %% [markdown]
# - Graphs of residuals

# %%
labels = {
    "no_reg": "No regularization",
    "gs": "Gradient smoothing (GS)",
    "tka": "Adaptive Tikhonov",
    "gstka": "Adaptive Tikhonov + GS",
    "tva": "Adaptive TV",
    "sg": "Sigmoid rescaling",
    "spde_prior": "Bayesian (SPDE prior)",
    "spde_prior_adaptive": "Adaptive Bayesian (SPDE prior)",
    "gdncs": "Gradual deformation + SPDE",
}

data = {
    labels[case]: param.values.reshape(nx, ny, order="F") - perm_reference_2d
    for case, param in params.items()
}
shift = 0
if len(data.values()) % 2 != 0:
    shift += 1

nrows = int(len(data.values()) / 2) + len(data.values()) % 2

plotter = ngp.NestedGridPlotter(
    plt.figure(constrained_layout=True, figsize=(12, nrows * 4.2)),
    builder=ngp.SubplotsMosaicBuilder(
        mosaic=[[f"ax{i + 1}-{j + 1}" for j in range(2)] for i in range(nrows)],
        sharey=True,
        sharex=True,
    ),
)

# Plot the permeability
ngp.multi_imshow(
    axes=plotter.axes[shift : len(data.values()) + shift],
    fig=plotter.fig,
    data=data,
    cbar_title="Permeability field $[m/s]$",
    imshow_kwargs={
        "cmap": plt.get_cmap("bwr"),
        "extent": [0.0, nx * dx, 0.0, ny * dy],
        "aspect": "equal",
        "norm": SymLogNorm(linthresh=0.5, vmin=-1e-3, vmax=1e-3),
    },
    xlabel="X [m]",
    ylabel="Y [m]",
    cbar_kwargs={"shrink": 0.4},
)

if len(data.values()) % 2 != 0:
    plotter.axes[0].axis("off")

fname = fig_save_path.joinpath("bench_inversed_perm_residuals")
for format in ["png", "pdf"]:
    plotter.savefig((fig_save_path.joinpath(f"{fname}.{format}")), format=format)

# %% [markdown]
# - Plot the objective functions

# %%
plotter = ngp.NestedGridPlotter(
    plt.figure(constrained_layout=True, figsize=(9, 10)),
    builder=ngp.SubplotsMosaicBuilder(
        mosaic=[["ax1-1"], ["ax1-2"]],
        sharey=True,
        sharex=True,
    ),
)

linestyles = [
    "solid",
    "solid",
    "solid",
    "solid",
    "dotted",
    "dashed",
    "dashdot",
    (5, (10, 3)),
    (5, (10, 3)),
]
markers = ["x", "o", "D", ">"]

# save obj functions
for i, case in enumerate(params.keys()):
    np.savetxt(
        fig_save_path.joinpath(f"loss_div_nobs_history_{case}.txt"),
        inverse_models[case].loss_scaled_history,
    )

# Ax 1.1
ax = plotter.axes[0]
for i, case in enumerate(params.keys()):
    if linestyles[i] == "solid":
        marker = markers[i]
    else:
        marker = None
    # we need to modify the scaling coefficient in the spde approach
    # ax.semilogy(inverse_models[case].loss_scaled_history /inverse_models[case].scaling_factor / executors[case].data_model.n_obs, label=labels[case], linestyle=linestyles[i], marker=marker, mec="k")
    y = (
        np.array(inverse_models[case].loss_ls_history)
        / executors[case].data_model.n_obs
    )
    ax.semilogy(
        np.arange(y.size) + 1,
        y,
        label=labels[case],
        linestyle=linestyles[i],
        marker=marker,
        mec="k",
    )
ax.set_ylabel(r"$\mathcal{J}_{\mathrm{LS}} / N_{\mathrm{obs}}$", fontweight="bold")

# Ax 1.2
ax = plotter.axes[1]
for i, case in enumerate(params.keys()):
    if linestyles[i] == "solid":
        marker = markers[i]
    else:
        marker = None
    # we need to modify the scaling coefficient in the spde approach
    y = (
        np.array(inverse_models[case].loss_scaled_history)
        / inverse_models[case].scaling_factor
        / executors[case].data_model.n_obs
    )

    ax.semilogy(
        np.arange(y.size) + 1,
        y,
        label=labels[case],
        linestyle=linestyles[i],
        marker=marker,
        mec="k",
    )
    # ax.semilogy(np.array(inverse_models[case].loss_ls_history) / executors[case].data_model.n_obs, label=labels[case], linestyle=linestyles[i], marker=marker, mec="k")
ax.set_xlabel(r"$\mathcal{J}$ evaluations", fontweight="bold")
ax.set_ylabel(r"$\mathcal{J}_{\mathrm{reg}} / N_{\mathrm{obs}}$", fontweight="bold")

# Remove non-integer ticks:
ax.set_xticks([tick for tick in ax.get_xticks() if tick % 1 == 0])

legend = plotter.add_fig_legend(ncols=3, bbox_y_shift=-0.05)
# ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
#           ncol=3, fancybox=True, shadow=True)

fname = fig_save_path.joinpath("bench_cost_fun")
for format in ["png", "pdf"]:
    plotter.savefig(
        fig_save_path.joinpath(f"{fname}.{format}"),
        format=format,
    )
# Out:
# INFO:matplotlib.mathtext:Substituting symbol J from STIXNonUnicode
# INFO:matplotlib.mathtext:Substituting symbol J from STIXNonUnicode
# INFO:matplotlib.mathtext:Substituting symbol J from STIXNonUnicode
# INFO:matplotlib.mathtext:Substituting symbol J from STIXNonUnicode
# INFO:matplotlib.mathtext:Substituting symbol J from STIXNonUnicode
# INFO:matplotlib.mathtext:Substituting symbol J from STIXNonUnicode
# INFO:matplotlib.mathtext:Substituting symbol J from STIXNonUnicode
# INFO:matplotlib.mathtext:Substituting symbol J from STIXNonUnicode
# INFO:matplotlib.mathtext:Substituting symbol J from STIXNonUnicode
# INFO:matplotlib.mathtext:Substituting symbol J from STIXNonUnicode
# INFO:matplotlib.mathtext:Substituting symbol J from STIXNonUnicode
# INFO:matplotlib.mathtext:Substituting symbol J from STIXNonUnicode
# INFO:matplotlib.mathtext:Substituting symbol J from STIXNonUnicode
# INFO:matplotlib.mathtext:Substituting symbol J from STIXNonUnicode
# INFO:matplotlib.mathtext:Substituting symbol J from STIXNonUnicode
# INFO:matplotlib.mathtext:Substituting symbol J from STIXNonUnicode
# INFO:matplotlib.mathtext:Substituting symbol J from STIXNonUnicode
# INFO:matplotlib.mathtext:Substituting symbol J from STIXNonUnicode
# INFO:matplotlib.mathtext:Substituting symbol J from STIXNonUnicode
# INFO:matplotlib.mathtext:Substituting symbol J from STIXNonUnicode
# INFO:matplotlib.mathtext:Substituting symbol J from STIXNonUnicode

# %% [markdown]
# Notes:
# - Toutes les courbes ont le même point de départ sauf l'approche avec des déformations graduelle car le point de départ n'est pas le même.
# - Sur la figure  1

# %% [markdown]
# ## Uncertainty quantification

# %% [markdown]
# - Quand il n'y a pas de tirage explicit, peut-etre propager par monte carlo avec 1000 tirage par exemple.
# - Regarder comment faire des tirages avec un Hessien inverse.

# %% [markdown]
# - Get the approximated hessian diagonal

# %%
hess_diag = extract_hess_inv_diag(res.hess_inv)
std = np.sqrt(hess_diag)

std_perm = np.abs(std) * np.abs(np.exp(res.x))

# %%
std
# Out:
# array([1.07544736, 1.17056653, 1.16595948, ..., 1.23538032, 1.23780015,
#        1.12726994])

# %%
import numpy as np
from scipy.optimize import LbfgsInvHessProduct
from scipy.sparse.linalg import LinearOperator, gmres
from pyrtid.inverse.preconditioner import NoTransform


from pyrtid.utils.types import NDArrayFloat
from scipy._lib._util import check_random_state  # To handle random_state
from pyrtid.utils import extract_hess_inv_diag

from typing import Optional, Union
from pyesmda.utils import get_ensemble_variance
from pyrtid.inverse.regularization.covariances import (
    CovarianceMatrix,
    EigenFactorizedCovarianceMatrix,
    eigen_factorize_cov_mat,
    CallBack,
)


def recover_matrix_from_operator(lin_op: LinearOperator, n: int) -> csc_array:
    """Recover matrix from linear operator using unit vectors (slow)."""
    return sp.sparse.vstack(
        [
            sp.sparse.csc_array(lin_op(unit_vector.toarray().T))
            for unit_vector in sp.sparse.eye(n).tocsc()
        ]
    )


class HessInvProductCovarianceMatrix(CovarianceMatrix):
    """Represents a Inverse Hessian Product (LBFGSB) covariance matrix."""

    def __init__(
        self,
        hess_inv: LbfgsInvHessProduct,
    ) -> None:
        """
        Initialize the instance.

        Parameters
        ----------
        hess_inv : LbfgsInvHessProduct
            Linear operator for the L-BFGS approximate inverse Hessian.
            This operator computes the product of a vector with the approximate inverse
            of the Hessian of the objective function, using the L-BFGS limited memory
            approximation to the inverse Hessian, accumulated during the optimization.
            We rely on the property that when L-BFGS has converged, the inverse Hessian
            is an approximation of the covariance matrix a posteriori.
        """
        self.hess_inv: LbfgsInvHessProduct = hess_inv
        super().__init__((hess_inv.shape[0], hess_inv.shape[0]))

    def _matvec(self, x: NDArrayFloat) -> NDArrayFloat:
        """Return the covariance matrix times the vector x."""
        return self.hess_inv(x)

    def _rmatvec(self, x: NDArrayFloat) -> NDArrayFloat:
        """Return the covariance matrix conjugate transpose times the vector x."""
        return self.hess_inv(x)

    def solve(
        self, b: NDArrayFloat, tol: float = 1e-12, maxiter: int = 1000
    ) -> NDArrayFloat:
        """Solve Ax = b, with A, the current covariance matrix instance."""
        residual = CallBack()
        x, info = gmres(
            self,
            b,
            tol=tol,
            maxiter=maxiter,
            callback=residual,
            M=None,
            atol=0.0,
            callback_type="legacy",
        )
        self.solvmatvecs += residual.itercount
        return x

    def get_diagonal(self) -> NDArrayFloat:
        """Return the diagonal entries of the matrix (variances)."""
        return extract_hess_inv_diag(self.hess_inv)

    def get_trace(self) -> float:
        """Return the trace (sum of the diagonal) of the covariance matrix."""
        return float(np.sum(self.get_diagonal()))


def get_sparse_eigen_factor_hess(
    hess_inv: LbfgsInvHessProduct,
    n_pc: int = 200,
    random_state: Optional[
        Union[int, np.random.Generator, np.random.RandomState]
    ] = None,
) -> csc_array:
    """
    Factorize as AA^T the linear operator for the L-BFGS approximate inverse Hessian.

    A is a sparse square matrix with size (n, n) with only the n_pc first columns
    non null.

    Parameters
    ----------
    hess_inv : LbfgsInvHessProduct
        Linear operator for the L-BFGS approximate inverse Hessian.
        This operator computes the product of a vector with the approximate inverse
        of the Hessian of the objective function, using the L-BFGS limited memory
        approximation to the inverse Hessian, accumulated during the optimization.
    n_pc : int
        Number of principal component kept (eigen vectors and values). The default
        is 200.
    random_state : Optional[Union[int, np.random.Generator, np.random.RandomState]]
        Pseudorandom number generator state used to generate resamples.
        If `random_state` is ``None`` (or `np.random`), the
        `numpy.random.RandomState` singleton is used.
        If `random_state` is an int, a new ``RandomState`` instance is used,
        seeded with `random_state`.
        If `random_state` is already a ``Generator`` or ``RandomState``
        instance then that instance is used. The default is None

    Returns
    -------
    csc_array
        Sparse square factor A with size (n, n) and only the n_pc first columns non
        null.
    """
    # 1) Perform the eigen factorization of the matrix -> UVU'
    eigen_mat = eigen_factorize_cov_mat(
        HessInvProductCovarianceMatrix(hess_inv), n_pc, random_state
    )
    # 2) Convert U sqrt(V) to a sparse format
    sp_mat = sp.sparse.lil_array(eigen_mat.eig_vects * np.sqrt(eigen_mat.eig_vals).T)
    # 3) Resize -> we now have a square matrix and indices are preserved
    sp_mat.resize(eigen_mat.shape)
    # 4) Convert to column format
    return sp_mat.tocsc()


def factorize_hess_inv(
    hess_inv: LbfgsInvHessProduct,
    size_threshold: int = 200,
    n_pc: int = 200,
    random_state: Optional[
        Union[int, np.random.Generator, np.random.RandomState]
    ] = None,
) -> Union[csc_array, NDArrayFloat]:
    """
    Factorize the linear operator for the L-BFGS approximate inverse Hessian as AA^T.

    A is a sparse square matrix with size (n, n) with only the n_pc first columns
    non null.

    Parameters
    ----------
    hess_inv : LbfgsInvHessProduct
        Linear operator for the L-BFGS approximate inverse Hessian.
        This operator computes the product of a vector with the approximate inverse
        of the Hessian of the objective function, using the L-BFGS limited memory
        approximation to the inverse Hessian, accumulated during the optimization.
    size_threshold : int, optional
        If the number of elements n in the diagonal of hess_inv of size (n, n) is
        smaller or equal to the `size_threshold`, then a cholesky factorization is used
        and the lower factor is returned. Above this number, n is considered to large
        to perform cholesky and an eigen factorization is used instead. By default 200.
    n_pc : int
        Number of principal component kept (eigen vectors and values). The default is
        200.
    random_state : Optional[Union[int, np.random.Generator, np.random.RandomState]]
        Pseudorandom number generator state used to generate resamples.
        If `random_state` is ``None`` (or `np.random`), the
        `numpy.random.RandomState` singleton is used.
        If `random_state` is an int, a new ``RandomState`` instance is used,
        seeded with `random_state`.
        If `random_state` is already a ``Generator`` or ``RandomState``
        instance then that instance is used. The default is None

    Returns
    -------
    Union[csc_array, NDArrayFloat]
        Lower cholesky factor or sparse square factor A with size (n, n) and only the
        n_pc first columns non null.
    """
    # if the matrix is reasonably small, se perform a cholesky factorization directly
    # on the dense matrix
    if hess_inv.shape[0] <= size_threshold:
        return sp.linalg.cholesky(hess_inv.todense(), lower=True)

    # Otherwise, we use an eigen factorization.
    # we cannot have n_pc equal or higher than the number of adjusted parameters
    return get_sparse_eigen_factor_hess(
        hess_inv, max(1, min(hess_inv.shape[0] - 1, n_pc)), random_state
    )


def sample_from_hess_inv_post_dist(
    param: dminv.AdjustableParameter,
    x_cond: NDArrayFloat,
    hess_inv: LbfgsInvHessProduct,
    n_samples: int = 100,
    n_pc: int = 200,
    size_threshold: int = 200,
    random_state: Optional[
        Union[int, np.random.Generator, np.random.RandomState]
    ] = None,
) -> NDArrayFloat:
    """
    Sample from the Quantify the uncertainty from the ibverse lbfgsb hessian.

    If no preconditioning, then simply solve N_s symstem to extract the diagonal.
    Otherwise, perform a sparse cholesky factorization and generated samples that are
    backconditioned to propagate the uncertainty.

    Parameters
    ----------
    random_state : Optional[Union[int, np.random.Generator, np.random.RandomState]]
        Pseudorandom number generator state used to generate resamples.
        If `random_state` is ``None`` (or `np.random`), the
        `numpy.random.RandomState` singleton is used.
        If `random_state` is an int, a new ``RandomState`` instance is used,
        seeded with `random_state`.
        If `random_state` is already a ``Generator`` or ``RandomState``
        instance then that instance is used. The default is None
    """
    # Comme il est très difficile d'obtenir des forme analytiques de propagation
    # d'incertitudes, on procède de la manière suivante:
    # 1) Nous factorisons l'inverse du hessien (la matrice de covariance a posteriori)
    # sous la forme AA'
    # 2) Cette factorization nous permet de génerer des réalizations equiprobables des
    # paramètres préconditionés a posteriori, sachant que le vecteurs valeurs est la
    # moyenne.
    # 3) On approxime la variance à partir de l'ensemble de réalizations
    # back-conditionnées. Ces réalisations peuvent être utilisées pour propager les
    # incertitudes à travers le solveur direct.
    # uncertainty propagation
    factor = factorize_hess_inv(hess_inv, size_threshold, n_pc, random_state)

    if random_state is not None:
        random_state = check_random_state(random_state)
    else:
        random_state = np.random.default_rng()

    # ens = np.zeros((param.size, n_samples))
    # for i in range(n_samples):
    # Random state for v0 vector used by eigsh and svds

    return np.vstack(
        [
            [
                param.preconditioner.backtransform(factor @ w + x_cond)
                for w in random_state.normal(size=(n_samples, hess_inv.shape[0]))
            ]
        ]
    ).T

    # if param.preconditioner is NoTransform():
    #     # No need to transform the parameters, the diagonal can be extracted directly
    #     # TODO: if the transformation is linear, same thing.
    #     return extract_hess_inv_diag(hess_inv)

# %%
ens_test = sample_from_hess_inv_post_dist(
    params[case],
    res_list[case].x,
    res_list[case].hess_inv,
    n_samples=1000,
    size_threshold=99,
    random_state=2024,
)
# Out:
# INFO:root:Eigendecomposition of Prior Covariance
# INFO:root:- time for eigendecomposition with k = 99 is 0 sec
# INFO:root:- 1st eigv : [5.61982764], 99-th eigv : [0.99791247], ratio: [0.17756994]

# %%
std_test = np.sqrt(get_ensemble_variance(ens_test))
plt.imshow(
    std_test.reshape(nx, ny, order="F").T,
    origin="lower",
    aspect="equal",
    cmap=plt.get_cmap("jet"),
    norm=LogNorm(),
)
plt.colorbar()

# %% [markdown]
# - Compute the uncertainty for all cases

# %%
post_var_dict = {}

for case in list(params.keys()):
    logger.info(f"Running case = {case}\n")
    post_var_dict[case] = get_ensemble_variance(
        sample_from_hess_inv_post_dist(
            params[case],
            res_list[case].x,
            res_list[case].hess_inv,
            n_samples=1000,
            size_threshold=200,
            random_state=2024,
        )
    )
# Out:
# INFO:root:Running case = no_reg
#
# INFO:root:Eigendecomposition of Prior Covariance
# INFO:root:- time for eigendecomposition with k = 200 is 17 sec
# INFO:root:- 1st eigv : [1744.06750666], 200-th eigv : [1.], ratio: [0.00057337]
# INFO:root:Running case = gs
#
# INFO:root:Eigendecomposition of Prior Covariance
# INFO:root:- time for eigendecomposition with k = 200 is 11 sec
# INFO:root:- 1st eigv : [1772.24753279], 200-th eigv : [1.], ratio: [0.00056426]
# INFO:root:Running case = tka
#
# INFO:root:Eigendecomposition of Prior Covariance
# INFO:root:- time for eigendecomposition with k = 200 is 20 sec
# INFO:root:- 1st eigv : [155.39562042], 200-th eigv : [1.], ratio: [0.00643519]
# INFO:root:Running case = gstka
#
# INFO:root:Eigendecomposition of Prior Covariance
# INFO:root:- time for eigendecomposition with k = 200 is 39 sec
# INFO:root:- 1st eigv : [325.49558452], 200-th eigv : [1.], ratio: [0.00307224]
# INFO:root:Running case = tva
#
# INFO:root:Eigendecomposition of Prior Covariance
# INFO:root:- time for eigendecomposition with k = 200 is 25 sec
# INFO:root:- 1st eigv : [885.93678769], 200-th eigv : [1.], ratio: [0.00112875]
# INFO:root:Running case = sg
#
# INFO:root:Eigendecomposition of Prior Covariance
# INFO:root:- time for eigendecomposition with k = 200 is 22 sec
# INFO:root:- 1st eigv : [80.88965628], 200-th eigv : [1.], ratio: [0.01236252]
# INFO:root:Running case = spde_prior
#
# INFO:root:Eigendecomposition of Prior Covariance
# INFO:root:- time for eigendecomposition with k = 200 is 12 sec
# INFO:root:- 1st eigv : [1744.03876969], 200-th eigv : [1.], ratio: [0.00057338]
# INFO:root:Running case = spde_prior_adaptive
#
# INFO:root:Eigendecomposition of Prior Covariance
# INFO:root:- time for eigendecomposition with k = 200 is 13 sec
# INFO:root:- 1st eigv : [342.07068434], 200-th eigv : [1.], ratio: [0.00292337]
# INFO:root:Running case = gdncs
#
# INFO:root:Eigendecomposition of Prior Covariance
# INFO:root:- time for eigendecomposition with k = 99 is 0 sec
# INFO:root:- 1st eigv : [5.61982764], 99-th eigv : [0.99791247], ratio: [0.17756994]

# %%
factor_95_pct_interval = (
    1.96  # number of sigma to get the 95% interval in the gaussian case
)
factor_99_pct_interval = (
    2.575829  # number of sigma to get the 99% interval in the gaussian case
)

labels = {
    "no_reg": "No regularization",
    "gs": "Gradient smoothing (GS)",
    "tka": "Adaptive Tikhonov",
    "gstka": "Adaptive Tikhonov + GS",
    "tva": "Adaptive TV",
    "sg": "Sigmoid rescaling",
    "spde_prior": "Bayesian (SPDE prior)",
    "spde_prior_adaptive": "Adaptive Bayesian (SPDE prior)",
    "gdncs": "Gradual deformation + SPDE",
}

data = {
    labels[case]: np.sqrt(post_var_dict[case].reshape(nx, ny, order="F"))
    for case, param in params.items()
}
shift = 0
if len(data.values()) % 2 != 0:
    shift += 1

nrows = int(len(data.values()) / 2) + len(data.values()) % 2

plotter = ngp.NestedGridPlotter(
    plt.figure(constrained_layout=True, figsize=(12, nrows * 4.2)),
    builder=ngp.SubplotsMosaicBuilder(
        mosaic=[[f"ax{i + 1}-{j + 1}" for j in range(2)] for i in range(nrows)],
        sharey=True,
        sharex=True,
    ),
)

# Plot the permeability
ngp.multi_imshow(
    axes=plotter.axes[shift : len(data.values()) + shift],
    fig=plotter.fig,
    data=data,
    cbar_title="Permeability field $[m/s]$",
    imshow_kwargs={
        "cmap": plt.get_cmap("bwr"),
        "extent": [0.0, nx * dx, 0.0, ny * dy],
        "aspect": "equal",
        "norm": LogNorm(vmin=1e-5, vmax=1e-3),
    },
    xlabel="X [m]",
    ylabel="Y [m]",
    cbar_kwargs={"shrink": 0.4},
)

if len(data.values()) % 2 != 0:
    plotter.axes[0].axis("off")

fname = fig_save_path.joinpath("bench_inversed_perm_residuals")
for format in ["png", "pdf"]:
    plotter.savefig((fig_save_path.joinpath(f"{fname}.{format}")), format=format)
