# %% [markdown]
# Ici le dérive la chimie pour faire un essai en 1D et voir si j'ai la bonne forme.

# %% [markdown]
# L'équation de dissolution d'un mineral traceur et de l'évolution des concentrations s'écrit:
#
# - En version explicite

# %% [markdown]
# $$
#   \left\{
#     \begin{array}{l}
#       \overline{c}_{i}^{2n+1} = \overline{c}_{i}^{2n}
#       \\
#       c_{i}^{2n+1} = 1.05 * c_{i}^{2n} - \left(\overline{c}_{i}^{2n+2} - \overline{c}_{i}^{2n+1} \right)
#       \\
#       \mathcal{A}_{i} \omega_{i} \dfrac{\overline{c}_{i}^{2n+2} - \overline{c}_{i}^{2n+1}}{\Delta t^{2n}} = \mathcal{A}_{i} \omega_{i} k_{v} A_{s} \overline{c}_{i}^{2n+1} \left( 1 - \dfrac{c_{i}^{2n+1}}{K_{s}}\right)
#       \\
#       \mathcal{A}_{i} \omega_{i} \dfrac{c_{i}^{2n+2} - c_{i}^{2n+1}}{\Delta t^{2n}} = - \mathcal{A}_{i} \omega_{i} k_{v} A_{s} \overline{c}_{i}^{2n+1} \left( 1 - \dfrac{c_{i}^{2n+1}}{K_{s}}\right)
#     \end{array}
#   \right.
# $$

# %% [markdown]
# with the fix point iteration (FPI) with the criteria: $1 - \dfrac{\overline{c}_{i}^{2n+2}}{\overline{c}_{i}^{2n}} < \epsilon$

# %% [markdown]
# $$ \mathcal{L} = \dfrac{1}{2} \sum_{n} \sum_{i} \left( \dfrac{c_{i}^{2n, obs} - c_{i}^{2n, calc}}{\sigma_{c_{i}^{n, obs}}}\right)^{2} - \langle \lambda_{c_{i}^{n+1}}, g_{c} \rangle - \langle \lambda_{\overline{c}_{i}^{n+1}}, g_{\overline{c}} \rangle $$

# %% [markdown]
# Derivation par $\overline{c}_{i}^{2n}$:
#
# $$ \dfrac{\partial}{\partial \overline{c}_{i}^{2n}} \langle \lambda_{\overline{c}_{i}}^{2n+1}, \overline{c}_{i}^{2n+1} - \overline{c}_{i}^{2n} \rangle$$
#
# $$ = \lambda_{\overline{c}_{i}}^{2n} - \lambda_{\overline{c}_{i}}^{2n+1}$$

# %% [markdown]
# Derivation par $\overline{c}_{i}^{2n+1}$:
#
# $$ \dfrac{\partial}{\partial \overline{c}_{i}^{2n+1}} \biggl< \lambda_{\overline{c}_{i}}^{2n+2}, \mathcal{A}_{i} \omega_{i} \dfrac{\overline{c}_{i}^{2n+2} - \overline{c}_{i}^{2n+1}}{\Delta t^{2n}} - \mathcal{A}_{i} \omega_{i} k_{v} A_{s} \overline{c}_{i}^{2n+1} \left( 1 - \dfrac{c_{i}^{2n+1}}{K_{s}}\right) \biggr>$$
#
# $$ = \lambda_{\overline{c}_{i}}^{2n+2} \Bigg( \dfrac{-\mathcal{A}_{i} \omega_{i}}{\Delta t^{2n}} - \mathcal{A}_{i} \omega_{i} k_{v} A_{s} \left( 1 - \dfrac{c_{i}^{2n+1}}{K_{s}}\right) \Bigg) + \lambda_{\overline{c}_{i}}^{2n+1} \Bigg( \dfrac{\mathcal{A}_{i} \omega_{i}}{\Delta t^{2n-1}}\Bigg) $$

# %% [markdown]
# $$ \dfrac{\partial}{\partial \overline{c}_{i}^{2n+1}} \biggl< \lambda_{c_{i}}^{2n+2}, \mathcal{A}_{i} \omega_{i} \dfrac{c_{i}^{2n+2} - c_{i}^{2n+1}}{\Delta t^{2n}} + \mathcal{A}_{i} \omega_{i} k_{v} A_{s} \overline{c}_{i}^{2n+1} \left( 1 - \dfrac{c_{i}^{2n+1}}{K_{s}}\right) \biggr>$$
#
# $$ = \lambda_{c_{i}}^{2n+2} \mathcal{A}_{i} \omega_{i} k_{v} A_{s} \left( 1 - \dfrac{c_{i}^{2n+1}}{K_{s}}\right)$$

# %% [markdown]
# On obtient alors une expression explicite pour les teneurs adjointes:
#
# $$ \lambda_{\overline{c}_{i}}^{2n+1} = \Bigg( \lambda_{\overline{c}_{i}}^{2n+2} \left( \dfrac{1}{\Delta t^{2n}} + k_{v} A_{s} \left( 1 - \dfrac{c_{i}^{2n+1}}{K_{s}}\right) \right) - \lambda_{c_{i}}^{2n+2} k_{v} A_{s} \left( 1 - \dfrac{c_{i}^{2n+1}}{K_{s}}\right) \Bigg) \Delta t^{2n-1} $$

# %% [markdown]
# 2) Derivation by $c_{i}^{2n} \implies$ we obtain an explicit expression of $\lambda_{c_{i}}^{2n}$:
#
# $$ \dfrac{\partial}{\partial c_{i}^{2n}} \biggl< \lambda_{c_{i}}^{2n+1}, \mathcal{A}_{i} \omega_{i} c_{i}^{2n+1} - \mathcal{A}_{i} \omega_{i} 1.05 * c_{i}^{2n} \biggr>$$
#
# $$ \implies \mathcal{A}_{i} \omega_{i} \lambda_{c_{i}}^{2n} = \mathcal{A}_{i} \omega_{i} 1.05 * \lambda_{c_{i}}^{2n+1} $$

# %% [markdown]
# 3) Derivation par $c_{i}^{2n+1}$:
#
# $$ \dfrac{\partial}{\partial c_{i}^{2n+1}} \biggl< \lambda_{\overline{c}_{i}}^{2n+2}, \mathcal{A}_{i} \omega_{i} \dfrac{\overline{c}_{i}^{2n+2} - \overline{c}_{i}^{2n+1}}{\Delta t^{2n}} - \mathcal{A}_{i} \omega_{i} k_{v} A_{s} \overline{c}_{i}^{2n+1} \left( 1 - \dfrac{c_{i}^{2n+1}}{K_{s}}\right) \biggr>$$
#
# $$ = \lambda_{\overline{c}_{i}}^{2n+2} \mathcal{A}_{i} \omega_{i} k_{v} A_{s} \dfrac{\overline{c}_{i}^{2n+1}}{K_{s}} $$

# %% [markdown]
# $$ \dfrac{\partial}{\partial c_{i}^{2n+1}} \biggl< \lambda_{c_{i}}^{2n+2}, \mathcal{A}_{i} \omega_{i} \dfrac{c_{i}^{2n+2} - c_{i}^{2n+1}}{\Delta t^{2n}} + \mathcal{A}_{i} \omega_{i} k_{v} A_{s} \overline{c}_{i}^{2n+1} \left( 1 - \dfrac{c_{i}^{2n+1}}{K_{s}}\right) \biggr>$$
#
# $$ = \mathcal{A}_{i} \omega_{i}  \left(\dfrac{\lambda_{c_{i}}^{2n+1}}{\Delta t^{2n-1}} -  \dfrac{\lambda_{c_{i}}^{2n+2}}{\Delta t^{2n}} \right) - \lambda_{c_{i}}^{2n+2} \mathcal{A}_{i} \omega_{i} k_{v} A_{s} \dfrac{\overline{c}_{i}^{2n+1}}{K_{s}}$$

# %% [markdown]
# $$ \dfrac{\partial}{\partial c_{i}^{2n}} \dfrac{1}{2} \sum_{n} \sum_{i} \left( \dfrac{c_{i}^{2n, obs} - c_{i}^{2n, calc}}{\sigma_{c_{i}^{2n, obs}}}\right)^{2}$$
#
# $$ = - \left( \dfrac{c_{i}^{2n, obs} - c_{i}^{2n, calc}}{{\sigma_{c_{i}^{2n, obs}}}^{2}}\right)$$

# %% [markdown]
# Gathering the three previous, it yields

# %% [markdown]
# $$\dfrac{\partial \mathcal{L}}{\partial c_{i}^{2n+1}} = - \mathcal{A}_{i} \omega_{i}  \left( \dfrac{\lambda_{c_{i}}^{2n+1}}{\Delta t^{2n-1}} \right) + \mathcal{A}_{i} \omega_{i} \left( \dfrac{\lambda_{c_{i}}^{2n+2}}{\Delta t^{2n}} \right) + \lambda_{c_{i}}^{2n+2} \mathcal{A}_{i} \omega_{i} k_{v} A_{s} \dfrac{\overline{c}_{i}^{2n+1}}{K_{s}}  - \lambda_{\overline{c}_{i}}^{2n+2} \mathcal{A}_{i} \omega_{i} k_{v} A_{s} \dfrac{\overline{c}_{i}^{2n+1}}{K_{s}} - \left( \dfrac{c_{i}^{2n+2, obs} - c_{i}^{2n+2, calc}}{{\sigma_{c_{i}^{2n=2, obs}}}^{2}}\right) = 0 $$

# %% [markdown]
# $$ \implies \lambda_{c_{i}}^{2n+1} = \left( \dfrac{\lambda_{c_{i}}^{2n+2}}{\Delta t^{2n}} + \left(\lambda_{c_{i}}^{2n+2} - \lambda_{\overline{c}_{i}}^{2n+2} \right) k_{v} A_{s} \dfrac{\overline{c}_{i}^{2n+1}}{K_{s}} - \dfrac{c_{i}^{2n, obs} - c_{i}^{2n, calc}}{{\mathcal{A}_{i} \omega_{i} \sigma_{c_{i}^{2n, obs}}}^{2}} \right) \Delta t^{2n-1} $$

# %% [markdown]
# Dérivation par rapport à $\overline{c}_{i}^{0}$:
#
# $$ \dfrac{\partial}{\partial \overline{c}_{i}^{0}} \langle \lambda_{\overline{c}_{i}}^{1}, \overline{c}_{i}^{1} - \overline{c}_{i}^{0} \rangle = \lambda_{\overline{c}_{i}}^{0} - \lambda_{\overline{c}_{i}}^{1} = 0$$

# %% [markdown]
# Dérivation par rapport à $\overline{c}_{i}^{0}$:
#
# $$ \dfrac{\partial \mathcal{L}}{\partial \overline{c}_{i}^{0}} = \dfrac{\partial}{\partial \overline{c}_{i}^{0}} \biggl< \lambda_{\overline{c}_{i}^{2n+2}}, \mathcal{A}_{i} \omega{i} \dfrac{\overline{c}_{i}^{2n+2} - \overline{c}_{i}^{2n+1}}{\Delta t^{2n}} - \mathcal{A}_{i} \omega_{i} k_{v} A_{s} \overline{c}_{i}^{2n+1} \left( 1 - \dfrac{c_{i}^{2n+1}}{K_{s}}\right) \biggr>$$
#
# $$ = \dfrac{\partial}{\partial \overline{c}_{i}^{0}} \sum_{n=0}^{N} \lambda_{\overline{c}_{i}^{2n+2}} \left( \mathcal{A}_{i} \omega{i} \dfrac{\overline{c}_{i}^{2n+2} - \overline{c}_{i}^{2n+1}}{\Delta t^{2n}} - \mathcal{A}_{i} \omega_{i} k_{v} A_{s} \overline{c}_{i}^{2n+1} \left( 1 - \dfrac{c_{i}^{2n+1}}{K_{s}}\right) \right)$$
#
# Et, en remarquant que la boucle directe sur les temps commence à $n=1$, alors $\overline{c}_{i}^{1} = \overline{c}_{i}^{0}$, et $c_{i}^{1} = c_{i}^{0}$ alors la dérivée est non nulle pour $n=0$ uniquement:
#
# $$ \dfrac{\partial \mathcal{L}}{\partial \overline{c}_{i}^{0}} = \dfrac{\partial}{\partial \overline{c}_{i}^{0}} \left[\lambda_{\overline{c}_{i}^{2}} \left( \mathcal{A}_{i} \omega{i} \dfrac{\overline{c}_{i}^{2} - \overline{c}_{i}^{0}}{\Delta t^{0}} - \mathcal{A}_{i} \omega_{i} k_{v} A_{s} \overline{c}_{i}^{0} \left( 1 - \dfrac{c_{i}^{0}}{K_{s}}\right) \right) \right] $$
#
# $$ = \lambda_{\overline{c}_{i}^{2}} \left( \mathcal{A}_{i} \omega{i} \dfrac{- 1}{\Delta t^{0}} - \mathcal{A}_{i} \omega_{i} k_{v} A_{s}  \left( 1 - \dfrac{c_{i}^{0}}{K_{s}}\right) \right) $$

# %% [markdown]
# Et de la même manière:
#
# $$ \dfrac{\partial \mathcal{L}}{\partial \overline{c}_{i}^{0}} = \dfrac{\partial}{\partial \overline{c}_{i}^{0}} \biggl< \lambda_{c_{i}^{2n+2}}, \mathcal{A}_{i} \omega{i} \dfrac{c_{i}^{2n+2} - c_{i}^{2n+1}}{\Delta t^{2n}} + \mathcal{A}_{i} \omega_{i} k_{v} A_{s} \overline{c}_{i}^{2n+1} \left( 1 - \dfrac{c_{i}^{2n+1}}{K_{s}}\right) \biggr>$$
#
# $$ = \dfrac{\partial}{\partial \overline{c}_{i}^{0}} \sum_{n=0}^{N} \lambda_{c_{i}^{2n+2}} \left( \mathcal{A}_{i} \omega{i} \dfrac{c_{i}^{2n+2} - c_{i}^{2n+1}}{\Delta t^{2n}} - \mathcal{A}_{i} \omega_{i} k_{v} A_{s} \overline{c}_{i}^{2n+1} \left( 1 - \dfrac{c_{i}^{2n+1}}{K_{s}}\right) \right)$$
#
# $$ = \dfrac{\partial}{\partial \overline{c}_{i}^{0}} \left[\lambda_{c_{i}^{2}} \left( \mathcal{A}_{i} \omega{i} \dfrac{c_{i}^{2} - c_{i}^{0}}{\Delta t^{0}} - \mathcal{A}_{i} \omega_{i} k_{v} A_{s} \overline{c}_{i}^{0} \left( 1 - \dfrac{c_{i}^{0}}{K_{s}}\right) \right) \right] $$
#
# $$ = \lambda_{c_{i}^{2}} \mathcal{A}_{i} \omega_{i} k_{v} A_{s} \left( 1 - \dfrac{c_{i}^{0}}{K_{s}}\right) $$
#
# $$\implies \dfrac{d J}{d {\overline{c}_{i}}^{0}} = \mathcal{A}_{i} \omega_{i} \Bigg[ {\lambda_{\overline{c}_{i}}^{2}} \left(\dfrac{1}{\Delta t^{0}} + k_{v} A_{s} \left( 1 - \dfrac{c_{i}^{0}}{K_{s}}\right) \right) - \lambda_{c_{i}^{2}} k_{v} A_{s} \left( 1 - \dfrac{c_{i}^{0}}{K_{s}}\right) \Bigg]$$

# %% [markdown]
# $$
#   \left\{
#     \begin{array}{l}
#       \lambda_{c_{i}}^{2n+1} = \left( \dfrac{\lambda_{c_{i}}^{2n+2}}{\Delta t^{2n}} + \left(\lambda_{c_{i}}^{2n+2} - \lambda_{\overline{c}_{i}}^{2n+2} \right) k_{v} A_{s} \dfrac{\overline{c}_{i}^{2n+1}}{K_{s}} - \dfrac{c_{i}^{2n, obs} - c_{i}^{2n, calc}}{{\mathcal{A}_{i} \omega_{i} \sigma_{c_{i}^{2n, obs}}}^{2}} \right) \Delta t^{2n-1}
#       \\
#       \lambda_{\overline{c}_{i}}^{2n+1} = \Bigg( \lambda_{\overline{c}_{i}}^{2n+2} \left( \dfrac{1}{\Delta t^{2n}} + k_{v} A_{s} \left( 1 - \dfrac{c_{i}^{2n+1}}{K_{s}}\right) \right) - \lambda_{c_{i}}^{2n+2} k_{v} A_{s} \left( 1 - \dfrac{c_{i}^{2n+1}}{K_{s}}\right) \Bigg) \Delta t^{2n-1}
#       \\
#       \lambda_{c_{i}}^{2n} = 1.05 * \lambda_{c_{i}}^{2n+1}
#       \\
#       \lambda_{\overline{c}_{i}}^{2n} = \lambda_{\overline{c}_{i}}^{2n+1}
#     \end{array}
#   \right.
# $$

# %% [markdown]
# ## Numerical tests

# %% [markdown]
# - Class for the geochemical parameters

# %%
from typing import List
import numpy as np
import matplotlib.pyplot as plt
import numpy.typing as npt
from pyrtid.utils import finite_gradient
import numdifftools as nd

# %%
NDArrayFloat = npt.NDArray[np.float_]

# %%
class GeochemicalParameters:
    """
    Class defining the geocgemical parameters used in the simulation.

    Attributes
    ----------
    conc: float, optional
        Initial tracer concentration in the grid in molal. The default is 0.0.
    grade: float, optional
        Default mineral grade in the grid in mol/kg (kg of water).
        The default is 0.0.
    kv: float, optional
        The kinetic rate of the mineral in [mol/m2/s]. The default is -6.9e-9.
    As: float, optional
        Specific area in [m2/mol]. The default is 13.5.
    Ks: float, optional
        Solubility constant (no unit). The default is 6.3e-4.
    """

    def __init__(
        self,
        conc: float = 0.0,
        grade: float = 0.0,
        kv: float = -6.9e-9,
        As: float = 13.5,
        Ks: float = 6.3e-4,
    ) -> None:
        """Initialize the instance."""
        self.conc: float = conc
        self.grade: float = grade
        self.kv: float = kv
        self.As: float = As
        self.Ks: float = Ks


class Geometry:
    """
    Class defining the grid geometry used in the simulation.

    Attributes
    ----------
    nx : int
        Number of voxels along the x axis.
    ny : int
        Number of voxels along the y axis.
    dx : float
        Voxel dimension along the x axis.
    dy : float
        Voxel dimension along the y axis.
    dz : float
        Voxel dimension along the z axis. This is only taken into account for
        the voxel volume computation.
    """

    def __init__(
        self,
        nx: int,
        ny: int,
        dx: float,
        dy: float,
        dz: float = 1.0,
    ) -> None:
        """Initialize the class instance."""
        self._nx = 1
        self._ny = 1
        self.nx = int(nx)
        self.ny = int(ny)
        self.dx: float = dx
        self.dy: float = dy
        self.dz: float = dz

    @property
    def nx(self) -> int:
        """Return the number of meshes along the x axis."""
        return self._nx

    @nx.setter
    def nx(self, value: int) -> None:
        if value < 1:
            raise (ValueError("nx should be > 1!)"))
        self._nx = value

    @property
    def ny(self) -> int:
        """Return the number of meshes along the y axis."""
        return self._ny

    @ny.setter
    def ny(self, value: int) -> None:
        self._ny = value

    @property
    def mesh_area(self) -> float:
        """Return the area of a voxel in m2."""
        return self.dx * self.dy

    @property
    def mesh_volume(self) -> float:
        """Return the volume of a voxel in m3."""
        return self.mesh_area * self.dz


class TimeParameters:
    """
    Class defining the time parameters used in the simulation.

    It also handles the variable timestep.

    Attributes
    ----------
    nt : int
        Number of timesteps in the simulation.
    dt : float
        Current timestep in seconds.
    dt_init : float
        Initial timestep in seconds.
    dt_min : float
        Minimum timestep in seconds.
    dt_max : float
        Maximum timestep in seconds.
    ldt: List[float]
        List of successive timesteps (in seconds) used in the forward modelling.
    """

    __slots__ = ["nt", "dt", "dt_init", "dt_min", "dt_max", "ldt"]

    def __init__(self, nt: int, dt_init: float, dt_min: float, dt_max: float) -> None:
        """Initialize the instance."""
        self.nt: int = int(nt)
        self.dt_init: float = dt_init
        self.dt: float = dt_init
        self.dt_min: float = dt_min
        self.dt_max: float = dt_max
        self.ldt: List[float] = []

    @property
    def duration(self) -> float:
        """Simulation duration in seconds."""
        return self.nt * self.dt

    def reset_dt(self) -> None:
        """Empty the list of timesteps and set dt to its initial value."""
        self.dt = self.dt_init
        self.ldt = []

    def update_dt(self, n_iter: int) -> None:
        """
        Update the timestep.

        Parameters
        ----------
        n_iter: int
            Number of iterations required to solve the current timestep.
        """
        if n_iter < 20:
            # increase dt by 5%
            self.dt *= 1.05
        else:
            # decrease dt by 30%
            self.dt *= 0.7
        # Ensure timebounds
        if self.dt < self.dt_min:
            self.dt = self.dt_min
        if self.dt > self.dt_max:
            self.dt = self.dt_max
        self.ldt.append(self.dt)


class TransportParameters:
    """
    Class defining the transport parameters used in the simulation.

    Attributes
    ----------
    diffusion: float, optional
        Default diffusion coefficient in the grid in [m2/s]. The default is 1e-4 m2/s.
    porosity: float, optional
        Default porosity in the grid Should be a number between 0 and 1.
        The default is 1.0.
    crank_nicolson: float
        The Crank-Nicholson parameter allows to set the temporal resolution
        scheme to explicit, fully implicit or somewhere in between these two
        extremes. The value must be comprised between 0.0 and 1.0, 0.0 being a
        full explicit scheme and 1.0 fully implicit. The default is 0.5.
    tolerance: float, optional
        The tolerance on the transport. The default is 1e-8.
    is_numerical_acceleration: bool, optional
        Whether to use the concentration values at the previous iteration as an initial
        guess for gmres (x0) rather than using a random vector. This should increase the
        speed of resolution. The default is False.
    fip_eps: float
       Precision of transport-chemistry coupling procedure. The default value is 1e-5
       which is a strict value if the error is evaluated for each node and each
       species separately.
    """

    def __init__(
        self,
        diffusion: float = 1e-4,
        porosity: float = 1.0,
        crank_nicolson_advection: float = 0.5,
        crank_nicolson_diffusion: float = 1.0,
        tolerance: float = 1e-8,
        is_numerical_acceleration: bool = False,
        fip_eps=1e-5,
    ) -> None:
        """Initialize the instance."""
        self.diffusion: float = diffusion
        self.porosity: float = porosity
        self.crank_nicolson_advection: float = crank_nicolson_advection
        self.crank_nicolson_diffusion: float = crank_nicolson_diffusion
        self.tolerance: float = tolerance
        self.is_numerical_acceleration: bool = is_numerical_acceleration
        self.fip_eps = fip_eps

# %%
nx = 20  # number of voxels along the x axis
ny = 1  # number of voxels along the y axis
dx = 2.98  # voxel dimension along the x axis
dy = 3.7  # voxel dimension along the y axis
dz = 1

geom = Geometry(nx, ny, dx, dy, dz)

time_params = TimeParameters(
    nt=50,  # number of time steps
    dt_init=20000.0,  # timestep in seconds
    dt_min=50000.0,
    dt_max=200000.0,
)

# Chemistry parameters
c0 = 0.0001  # general initial concentration [molal]
M0 = 0.001  # mineral grade [mol/kg] -> kg of water
M1 = 0.0005  # mineral grade [mol/kg] -> kg of water
M1 = np.abs(0.001 * (0.5 + 0.5 * np.sin(np.arange(nx) / 2))).reshape(20, -1)
kv = -6.9e-9  # kinetic rate,       [mol/m2/s]
moleweight = 270.0  # molar weight [g/mol]
surface = 500  # cm2/g
As = moleweight * surface / 1e4  # specific area [m2/mol]
logK = 3.2
Ks = 1.0 / pow(10, logK)  # solubility constant [no unit]
porosity = 0.23
diffusion = 0.0

gch_params_ref = GeochemicalParameters(c0, M0, kv, As, Ks)

gch_params_est = GeochemicalParameters(c0, M1, kv, As, Ks)

tr_params = TransportParameters(diffusion=diffusion, porosity=porosity)

# %%
plt.plot(M1)

# %%
class TransportModel:
    def __init__(
        self, nt: int, geochem: GeochemicalParameters, tr_params: TransportParameters
    ) -> None:
        self.conc = np.zeros((nx, ny, nt + 1))
        self.conc_post_tr = np.zeros((nx, ny, nt + 1))
        self.conc[:, :, 0] = geochem.conc
        self.conc_post_tr[:, :, 0] = geochem.conc
        self.grade = np.zeros((nx, ny, nt + 1))
        self.grade_post_tr = np.zeros((nx, ny, nt + 1))
        self.grade[:, :, 0] = geochem.grade
        self.grade_post_tr[:, :, 0] = geochem.grade
        self.porosity = np.zeros((nx, ny))
        self.porosity[:, :] = tr_params.porosity
        self.diffusion = np.zeros((nx, ny))
        self.diffusion[:, :] = tr_params.diffusion

        # Useful for the fixed point iterations
        self.grade_old = np.zeros((nx, ny))

        self.fip_eps = tr_params.fip_eps


class AdjointTransportModel:
    def __init__(self, nt: int) -> None:
        self.a_conc = np.zeros((nx, ny, nt + 1))
        self.a_conc_post_gch = np.zeros((nx, ny, nt + 1))
        self.a_grade = np.zeros((nx, ny, nt + 1))
        self.a_grade_post_gch = np.zeros((nx, ny, nt + 1))

# %%
def solve_transport(
    tr_model: TransportModel,
    gch_params: GeochemicalParameters,
    time_params: TimeParameters,
    time_index: int,
) -> None:
    """Compute the geochemistry part."""

    # Need to take into account boundary conditions:
    # And then the reactive (chemistry) contribution with the updated conc

    # Note: the concentration has been modified by the transport so we need to use the
    # updated one.
    dmdt = tr_model.grade[:, :, time_index] - tr_model.grade[:, :, time_index - 1]
    # print(dmdt)

    tr_model.conc_post_tr[:, :, time_index] = (1 + tr_model.diffusion) * tr_model.conc[
        :, :, time_index - 1
    ] - dmdt


def solve_geochem(
    tr_model: TransportModel,
    gch_params: GeochemicalParameters,
    time_params: TimeParameters,
    time_index: int,
) -> None:
    """Compute the geochemistry part."""

    # Need to take into account boundary conditions:
    # And then the reactive (chemistry) contribution with the updated conc

    # Note: the concentration has been modified by the transport so we need to use the
    # updated one.
    m0 = tr_model.grade[:, :, time_index - 1]

    dMdt = (
        gch_params.kv
        * gch_params.As
        * m0
        * (1.0 - tr_model.conc_post_tr[:, :, time_index] / gch_params.Ks)
    )

    print(dMdt)

    tr_model.grade[:, :, time_index] = m0 + dMdt * time_params.dt
    tr_model.conc[:, :, time_index] = (
        tr_model.conc_post_tr[:, :, time_index] - dMdt * time_params.dt
    )


def get_max_coupling_error(tr_model: TransportModel, time_index: int) -> float:
    """
    Return the maximum transport-chemistry coupling error.

    This error is evaluated from the immobile concentrations (mineral grades).
    """
    return float(np.max(1 - tr_model.grade[:, :, time_index] / tr_model.grade_old))

# %%
tr_model_ref = TransportModel(time_params.nt, gch_params_ref, tr_params)
tr_model_ref.grade[:, :, 0] = M0
tr_model_est = TransportModel(time_params.nt, gch_params_est, tr_params)
tr_model_est.grade[:, :, 0] = M1


def solve_forward(
    _time_params: TimeParameters,
    _gch_params: GeochemicalParameters,
    _tr_model: TransportModel,
    is_verbose: bool = False,
) -> None:
    dt_list = [0.0]
    nb_it = 1  # number of coupling iterations
    _time_params.reset_dt()
    # Otherwise there is an issue
    for it in range(1, _time_params.nt + 1):
        _time_params.dt
        if it != 1:
            _time_params.update_dt(
                nb_it
            )  # update the timestep based on the convergence speed.

        has_converged = False

        # Copy the grades (To place in another function afterwards)
        _tr_model.grade[:, :, it] = _tr_model.grade[:, :, it - 1]

        # Iterate the chemistry transport system while the convergence is no meet
        while not has_converged:
            # Save the grade for the fix point iterations
            _tr_model.grade_old = _tr_model.grade[:, :, it].copy()

            solve_transport(_tr_model, _gch_params, time_params, it)
            solve_geochem(_tr_model, _gch_params, time_params, it)
            # One more coupling iteration has been performed
            nb_it += 1
            if is_verbose:
                print(
                    f"max-coupling error at it = {it}-{nb_it}: {get_max_coupling_error(_tr_model, it)}"
                )
            has_converged = get_max_coupling_error(_tr_model, it) < _tr_model.fip_eps
            if is_verbose:
                print(f"has-converged ?: {has_converged}")

        # reset the number of coupling iterations
        nb_it = 0


solve_forward(time_params, gch_params_ref, tr_model_ref, is_verbose=True)
solve_forward(time_params, gch_params_est, tr_model_est)
# Out:
# [[-7.83867199e-11]
#  [-5.23928859e-11]
#  [-5.23928859e-11]
#  [-5.23928859e-11]
#  [-5.23928859e-11]
#  [-5.23928859e-11]]
# max-coupling error at it = 17-2: -8.529027557235835e-05
# has-converged ?: True
# [[-5.13433265e-11]
#  [-5.13433265e-11]
#  [-5.13433265e-11]
#  [-5.13433265e-11]
#  [-5.13433265e-11]
#  [-5.13433265e-11]
#  [-5.13433265e-11]
#  [-5.13433265e-11]
#  [-5.13433265e-11]
#  [-5.13433265e-11]
#  [-5.13433265e-11]
#  [-5.13433265e-11]
#  [-5.13433265e-11]
#  [-5.13433265e-11]
#  [-5.13433265e-11]
#  [-5.13433265e-11]
#  [-5.13433265e-11]
#  [-5.13433265e-11]
#  [-5.13433265e-11]
#  [-5.13433265e-11]]
# max-coupling error at it = 18-1: 0.006069513634372692
# has-converged ?: False
# [[-5.05795003e-11]
#  [-5.05795003e-11]
#  [-5.05795003e-11]
#  [-5.05795003e-11]
#  [-5.05795003e-11]
#  [-5.05795003e-11]
#  [-5.05795003e-11]
#  [-5.05795003e-11]
#  [-5.05795003e-11]
#  [-5.05795003e-11]
#  [-5.05795003e-11]
#  [-5.05795003e-11]
#  [-5.05795003e-11]
#  [-5.05795003e-11]
#  [-5.05795003e-11]
#  [-5.05795003e-11]
#  [-5.05795003e-11]
#  [-5.05795003e-11]
#  [-5.05795003e-11]
#  [-5.05795003e-11]]
# max-coupling error at it = 18-2: -9.084654799407232e-05
# has-converged ?: True
# [[-4.95291107e-11]
#  [-4.95291107e-11]
#  [-4.95291107e-11]
#  [-4.95291107e-11]
#  [-4.95291107e-11]
#  [-4.95291107e-11]
#  [-4.95291107e-11]
#  [-4.95291107e-11]
#  [-4.95291107e-11]
#  [-4.95291107e-11]
#  [-4.95291107e-11]
#  [-4.95291107e-11]
#  [-4.95291107e-11]
#  [-4.95291107e-11]
#  [-4.95291107e-11]
#  [-4.95291107e-11]
#  [-4.95291107e-11]
#  [-4.95291107e-11]
#  [-4.95291107e-11]
#  [-4.95291107e-11]]
# max-coupling error at it = 19-1: 0.006184779964882425
# has-converged ?: False
# [[-4.87600584e-11]
#  [-4.87600584e-11]
#  [-4.87600584e-11]
#  [-4.87600584e-11]
#  [-4.87600584e-11]
#  [-4.87600584e-11]
#  [-4.87600584e-11]
#  [-4.87600584e-11]
#  [-4.87600584e-11]
#  [-4.87600584e-11]
#  [-4.87600584e-11]
#  [-4.87600584e-11]
#  [-4.87600584e-11]
#  [-4.87600584e-11]
#  [-4.87600584e-11]
#  [-4.87600584e-11]
#  [-4.87600584e-11]
#  [-4.87600584e-11]
#  [-4.87600584e-11]
#  [-4.87600584e-11]]
# max-coupling error at it = 19-2: -9.663043239593883e-05
# has-converged ?: True
# [[-4.77106697e-11]
#  [-4.77106697e-11]
#  [-4.77106697e-11]
#  [-4.77106697e-11]
#  [-4.77106697e-11]
#  [-4.77106697e-11]
#  [-4.77106697e-11]
#  [-4.77106697e-11]
#  [-4.77106697e-11]
#  [-4.77106697e-11]
#  [-5.11220368e-13]
#  [-9.24891961e-13]
#  [-5.71635004e-12]
#  [-1.06037065e-11]
#  [-1.24909467e-11]
#  [-1.20225768e-11]
#  [-1.11395305e-11]
#  [-1.09488411e-11]
#  [-1.16167448e-11]
#  [-1.24641690e-11]
#  [-1.17873585e-11]]
# [[-1.19438722e-11]
#  [-1.21803962e-11]
#  [-1.12356857e-11]
#  [-1.06657557e-11]
#  [-1.09964752e-11]
#  [-1.19449832e-11]
#  [-1.22553583e-11]
#  [-9.96549598e-12]
#  [-4.85928320e-12]
#  [-5.11120189e-13]
#  [-9.24559268e-13]
#  [-5.70080856e-12]
#  [-1.05276278e-11]
#  [-1.23289213e-11]
#  [-1.17992094e-11]
#  [-1.08910892e-11]
#  [-1.06970829e-11]
#  [-1.13792887e-11]
#  [-1.22718582e-11]
#  [-1.16754100e-11]]
# [[-1.17395851e-11]
#  [-1.19291146e-11]
#  [-1.09648692e-11]
#  [-1.03909309e-11]
#  [-1.07235920e-11]
#  [-1.16857057e-11]
#  [-1.20348517e-11]
#  [-9.81062408e-12]
#  [-4.78588752e-12]
#  [-5.03148911e-13]
#  [-9.10198426e-13]
#  [-5.61491140e-12]
#  [-1.03615277e-11]
#  [-1.21006954e-11]
#  [-1.15365628e-11]
#  [-1.06174821e-11]
#  [-1.04224023e-11]
#  [-1.11100422e-11]
#  [-1.20257640e-11]
#  [-1.14805707e-11]]
# [[-1.16185754e-11]
#  [-1.17357062e-11]
#  [-1.07352046e-11]
#  [-1.01515147e-11]
#  [-1.04892525e-11]
#  [-1.14783192e-11]
#  [-1.18904850e-11]
#  [-9.74851285e-12]
#  [-4.77538724e-12]
#  [-5.03051833e-13]
#  [-9.09875988e-13]
#  [-5.59983474e-12]
#  [-1.02878307e-11]
#  [-1.19446131e-11]
#  [-1.13230289e-11]
#  [-1.03813667e-11]
#  [-1.01834075e-11]
#  [-1.08836900e-11]
#  [-1.18410889e-11]
#  [-1.13723274e-11]]

# %%
import matplotlib.pyplot as plt

plt.plot(tr_model_ref.grade[0, 0, :], label="grade ref")
plt.plot(tr_model_ref.conc[0, 0, :], label="conc ref")
plt.plot(tr_model_est.grade[0, 0, :], label="grade est")
plt.plot(tr_model_est.conc[0, 0, :], label="conc est")
plt.legend()

# %% [markdown]
# - Build an inverse

# %% [markdown]
# $$
#   \left\{
#     \begin{array}{l}
#       \lambda_{c_{i}}^{2n+1} = \left( \dfrac{\lambda_{c_{i}}^{2n+2}}{\Delta t^{2n}} + \left(\lambda_{c_{i}}^{2n+2} - \lambda_{\overline{c}_{i}}^{2n+2} \right) k_{v} A_{s} \dfrac{\overline{c}_{i}^{2n+1}}{K_{s}} - \dfrac{c_{i}^{2n, obs} - c_{i}^{2n, calc}}{{\mathcal{A}_{i} \omega_{i} \sigma_{c_{i}^{2n, obs}}}^{2}} \right) \Delta t^{2n-1}
#       \\
#       \lambda_{\overline{c}_{i}}^{2n+1} = \Bigg( \lambda_{\overline{c}_{i}}^{2n+2} \left( \dfrac{1}{\Delta t^{2n}} + k_{v} A_{s} \left( 1 - \dfrac{c_{i}^{2n+1}}{K_{s}}\right) \right) - \lambda_{c_{i}}^{2n+2} k_{v} A_{s} \left( 1 - \dfrac{c_{i}^{2n+1}}{K_{s}}\right) \Bigg) \Delta t^{2n-1}
#       \\
#       \lambda_{c_{i}}^{2n} = 1.05 * \lambda_{c_{i}}^{2n+1}
#       \\
#       \lambda_{\overline{c}_{i}}^{2n} = \lambda_{\overline{c}_{i}}^{2n+1}
#     \end{array}
#   \right.
# $$

# %%
def add_chem_adjoint_sources(
    tr_model: TransportModel,
    a_tr_model: AdjointTransportModel,
    geometry: Geometry,
    a_sources: NDArrayFloat,
    time_params: TimeParameters,
    time_index: int,
) -> None:
    """Add the sources in the adjoint problem."""
    # Note the sources are added on the previous timestep
    # -> this is the time at which the observation has been made !
    dt_cur = time_params.ldt[time_index]
    a_tr_model.a_conc[:, :, time_index + 1] -= (
        a_sources[:, :, time_index + 1]
        / geometry.mesh_area
        / tr_model.porosity
        * dt_cur
    )


def solve_adj_geochem_explicit(
    tr_model: TransportModel,
    a_tr_model: AdjointTransportModel,
    gch_params: GeochemicalParameters,
    geometry: Geometry,
    a_sources,
    time_params: TimeParameters,
    time_index: int,
) -> None:
    """Compute the geochemistry part."""

    # 1) Add the adjoint sources on the previous timestep
    add_chem_adjoint_sources(
        tr_model_est, a_tr_model, geometry, a_sources, time_params, it
    )

    # Skip the last timestep (there is no transport between n=0 and n=1)
    if time_index == 0:
        return

    # Adjoint variable at the previous timestep going backward (timestep n+1)
    am_prev = a_tr_model.a_grade[:, :, time_index + 1]
    ac_prev = a_tr_model.a_conc[:, :, time_index + 1]
    dt_prev = time_params.ldt[time_index]
    # Forward variable at the current timestep going backward
    # (timestep n -> we want to predict)
    m_cur = tr_model.grade[:, :, time_index]
    c_prev_post_tr = tr_model.conc_post_tr[:, :, time_index + 1]  # 2n + 1
    dt_cur = time_params.ldt[time_index - 1]

    # Update concentration (with adjoint sources)
    a_tr_model.a_conc_post_gch[:, :, time_index] = (
        ac_prev / dt_prev
        + (ac_prev - am_prev) * gch_params.kv * gch_params.As * m_cur / gch_params.Ks
    ) * dt_cur

    # Update mineral value
    a_tr_model.a_grade_post_gch[:, :, time_index] = (
        am_prev
        * (
            1 / dt_prev
            + gch_params.kv * gch_params.As * (1.0 - c_prev_post_tr / gch_params.Ks)
        )
        # - a_tr_model.a_conc_post_gch[:, :, time_index] / dt_cur + ac_prev / dt_prev
        - ac_prev * gch_params.kv * gch_params.As * (1 - c_prev_post_tr / gch_params.Ks)
    ) * dt_cur

# %%
tr_model_est.porosity[:, :].shape
# Out:
# (20, 1)

# %%
def solve_adj_transport(
    tr_model: TransportModel,
    a_tr_model: AdjointTransportModel,
    gch_params: GeochemicalParameters,
    geometry: Geometry,
    a_sources: float,
    time_params: TimeParameters,
    time_index: int,
) -> None:
    # Skip the last timestep (there is no transport between n=0 and n=1)
    if time_index == 0:
        return
    a_tr_model.a_conc[:, :, time_index] = a_tr_model.a_conc_post_gch[
        :, :, time_index
    ] * (1 + tr_model.diffusion)
    a_tr_model.a_grade[:, :, time_index] = a_tr_model.a_grade_post_gch[:, :, time_index]

# %%
atr_model = AdjointTransportModel(time_params.nt)
_a_sources = tr_model_ref.conc - tr_model_est.conc

for it in range(time_params.nt - 1, -1, -1):
    solve_adj_geochem_explicit(
        tr_model_est, atr_model, gch_params_est, geom, _a_sources, time_params, it
    )
    solve_adj_transport(
        tr_model_est, atr_model, gch_params_est, geom, _a_sources, time_params, it
    )

# copy the last values
atr_model.a_conc[:, :, 0] = atr_model.a_conc[:, :, 1]
atr_model.a_conc_post_gch[:, :, 0] = atr_model.a_conc[:, :, 1]

atr_model.a_grade[:, :, 0] = atr_model.a_grade[:, :, 1]
atr_model.a_grade_post_gch[:, :, 0] = atr_model.a_grade[:, :, 1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[91], line 5
#       2 _a_sources = tr_model_ref.conc - tr_model_est.conc
#       4 for it in range(time_params.nt - 1, -1, -1):
# ----> 5     solve_adj_geochem_explicit(
#       6         tr_model_est, atr_model, gch_params_est, geom, _a_sources, time_params, it
#       7     )
#       8     solve_adj_transport(
#       9         tr_model_est, atr_model, gch_params_est, geom, _a_sources, time_params, it
#      10     )
#      12 # copy the last values
#
# Cell In[88], line 33, in solve_adj_geochem_explicit(tr_model, a_tr_model, gch_params, geometry, a_sources, time_params, time_index)
#      30 """Compute the geochemistry part."""
#      32 # 1) Add the adjoint sources on the previous timestep
# ---> 33 add_chem_adjoint_sources(
#      34     tr_model_est, a_tr_model, geometry, a_sources, time_params, it
#      35 )
#      37 # Skip the last timestep (there is no transport between n=0 and n=1)
#      38 if time_index == 0:
#
# Cell In[88], line 12, in add_chem_adjoint_sources(tr_model, a_tr_model, geometry, a_sources, time_params, time_index)
#       9 """Add the sources in the adjoint problem."""
#      10 # Note the sources are added on the previous timestep
#      11 # -> this is the time at which the observation has been made !
# ---> 12 dt_cur = time_params.ldt[time_index]
#      13 a_tr_model.a_conc[:, :, time_index + 1] -= (
#      14     a_sources[:, :, time_index + 1]
#      15     / geometry.mesh_area
#      16     / tr_model.porosity
#      17     * dt_cur
#      18 )
#
# IndexError: list index out of range

# %%
plt.plot(atr_model.a_conc[0, 0, :], label="adjoint conc")
plt.legend()

# %%
plt.plot(atr_model.a_grade[0, 0, :], label="adjoint grade")
plt.legend()

# %% [markdown]
# # TODO: check the indices for this one. Normally should be zero...

# %% [markdown]
# $$\implies \dfrac{d J}{d {\overline{c}_{i}}^{0}} = \mathcal{A}_{i} \omega_{i} \Bigg[ {\lambda_{\overline{c}_{i}}^{2}} \left(\dfrac{1}{\Delta t^{0}} + k_{v} A_{s} \left( 1 - \dfrac{c_{i}^{0}}{K_{s}}\right) \right) - {\lambda_{c_{i}}^{2}} k_{v} A_{s} \left( 1 - \dfrac{c_{i}^{0}}{K_{s}}\right) \Bigg]$$

# %%
gch_params = gch_params_est


def get_gradient(time_params: TimeParameters):
    return (
        (
            atr_model.a_grade[:, :, 1]
            * (
                1 / time_params.ldt[0]
                + gch_params.kv
                * gch_params.As
                * (1.0 - tr_model_est.conc[:, :, 0] / gch_params.Ks)
            )
            - atr_model.a_conc[:, :, 1]
            * gch_params.kv
            * gch_params.As
            * (1 - tr_model_est.conc[:, :, 0] / gch_params.Ks)
        )
        * geom.mesh_area
        * porosity
    )


def get_gradient(time_params: TimeParameters):
    return (
        (
            (
                atr_model.a_grade[:, :, 0] / time_params.ldt[0]
                + (atr_model.a_grade[:, :, 0] - atr_model.a_conc[:, :, 0])
                * gch_params.kv
                * gch_params.As
                * (
                    1.0
                    - tr_model_est.conc[:, :, 0]
                    * (1 + tr_model_est.diffusion)
                    / gch_params.Ks
                )
            )
        )
        * geom.mesh_area
        * porosity
    )


adjoint_gradient = get_gradient(time_params=time_params).ravel()

# %%
def objfun(x, time_params: TimeParameters) -> float:
    _tr_model = TransportModel(time_params.nt, gch_params_est, tr_params)
    _tr_model.grade[:, :, 0] = x.reshape(nx, ny, order="F")

    solve_forward(time_params, gch_params_est, _tr_model, is_verbose=False)

    a_sources = tr_model_ref.conc - _tr_model.conc
    return float(0.5 * np.sum(a_sources**2))

# %%
objfun(np.ones((nx, ny)) * M0, time_params)
# Out:
# 0.0

# %%
objfun(M1, time_params)
# Out:
# 8.81520383010486e-06

# %% [markdown]
# - Define a step for the finite differences

# %%
import sys

eps = sys.float_info.epsilon * 1e6
eps
# Out:
# 2.220446049250313e-10

# %%
def objfun_wrapper(x: NDArrayFloat) -> float:
    return objfun(x, time_params)


fd_gradient_numdifftools = nd.Gradient(objfun_wrapper, step=eps)(M1.ravel("F"))
fd_gradient_pyrtid = finite_gradient(
    np.array([M1]).ravel("F"), objfun, fm_args=(time_params,), eps=eps
)

# %%
adjoint_gradient
# Out:
# array([-8.15545823e-04, -3.01139042e-04, -7.14549691e-05, -1.01718579e-06,
#        -3.90597555e-05, -2.13750962e-04, -6.32295293e-04, -1.42533519e-03,
#        -2.50330409e-03, -3.31478535e-03, -3.23913359e-03, -2.33991515e-03,
#        -1.28074982e-03, -5.47828233e-04, -1.75357360e-04, -2.61918440e-05,
#        -4.34456195e-06, -9.35117380e-05, -3.56586170e-04, -9.26286416e-04])

# %% [markdown]
# - Plot the gradients

# %%
plt.plot(adjoint_gradient, label="adjoint")
plt.plot(fd_gradient_pyrtid, label="fd pyrtid", linestyle="--")
plt.plot(fd_gradient_numdifftools, label="fd numdifftools", linestyle="--")
plt.legend()

# %%
plt.plot((adjoint_gradient - fd_gradient_pyrtid), label="residuals pyrtid")
plt.plot(
    (adjoint_gradient - fd_gradient_numdifftools),
    linestyle="--",
    label="residuals numdifftools",
)
plt.legend()

# %%
def objfun_wrapper(x: NDArrayFloat):
    return objfun(x, time_params)


fd_gradient_2 = nd.Gradient(objfun_wrapper, step=eps)(M1.ravel("F"))

# %%
plt.plot(adjoint_gradient, label="adjoint")
plt.plot(fd_gradient_2, label="fd - numdifftools")
plt.legend()

# %%
plt.plot(adjoint_gradient - fd_gradient_2, label="residuals 2")
plt.legend()
