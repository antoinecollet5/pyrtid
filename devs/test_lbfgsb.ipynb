# %% [markdown]
# - import some functions from stochopy to test the code

# %%
# python lbfgsb works with numpy arrays
import numpy as np
from pyrtid.inverse import minimize_lbfgsb
from scipy.optimize import minimize

# %% [markdown]
# - First example: min x^{\mathrm{T}}x such that x>=1. Optimal solution hits the boundary.

# %%
def quad(x):
    return x.dot(x)


def grad_quad(x):
    return x


ftol = 1e-5
gtol = 1e-5
l = np.array([1, 1])
u = np.array([np.inf, np.inf])
bounds = np.array((l, u)).T
x0 = np.array([5, 5])

# %%
bounds[0]
# Out:
# array([ 1., inf])

# %% [markdown]
# ### New implementation

# %%
print("====================== Quadratic example ======================")
opt_quad = minimize_lbfgsb(
    x0=x0, fun=quad, jac=grad_quad, bounds=bounds, ftol=ftol, gtol=gtol, iprint=100
)
print("")
print("")
xOpt = np.array([1, 1])
theoOpt = {"x": xOpt, "f": quad(xOpt), "df": grad_quad(xOpt)}
print("Theoretical optimal value: ")
print(theoOpt)
print("Optimal value found: ")
print(opt_quad)
# Out:
# ====================== Quadratic example ======================
# Iteration #0 (max: 50): ||x||=1.613e+00, f(x)=3.304e+00, ||jac(x)||=1.613e+00, cdt_arret=1.613e+00 (eps=1.000e-10)
# Iteration #1 (max: 50): ||x||=0.000e+00, f(x)=0.000e+00, ||jac(x)||=0.000e+00, cdt_arret=0.000e+00 (eps=1.000e-10)
# Iteration #2 (max: 50): ||x||=0.000e+00, f(x)=0.000e+00, ||jac(x)||=0.000e+00, cdt_arret=0.000e+00 (eps=1.000e-10)
#
#
# Theoretical optimal value:
# {'x': array([1, 1]), 'f': 2, 'df': array([1, 1])}
# Optimal value found:
#   message: CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#   success: True
#    status: 1
#       fun: 0.0
#         x: [ 0.000e+00  0.000e+00]
#       nit: 2
#       jac: [ 0.000e+00  0.000e+00]
#      nfev: 3
#      njev: 3
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>

# %% [markdown]
# ### Scipy

# %%
bounds
# Out:
# array([[ 1., inf],
#        [ 1., inf]])

# %%
minimize(
    quad,
    x0,
    jac=grad_quad,
    bounds=bounds,
    method="l-bfgs-b",
    options={"gtol": gtol, "ftol": ftol, "disp": 100},
)
# Out:
#   message: CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#   success: True
#    status: 0
#       fun: 0.0
#         x: [ 0.000e+00  0.000e+00]
#       nit: 1
#       jac: [ 0.000e+00  0.000e+00]
#      nfev: 2
#      njev: 2
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.94000D+00    |proj g|=  2.50000D+00
#
#
# ITERATION     1
#
# ---------------- CAUCHY entered-------------------
#  There are            2   breakpoints
#
# Piece      1 --f1, f2 at start point  -7.9400D+00  7.9400D+00
# Distance to the next break point =   2.8000D+00
# Distance to the stationary point =   1.0000D+00
#
#  GCP found in this segment
# Piece      1 --f1, f2 at start point  -7.9400D+00  7.9400D+00
# Distance to the stationary point =   1.0000D+00
#
# ---------------- exit CAUCHY----------------------
#
#            2  variables are free at GCP            1
#  LINE SEARCH           0  times; norm of step =    2.8178005607210741
#
# At iterate    1    f=  0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1      2      1     0     0   0.000D+00   0.000D+00
#
#  X =  0.0000D+00  0.0000D+00
#   F =   0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL

# %% [markdown]
# ## Second example : min Rosenbrock function

# %%
def rosenbrock(x):
    return 100 * (x[1] - x[0] ** 2) ** 2 + (1 - x[0]) ** 2


def grad_rosenbrock(x):
    g = np.empty(x.size)
    g[0] = 400 * x[0] * (x[0] ** 2 - x[1]) + 2 * (x[0] - 1)
    g[1] = 200 * (-x[0] ** 2 + x[1])
    return g


l = np.array([-2, -2])
u = np.array([2, 2])
bounds = np.array((l, u)).T
# x0 = np.array([0.12, 0.12])
x0 = np.array([-1, -1])

# %% [markdown]
# ### New implementation

# %%
np.finfo(1.0).resolution * 1e7
# Out:
# 1e-08

# %%
opt_rosenbrock = minimize_lbfgsb(
    x0=x0, fun=rosenbrock, jac=grad_rosenbrock, bounds=bounds, ftol=ftol, gtol=gtol
)
print("")
print("")
theoOpt = {"x": np.array([1, 1]), "f": 0, "df": grad_rosenbrock(np.array([1, 1]))}
print("Theoretical optimal value: ")
print(theoOpt)
print("Optimal value found: ")
print(opt_rosenbrock)
# Out:
# Theoretical optimal value:
# {'x': array([1, 1]), 'f': 0, 'df': array([0., 0.])}
# Optimal value found:
#   message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 6.011336239616695e-07
#         x: [ 1.000e+00  1.001e+00]
#       nit: 22
#       jac: [ 2.558e-02 -1.231e-02]
#      nfev: 29
#      njev: 29
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>

# %% [markdown]
# ### Scipy

# %%
minimize(
    rosenbrock,
    x0,
    jac=grad_rosenbrock,
    bounds=bounds,
    method="l-bfgs-b",
    options={"gtol": gtol, "ftol": ftol},
)
# Out:
#   message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 1.7971218235019573e-07
#         x: [ 9.996e-01  9.992e-01]
#       nit: 16
#       jac: [ 1.406e-03 -1.124e-03]
#      nfev: 20
#      njev: 20
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>

# %% [markdown]
# ## Third example : min Beale function

# %%
def beale(x):
    return (
        (1.5 - x[0] + x[0] * x[1]) ** 2
        + (2.25 - x[0] + x[0] * x[1] ** 2) ** 2
        + (2.625 - x[0] + x[0] * x[1] ** 3) ** 2
    )


def grad_beale(x):
    y1 = x[1]
    y2 = y1 * y1
    y3 = y2 * y1
    f1 = 1.5 - x[0] + x[0] * y1
    f2 = 2.25 - x[0] + x[0] * y2
    f3 = 2.625 - x[0] + x[0] * y3

    return np.array(
        [
            2 * (y1 - 1) * f1 + 2 * (y2 - 1) * f2 + 2 * (y3 - 1) * f3,
            2 * x[0] * f1 + 4 * x[0] * y1 * f2 + 6 * x[0] * y2 * f3,
        ]
    )


ftol = 1e-14
gtol = 1e-10
l = -4.5 * np.ones(2)
u = -l
bounds = np.array((l, u)).T
x0 = np.array([2.5, -1.3])

# %% [markdown]
# ### New implementation

# %%
opt_beale = minimize_lbfgsb(
    x0=x0, fun=beale, jac=grad_beale, bounds=bounds, ftol=ftol, gtol=gtol
)
print("")
print("")
theoOpt = {
    "x": np.array([3, 0.5]),
    "f": beale(np.array([3, 0.5])),
    "df": grad_beale(np.array([3, 0.5])),
}
print("Theoretical optimal value: ")
print(theoOpt)
print("Optimal value found: ")
print(opt_beale)
# Out:
# Theoretical optimal value:
# {'x': array([3. , 0.5]), 'f': 0.0, 'df': array([-0.,  0.])}
# Optimal value found:
#   message: CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#   success: True
#    status: 1
#       fun: 6.907776935181068e-24
#         x: [ 3.000e+00  5.000e-01]
#       nit: 16
#       jac: [-5.140e-12  2.367e-11]
#      nfev: 19
#      njev: 19
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>

# %% [markdown]
# ### Scipy

# %%
minimize(
    beale,
    x0,
    jac=grad_beale,
    bounds=bounds,
    method="l-bfgs-b",
    options={"gtol": gtol, "ftol": ftol},
)
# Out:
#   message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 1.4337068336583181e-21
#         x: [ 3.000e+00  5.000e-01]
#       nit: 16
#       jac: [-7.089e-11  1.797e-10]
#      nfev: 20
#      njev: 20
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>

# %% [markdown]
# - Comparision of convergence
