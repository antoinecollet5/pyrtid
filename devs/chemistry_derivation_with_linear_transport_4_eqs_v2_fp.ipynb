# %% [markdown]
# GOAL: test the equations coupling and the variable timestep.

# %% [markdown]
# L'équation de dissolution d'un mineral traceur et de l'évolution des concentrations s'écrit:

# %% [markdown]
# $$
#   \forall n \in [0, N], \left\{
#     \begin{array}{l}
#       \overline{c}_{i}^{2n+1} = \overline{c}_{i}^{2n}
#       \\\\
#       c_{i}^{2n+1} = (1 + D_{i}) c_{i}^{2n} - \left(\overline{c}_{i}^{2n+2} - \overline{c}_{i}^{2n+1}\right)
#       \\\\
#       \overline{c}_{i}^{2n+2} = \overline{c}_{i}^{2n+1} + \Delta t^{2n} k_{v} A_{s} \overline{c}_{i}^{2n+1} \left( 1 - \dfrac{c_{i}^{2n+1}}{K_{s}}\right)
#       \\\\
#       c_{i}^{2n+2} = c_{i}^{2n+1}
#       \\\\
#       \left(1 - \dfrac{c_{i}^{2n+2}}{c_{i}^{2n+2}} \right) < \epsilon
#     \end{array}
#   \right.
# $$
#
# Note that $N$ is the number of timesteps, in total, there are $N+1$ states and $n=0$ is the initial state.

# %% [markdown]
# $$ \mathcal{L} = \dfrac{1}{2} \sum_{n=0}^{N+1} \sum_{i} \left( \dfrac{c_{i}^{2n, \mathrm{obs}} - c_{i}^{2n, \mathrm{calc}}}{\sigma_{c_{i}}^{2n, \mathrm{obs}}}\right)^{2} - \langle \lambda_{c_{i}}^{n+1}, g_{c}^{n+1} \rangle_{n \in [0, N]} - \langle \lambda_{c_{i}}^{n}, g_{c}^{n} \rangle_{n \in [0, N]} - \langle \lambda_{\overline{c}_{i}}^{n+1}, g_{\overline{c}}^{n+1} \rangle_{n \in [0, N]} - \langle \lambda_{\overline{c}_{i}}^{n}, g_{\overline{c}}^{n} \rangle_{n \in [0, N]} $$

# %% [markdown]
# Written explicitely, it reads:

# %% [markdown]
# \begin{equation}
# \begin{aligned}
# \mathcal{L} = &\dfrac{1}{2} \sum_{n=0}^{N+1} \sum_{i} \left( \dfrac{c_{i}^{2n, \mathrm{obs}} - c_{i}^{2n, \mathrm{calc}}}{\sigma_{c_{i}}^{2n, \mathrm{obs}}}\right)^{2}
# \\
# &- \sum_{n=0}^{N} \lambda_{\overline{c}_{i}}^{2n+1} \Bigg[ \overline{c}_{i}^{2n+1} - \overline{c}_{i}^{2n}\Bigg]
# \\
# &- \sum_{n=0}^{N} \lambda_{c_{i}}^{2n+1} \Bigg[ c_{i}^{2n+1} - (1 + D_{i}) c_{i}^{2n}  + \overline{c}_{i}^{2n+2} - \overline{c}_{i}^{2n+1} \Bigg]
# \\
# &- \sum_{n=0}^{N} \lambda_{\overline{c}_{i}}^{2n+2} \Bigg[\overline{c}_{i}^{2n+2} - \overline{c}_{i}^{2n+1} - \Delta t^{2n} k_{v} A_{s} \overline{c}_{i}^{2n+1} \left( 1 - \dfrac{c_{i}^{2n+1}}{K_{s}}\right)
#  \Bigg]
# \\
# &- \sum_{n=0}^{N} \lambda_{c_{i}}^{2n+2}\Bigg[c_{i}^{2n+2} - c_{i}^{2n+1} \Bigg]
# \end{aligned}
# \end{equation}

# %% [markdown]
# Very important remark for the derivation: $\overline{c}_{i}^{2n}$ and $\overline{c}_{i}^{2n+1}$ are two independant variables. Same for $c_{i}^{2n}$ and $c_{i}^{2n+1}$, no matter $n$, it is never overlapping.

# %% [markdown]
# ## 1) Derivation by $\overline{c}_{i}^{2n}$:
#
# Only the second and the thrid scalar products have terms that depends on $\overline{c}_{i}^{2n}$ (or $\overline{c}_{i}^{2n+2}$), the lagrangian derivative reads:
# $$
# \dfrac{\partial \mathcal{L}}{\partial \overline{c}_{i}^{2n}} =
# \begin{cases}
#     \lambda_{\overline{c}_{i}}^{1}, & \text{if}\ n = 0
#     \\\\
#     \lambda_{\overline{c}_{i}}^{2n+1} - \lambda_{\overline{c}_{i}}^{2n} - \lambda_{c_{i}}^{2n-1}, & \forall n \in [1, N]
#     \\\\
#     - \lambda_{\overline{c}_{i}}^{2n+2} - \lambda_{c_{i}}^{2n+1}, & \text{if}\ n = N+1
# \end{cases}
# $$
#
# Since we want to impose $\dfrac{\partial \mathcal{L}}{\partial \overline{c}_{i}^{2n}} = 0$, it gives the initial condition for the adjoint state:
#
# $$ \lambda_{\overline{c}_{i}}^{2N+2} = - \lambda_{c_{i}}^{2N+1}$$
#
# And the temporal evolution:
# $$\lambda_{\overline{c}_{i}}^{2n} = \lambda_{\overline{c}_{i}}^{2n+1} - \lambda_{c_{i}}^{2n-1}, \forall n \in [1, N] $$

# %% [markdown]
# In addition we have the gradient with respect to $\overline{c}_{i}^{0}$

# %% [markdown]
# ## 2) Derivation by $\overline{c}_{i}^{2n+1}$:

# %% [markdown]
# Only the second and the thrid scalar products have terms that depends on $\overline{c}_{i}^{2n+1}$, the lagrangian derivative reads:
# $$
# \dfrac{\partial \mathcal{L}}{\partial \overline{c}_{i}^{2n+1}} =
# \begin{cases}
#     - \lambda_{\overline{c}_{i}}^{2n+1} + \lambda_{\overline{c}_{i}}^{2n+2} \left(1 + \Delta t^{2n}  k_{v} A_{s} \left( 1 - \dfrac{c_{i}^{2n+1}}{K_{s}}\right)\right) + \lambda_{c_{i}}^{2n+1}, & \forall n \in [0, N] \
#     \\
#     0, & \text{if}\ n = N+1
# \end{cases}
# $$

# %% [markdown]
# So we obtain the adjoint equation:
#
# $$  \lambda_{\overline{c}_{i}}^{2n+1} = \lambda_{\overline{c}_{i}}^{2n+2} \left(1 + \Delta t^{2n}  k_{v} A_{s} \left( 1 - \dfrac{c_{i}^{2n+1}}{K_{s}}\right)\right) + \lambda_{c_{i}}^{2n+1} , \forall n \in [0, N] $$

# %% [markdown]
# Note that we don't really care about

# %% [markdown]
# ## 3) Derivation by $c_{i}^{2n}$:

# %% [markdown]
# \begin{equation}
# \begin{aligned}
# \mathcal{L} = &\dfrac{1}{2} \sum_{n=0}^{N+1} \sum_{i} \left( \dfrac{c_{i}^{2n, \mathrm{obs}} - c_{i}^{2n, \mathrm{calc}}}{\sigma_{c_{i}}^{2n, \mathrm{obs}}}\right)^{2}
# \\
# &- \sum_{n=0}^{N} \lambda_{\overline{c}_{i}}^{2n+1} \Bigg[ \overline{c}_{i}^{2n+1} - \overline{c}_{i}^{2n}\Bigg]
# \\
# &- \sum_{n=0}^{N} \lambda_{c_{i}}^{2n+1} \Bigg[ c_{i}^{2n+1} - (1 + D_{i}) c_{i}^{2n}  + \overline{c}_{i}^{2n+2} - \overline{c}_{i}^{2n+1} \Bigg]
# \\
# &- \sum_{n=0}^{N} \lambda_{\overline{c}_{i}}^{2n+2} \Bigg[\overline{c}_{i}^{2n+2} - \overline{c}_{i}^{2n+1} - \Delta t^{2n} k_{v} A_{s} \overline{c}_{i}^{2n+1} \left( 1 - \dfrac{c_{i}^{2n+1}}{K_{s}}\right)
#  \Bigg]
# \\
# &- \sum_{n=0}^{N} \lambda_{c_{i}}^{2n+2}\Bigg[c_{i}^{2n+2} - c_{i}^{2n+1} \Bigg]
# \end{aligned}
# \end{equation}

# %% [markdown]
# $$
# \dfrac{\partial \mathcal{L}}{\partial c_{i}^{2n}} =
# \begin{cases}
#     - \lambda_{c_{i}}^{1} (1 + D_{i}) - \dfrac{c_{i}^{0, \mathrm{obs}} - c_{i}^{0, \mathrm{calc}}}{\left(\sigma_{c_{i}}^{0, \mathrm{obs}}\right)^{2}}, & \text{if}\ n = 0
#     \\\\
#     - \dfrac{c_{i}^{2n, \mathrm{obs}} - c_{i}^{2n, \mathrm{calc}}}{\left(\sigma_{c_{i}}^{2n, \mathrm{obs}}\right)^{2}} + \lambda_{c_{i}}^{2n+1} (1 + D_{i}) - \lambda_{c_{i}}^{2n}, & \forall n \in [1, N]
#     \\\\
#     - \dfrac{c_{i}^{2N+2, \mathrm{obs}} - c_{i}^{2N+2, \mathrm{calc}}}{\left(\sigma_{c_{i}}^{2N+2, \mathrm{obs}}\right)^{2}} - \lambda_{c_{i}}^{2N+2} , & \text{if}\ n = N+1
# \end{cases}
# $$

# %% [markdown]
# In addition to the gradient on the initial mobile concentration, we obtain the initial condition on the adjoint variable:
#
# $$ \lambda_{c_{i}}^{2N+2} = - \dfrac{c_{i}^{2N+2, \mathrm{obs}} - c_{i}^{2N+2, \mathrm{calc}}}{ \left(\sigma_{c_{i}}^{2N+2, \mathrm{obs}}\right)^{2}} $$

# %% [markdown]
# And the temporal evolution:

# %% [markdown]
# $$\lambda_{c_{i}}^{2n} = \lambda_{c_{i}}^{2n+1} (1 + D_{i}) - \dfrac{c_{i}^{2n, \mathrm{obs}} - c_{i}^{2n, \mathrm{calc}}}{\left(\sigma_{c_{i}}^{2n, \mathrm{obs}}\right)^{2}}, \forall n \in [1, N]$$

# %% [markdown]
# ## 4) Derivation by $c_{i}^{2n+1}$:

# %% [markdown]
# \begin{equation}
# \begin{aligned}
# \mathcal{L} = &\dfrac{1}{2} \sum_{n=0}^{N+1} \sum_{i} \left( \dfrac{c_{i}^{2n, \mathrm{obs}} - c_{i}^{2n, \mathrm{calc}}}{\sigma_{c_{i}}^{2n, \mathrm{obs}}}\right)^{2}
# \\
# &- \sum_{n=0}^{N} \lambda_{\overline{c}_{i}}^{2n+1} \Bigg[ \overline{c}_{i}^{2n+1} - \overline{c}_{i}^{2n}\Bigg]
# \\
# &- \sum_{n=0}^{N} \lambda_{c_{i}}^{2n+1} \Bigg[ c_{i}^{2n+1} - (1 + D_{i}) * c_{i}^{2n}\Bigg]
# \\
# &- \sum_{n=0}^{N} \lambda_{\overline{c}_{i}}^{2n+2} \Bigg[\overline{c}_{i}^{2n+2} - \overline{c}_{i}^{2n+1} - \Delta t^{2n} k_{v} A_{s} \overline{c}_{i}^{2n+1} \left( 1 - \dfrac{c_{i}^{2n+1}}{K_{s}}\right)
#  \Bigg]
# \\
# &- \sum_{n=0}^{N} \lambda_{c_{i}}^{2n+2}\Bigg[c_{i}^{2n+2} - c_{i}^{2n+1} + \overline{c}_{i}^{2n+2} - \overline{c}_{i}^{2n+1} \Bigg]
# \end{aligned}
# \end{equation}

# %% [markdown]
# $$
# \dfrac{\partial \mathcal{L}}{\partial c_{i}^{2n+1}} =
# \begin{cases}
#     - \lambda_{c_{i}}^{2n+1} + \lambda_{c_{i}}^{2n+2} - \lambda_{\overline{c}_{i}}^{2n+2} \Delta t^{2n} k_{v} A_{s} \overline{c}_{i}^{2n+1} \dfrac{1}{K_{s}}, & \forall n \in [0, N]
#     \\\\
#     0 , & \text{if}\ n = N+1
# \end{cases}
# $$

# %% [markdown]
# Then:
#
# $$ \lambda_{c_{i}}^{2n+1} = \lambda_{c_{i}}^{2n+2} - \lambda_{\overline{c}_{i}}^{2n+2} \Delta t^{2n} k_{v} A_{s} \overline{c}_{i}^{2n+1} \dfrac{1}{K_{s}}, \forall n \in [0, N]$$

# %% [markdown]
# ## Summary

# %% [markdown]
# $$
# \begin{cases}
#
#     \lambda_{c_{i}}^{2N+2} = - \dfrac{c_{i}^{2N+2, \mathrm{obs}} - c_{i}^{2N+2, \mathrm{calc}}}{ \left(\sigma_{c_{i}}^{2N+2, \mathrm{obs}}\right)^{2}}, & \text{Initial condition}
#     \\\\
#     \lambda_{\overline{c}_{i}}^{2N+2} = - \lambda_{c_{i}}^{2N+1} = - \lambda_{c_{i}}^{2N+2} + \lambda_{\overline{c}_{i}}^{2N+2} \Delta t^{2N} k_{v} A_{s} \overline{c}_{i}^{2N+1}, & \text{Initial condition}
#     \\\\
#     \lambda_{c_{i}}^{2n+1} = \lambda_{c_{i}}^{2n+2} - \lambda_{\overline{c}_{i}}^{2n+2} \Delta t^{2n} k_{v} A_{s} \overline{c}_{i}^{2n+1} \dfrac{1}{K_{s}}
#     \\\\
#     \lambda_{\overline{c}_{i}}^{2n+1} = \lambda_{\overline{c}_{i}}^{2n+2} \left(1 + \Delta t^{2n}  k_{v} A_{s} \left( 1 - \dfrac{c_{i}^{2n+1}}{K_{s}}\right)\right) + \lambda_{c_{i}}^{2n+1}
#     \\\\
#     \lambda_{c_{i}}^{2n} = \lambda_{c_{i}}^{2n+1} (1 + D_{i}) - \dfrac{c_{i}^{2n, \mathrm{obs}} - c_{i}^{2n, \mathrm{calc}}}{\left(\sigma_{c_{i}}^{2n, \mathrm{obs}}\right)^{2}}, \forall n \in [1, N]
#     \\\\
#     \lambda_{\overline{c}_{i}}^{2n} = \lambda_{\overline{c}_{i}}^{2n+1} - \lambda_{c_{i}}^{2n-1}
# \end{cases}
# $$

# %% [markdown]
# Là aussi on a un critère d'arrêt:

# %% [markdown]
# And
#
# $$\dfrac{\partial \mathcal{L}}{\partial \overline{c}_{i}^{0}} = \lambda_{\overline{c}_{i}}^{1}$$

# %% [markdown]
# ## Numerical tests

# %%
from typing import List
import numpy as np
import matplotlib.pyplot as plt
import numpy.typing as npt
import numdifftools as nd
from pyrtid.utils.finite_differences import finite_gradient

# %%
NDArrayFloat = npt.NDArray[np.float_]

# %%
class GeochemicalParameters:
    """
    Class defining the geocgemical parameters used in the simulation.

    Attributes
    ----------
    conc: float, optional
        Initial tracer concentration in the grid in molal. The default is 0.0.
    grade: float, optional
        Default mineral grade in the grid in mol/kg (kg of water).
        The default is 0.0.
    kv: float, optional
        The kinetic rate of the mineral in [mol/m2/s]. The default is -6.9e-9.
    As: float, optional
        Specific area in [m2/mol]. The default is 13.5.
    Ks: float, optional
        Solubility constant (no unit). The default is 6.3e-4.
    """

    def __init__(
        self,
        conc: float = 0.0,
        grade: float = 0.0,
        kv: float = -6.9e-9,
        As: float = 13.5,
        Ks: float = 6.3e-4,
    ) -> None:
        """Initialize the instance."""
        self.conc: float = conc
        self.grade: float = grade
        self.kv: float = kv
        self.As: float = As
        self.Ks: float = Ks


class Geometry:
    """
    Class defining the grid geometry used in the simulation.

    Attributes
    ----------
    nx : int
        Number of voxels along the x axis.
    ny : int
        Number of voxels along the y axis.
    dx : float
        Voxel dimension along the x axis.
    dy : float
        Voxel dimension along the y axis.
    dz : float
        Voxel dimension along the z axis. This is only taken into account for
        the voxel volume computation.
    """

    def __init__(
        self,
        nx: int,
        ny: int,
        dx: float,
        dy: float,
        dz: float = 1.0,
    ) -> None:
        """Initialize the class instance."""
        self._nx = 1
        self._ny = 1
        self.nx = int(nx)
        self.ny = int(ny)
        self.dx: float = dx
        self.dy: float = dy
        self.dz: float = dz

    @property
    def nx(self) -> int:
        """Return the number of meshes along the x axis."""
        return self._nx

    @nx.setter
    def nx(self, value: int) -> None:
        if value < 1:
            raise (ValueError("nx should be > 1!)"))
        self._nx = value

    @property
    def ny(self) -> int:
        """Return the number of meshes along the y axis."""
        return self._ny

    @ny.setter
    def ny(self, value: int) -> None:
        self._ny = value

    @property
    def mesh_area(self) -> float:
        """Return the area of a voxel in m2."""
        return self.dx * self.dy

    @property
    def mesh_volume(self) -> float:
        """Return the volume of a voxel in m3."""
        return self.mesh_area * self.dz


class TimeParameters:
    """
    Class defining the time parameters used in the simulation.

    It also handles the variable timestep.

    Attributes
    ----------
    nt : int
        Number of timesteps in the simulation.
    dt : float
        Current timestep in seconds.
    dt_init : float
        Initial timestep in seconds.
    dt_min : float
        Minimum timestep in seconds.
    dt_max : float
        Maximum timestep in seconds.
    ldt: List[float]
        List of successive timesteps (in seconds) used in the forward modelling.
    """

    __slots__ = ["nt", "dt", "dt_init", "dt_min", "dt_max", "ldt"]

    def __init__(self, nt: int, dt_init: float, dt_min: float, dt_max: float) -> None:
        """Initialize the instance."""
        self.nt: int = int(nt)
        self.dt_init: float = dt_init
        self.dt: float = dt_init
        self.dt_min: float = dt_min
        self.dt_max: float = dt_max
        self.ldt: List[float] = [dt_init]

    @property
    def duration(self) -> float:
        """Simulation duration in seconds."""
        return self.nt * self.dt

    def reset_dt(self) -> None:
        """Empty the list of timesteps and set dt to its initial value."""
        self.dt = self.dt_init
        self.ldt = [self.dt_init]

    def update_dt(self, nfpi: int) -> None:
        """
        Update the timestep.

        Parameters
        ----------
        nfpi: int
            Number of fixed point iterations between the transport and the chemistry
            required to solve the current timestep.
        """
        if nfpi < 20:
            # increase dt by 5%
            self.dt *= 1.05
        else:
            # decrease dt by 30%
            self.dt *= 0.7
        # Ensure timebounds
        if self.dt < self.dt_min:
            self.dt = self.dt_min
        if self.dt > self.dt_max:
            self.dt = self.dt_max
        self.ldt.append(self.dt)


class TransportParameters:
    """
    Class defining the transport parameters used in the simulation.

    Attributes
    ----------
    diffusion: float, optional
        Default diffusion coefficient in the grid in [m2/s]. The default is 1e-4 m2/s.
    porosity: float, optional
        Default porosity in the grid Should be a number between 0 and 1.
        The default is 1.0.
    crank_nicolson: float
        The Crank-Nicholson parameter allows to set the temporal resolution
        scheme to explicit, fully implicit or somewhere in between these two
        extremes. The value must be comprised between 0.0 and 1.0, 0.0 being a
        full explicit scheme and 1.0 fully implicit. The default is 0.5.
    tolerance: float, optional
        The tolerance on the transport. The default is 1e-8.
    is_numerical_acceleration: bool, optional
        Whether to use the concentration values at the previous iteration as an initial
        guess for gmres (x0) rather than using a random vector. This should increase the
        speed of resolution. The default is False.
    fpi_eps: float
       Precision of transport-chemistry coupling procedure. The default value is 1e-5
       which is a strict value if the error is evaluated for each node and each
       species separately.
    """

    def __init__(
        self,
        diffusion: float = 1e-4,
        porosity: float = 1.0,
        crank_nicolson_advection: float = 0.5,
        crank_nicolson_diffusion: float = 1.0,
        tolerance: float = 1e-8,
        is_numerical_acceleration: bool = False,
        fpi_eps=1e-5,
    ) -> None:
        """Initialize the instance."""
        self.diffusion: float = diffusion
        self.porosity: float = porosity
        self.crank_nicolson_advection: float = crank_nicolson_advection
        self.crank_nicolson_diffusion: float = crank_nicolson_diffusion
        self.tolerance: float = tolerance
        self.is_numerical_acceleration: bool = is_numerical_acceleration
        self.fpi_eps = fpi_eps

# %%
nx = 20  # number of voxels along the x axis
ny = 1  # number of voxels along the y axis
dx = 2.98  # voxel dimension along the x axis
dy = 3.7  # voxel dimension along the y axis
dz = 1

geom = Geometry(nx, ny, dx, dy, dz)

time_params = TimeParameters(
    nt=50,  # number of time steps
    dt_init=20000.0,  # timestep in seconds
    dt_min=50000.0,
    dt_max=200000.0,
)

# Chemistry parameters
c0 = 0.0001  # general initial concentration [molal]
M0 = 0.001  # mineral grade [mol/kg] -> kg of water
M1 = 0.0005  # mineral grade [mol/kg] -> kg of water
M1 = np.abs(0.001 * (0.5 + 0.5 * np.sin(np.arange(nx) / 2))).reshape(20, -1)
kv = -6.9e-9  # kinetic rate,       [mol/m2/s]
moleweight = 270.0  # molar weight [g/mol]
surface = 500  # cm2/g
As = moleweight * surface / 1e4  # specific area [m2/mol]
logK = 3.2
Ks = 1.0 / pow(10, logK)  # solubility constant [no unit]
porosity = 0.23
diffusion = -0.05

gch_params_ref = GeochemicalParameters(c0, M0, kv, As, Ks)

gch_params_est = GeochemicalParameters(c0, M1, kv, As, Ks)

tr_params = TransportParameters(diffusion=diffusion, porosity=porosity)

# %%
plt.plot(M1)

# %%
class TransportModel:
    def __init__(
        self, nt: int, geochem: GeochemicalParameters, tr_params: TransportParameters
    ) -> None:
        self.conc = np.zeros((nx, ny, nt + 1))
        self.conc_post_tr = np.zeros((nx, ny, nt + 1))
        self.conc[:, :, 0] = geochem.conc
        self.conc_post_tr[:, :, 0] = geochem.conc
        self.grade = np.zeros((nx, ny, nt + 1))
        self.grade_post_tr = np.zeros((nx, ny, nt + 1))
        self.grade[:, :, 0] = geochem.grade
        self.grade_post_tr[:, :, 0] = geochem.grade
        self.grade_old = np.zeros((nx, ny))
        self.porosity = np.zeros((nx, ny))
        self.porosity[:, :] = tr_params.porosity
        self.diffusion = np.zeros((nx, ny))
        self.diffusion[:, :] = tr_params.diffusion
        self.fpi_eps = tr_params.fpi_eps


class AdjointTransportModel:
    def __init__(self, nt: int) -> None:
        self.a_conc = np.zeros((nx, ny, nt + 1))
        self.a_conc_post_gch = np.zeros((nx, ny, nt + 1))
        self.a_conc_post_tr = np.zeros((nx, ny, nt + 1))
        self.a_grade = np.zeros((nx, ny, nt + 1))
        self.a_grade_post_gch = np.zeros((nx, ny, nt + 1))

# %%
def solve_transport(
    tr_model: TransportModel,
    time_index: int,
    nfpi: int,
    is_numerical_acceleration: bool = False,
) -> None:
    """Solve the transport.

    Parameters
    ----------
    tr_model: TransportModel
        The transport model.
    time_index: int
        The iteration, or timestep id.
    nfpi:
        Number of fixed point iterations.
    is_numerical_acceleration: bool
        Whether to use the chemical source term of the previous iteration as a first
        guess. It can save one inner iteration per timestep iteration.
        The default is false.

    """
    # No mechanical transport of immobile species
    tr_model.grade_post_tr[:, :, time_index] = tr_model.grade[:, :, time_index - 1]

    # Chemical source term
    if is_numerical_acceleration and nfpi == 1 and time_index != 1:
        dmdt = (
            tr_model.grade[:, :, time_index - 1] - tr_model.grade[:, :, time_index - 2]
        )
    else:
        dmdt = tr_model.grade[:, :, time_index] - tr_model.grade[:, :, time_index - 1]

    # Transport of mobile species
    tr_model.conc_post_tr[:, :, time_index] = (1 + tr_model.diffusion) * tr_model.conc[
        :, :, time_index - 1
    ] - dmdt


def solve_geochem(
    tr_model: TransportModel,
    gch_params: GeochemicalParameters,
    time_params: TimeParameters,
    time_index: int,
) -> None:
    """Compute the geochemistry part."""

    # Need to take into account boundary conditions:
    # And then the reactive (chemistry) contribution with the updated conc

    # Note: the concentration has been modified by the transport so we need to use the
    # updated one.
    # m0 = tr_model.grade_post_tr[:, :, time_index]
    m0 = tr_model.grade_post_tr[:, :, time_index]
    c0 = tr_model.conc_post_tr[:, :, time_index]

    dMdt = gch_params.kv * gch_params.As * m0 * (1.0 - c0 / gch_params.Ks)

    tr_model.grade[:, :, time_index] = m0 + dMdt * time_params.dt
    tr_model.conc[:, :, time_index] = c0


def get_max_coupling_error(tr_model: TransportModel, time_index: int) -> float:
    """
    Return the maximum transport-chemistry coupling error.

    This error is evaluated from the immobile concentrations (mineral grades).
    """
    return float(np.max(1 - tr_model.grade[:, :, time_index] / tr_model.grade_old))

# %%
tr_model_ref = TransportModel(time_params.nt, gch_params_ref, tr_params)
tr_model_ref.grade[:, :, 0] = M0
tr_model_est = TransportModel(time_params.nt, gch_params_est, tr_params)
tr_model_est.grade[:, :, 0] = M1


def solve_forward(
    _time_params: TimeParameters,
    _gch_params: GeochemicalParameters,
    _tr_model: TransportModel,
    is_verbose: bool = False,
) -> None:
    _time_params.reset_dt()
    # Otherwise there is an issue
    for it in range(1, _time_params.nt + 1):
        nfpi = 1  # number of coupling (Fixed Point) iterations
        # Do not update the timestep for the first iteration
        # update the timestep based on the convergence speed.
        if it != 1:
            _time_params.update_dt(nfpi)
        # Convergence flag
        has_converged = False

        # Copy the grades (To place in another function afterwards)
        _tr_model.grade[:, :, it] = _tr_model.grade[:, :, it - 1]

        # Iterate the chemistry transport system while the convergence is no meet
        while not has_converged:
            # Save the grade for the fix point iterations
            _tr_model.grade_old = _tr_model.grade[:, :, it].copy()

            solve_transport(_tr_model, it, nfpi, is_numerical_acceleration=False)
            solve_geochem(_tr_model, _gch_params, time_params, it)

            # One more coupling iteration has been performed

            if is_verbose:
                print(
                    f"max-coupling error at it = {it}-{nfpi}: {get_max_coupling_error(_tr_model, it)}"
                )
            has_converged = get_max_coupling_error(_tr_model, it) < _tr_model.fpi_eps
            if is_verbose:
                print(f"has-converged ?: {has_converged}")

            # Update the number of FPI
            nfpi += 1


solve_forward(time_params, gch_params_ref, tr_model_ref, is_verbose=True)
solve_forward(time_params, gch_params_est, tr_model_est)
# Out:
# max-coupling error at it = 1-1: 0.0015824976783322953
# has-converged ?: False
# max-coupling error at it = 1-2: -4.679977346100372e-06
# has-converged ?: True
# max-coupling error at it = 2-1: 0.003980209629218967
# has-converged ?: False
# max-coupling error at it = 2-2: -2.945134003851102e-05
# has-converged ?: True
# max-coupling error at it = 3-1: 0.0041855170729083735
# has-converged ?: False
# max-coupling error at it = 3-2: -3.2397225462998946e-05
# has-converged ?: True
# max-coupling error at it = 4-1: 0.004399616995469091
# has-converged ?: False
# max-coupling error at it = 4-2: -3.5616296810481174e-05
# has-converged ?: True
# max-coupling error at it = 5-1: 0.00462282892510657
# has-converged ?: False
# max-coupling error at it = 5-2: -3.9131717862517235e-05
# has-converged ?: True
# max-coupling error at it = 6-1: 0.004855479429183851
# has-converged ?: False
# max-coupling error at it = 6-2: -4.296835223449591e-05
# has-converged ?: True
# max-coupling error at it = 7-1: 0.005097901978494801
# has-converged ?: False
# max-coupling error at it = 7-2: -4.715285426692972e-05
# has-converged ?: True
# max-coupling error at it = 8-1: 0.005350436803405301
# has-converged ?: False
# max-coupling error at it = 8-2: -5.17137603746054e-05
# has-converged ?: True
# max-coupling error at it = 9-1: 0.005613430745827985
# has-converged ?: False
# max-coupling error at it = 9-2: -5.668158018301561e-05
# has-converged ?: True
# max-coupling error at it = 10-1: 0.0058872371118828815
# has-converged ?: False
# max-coupling error at it = 10-2: -6.208888671066504e-05
# has-converged ?: True
# max-coupling error at it = 11-1: 0.006172215531073388
# has-converged ?: False
# max-coupling error at it = 11-2: -6.797040475903238e-05
# has-converged ?: True
# max-coupling error at it = 12-1: 0.0064687318288774165
# has-converged ?: False
# max-coupling error at it = 12-2: -7.436309659270002e-05
# has-converged ?: True
# max-coupling error at it = 13-1: 0.0067771579208179
# has-converged ?: False
# max-coupling error at it = 13-2: -8.130624390112473e-05
# has-converged ?: True
# max-coupling error at it = 14-1: 0.007097871737338779
# has-converged ?: False
# max-coupling error at it = 14-2: -8.884152495802766e-05
# has-converged ?: True
# max-coupling error at it = 15-1: 0.007431257190153029
# has-converged ?: False
# max-coupling error at it = 15-2: -9.701308581022694e-05
# has-converged ?: True
# max-coupling error at it = 16-1: 0.007777704192169721
# has-converged ?: False
# max-coupling error at it = 16-2: -0.00010586760426423147
# has-converged ?: True
# max-coupling error at it = 17-1: 0.00813760874460856
# has-converged ?: False
# max-coupling error at it = 17-2: -0.00011545434537185706
# has-converged ?: True
# max-coupling error at it = 18-1: 0.008511373106492748
# has-converged ?: False
# max-coupling error at it = 18-2: -0.00012582520707749012
# has-converged ?: True
# max-coupling error at it = 19-1: 0.00889940606334505
# has-converged ?: False
# max-coupling error at it = 19-2: -0.0001370347546405526
# has-converged ?: True
# max-coupling error at it = 20-1: 0.009302123313585042
# has-converged ?: False
# max-coupling error at it = 20-2: -0.00014914024243739554
# has-converged ?: True
# max-coupling error at it = 21-1: 0.009719947992841815
# has-converged ?: False
# max-coupling error at it = 21-2: -0.00016220162174396258
# has-converged ?: True
# max-coupling error at it = 22-1: 0.010153311358104933
# has-converged ?: False
# max-coupling error at it = 22-2: -0.00017628153310855765
# has-converged ?: True
# max-coupling error at it = 23-1: 0.010602653655362726
# has-converged ?: False
# max-coupling error at it = 23-2: -0.00019144528197023725
# has-converged ?: True
# max-coupling error at it = 24-1: 0.011068425196059328
# has-converged ?: False
# max-coupling error at it = 24-2: -0.00020776079622653043
# has-converged ?: True
# max-coupling error at it = 25-1: 0.011551087669362192
# has-converged ?: False
# max-coupling error at it = 25-2: -0.00022529856452968566
# has-converged ?: True
# max-coupling error at it = 26-1: 0.012051115718824779
# has-converged ?: False
# max-coupling error at it = 26-2: -0.000244131554180127
# has-converged ?: True
# max-coupling error at it = 27-1: 0.012568998813560994
# has-converged ?: False
# max-coupling error at it = 27-2: -0.0002643351075886091
# has-converged ?: True
# max-coupling error at it = 28-1: 0.013105243445497017
# has-converged ?: False
# max-coupling error at it = 28-2: -0.0002859868163860302
# has-converged ?: True
# max-coupling error at it = 29-1: 0.01366037568563716
# has-converged ?: False
# max-coupling error at it = 29-2: -0.0003091663723766569
# has-converged ?: True
# max-coupling error at it = 30-1: 0.014234944133569849
# has-converged ?: False
# max-coupling error at it = 30-2: -0.00033395539462866
# has-converged ?: True
# max-coupling error at it = 31-1: 0.014411112512718982
# has-converged ?: False
# max-coupling error at it = 31-2: -0.0003402403942383003
# has-converged ?: True
# max-coupling error at it = 32-1: 0.01430348659302938
# has-converged ?: False
# max-coupling error at it = 32-2: -0.0003329096565067857
# has-converged ?: True
# max-coupling error at it = 33-1: 0.014208071770064556
# has-converged ?: False
# max-coupling error at it = 33-2: -0.0003260358536447683
# has-converged ?: True
# max-coupling error at it = 34-1: 0.014123834844366523
# has-converged ?: False
# max-coupling error at it = 34-2: -0.00031957483300537604
# has-converged ?: True
# max-coupling error at it = 35-1: 0.014049834951846751
# has-converged ?: False
# max-coupling error at it = 35-2: -0.00031348711866163725
# has-converged ?: True
# max-coupling error at it = 36-1: 0.013985214661688672
# has-converged ?: False
# max-coupling error at it = 36-2: -0.00030773737131228884
# has-converged ?: True
# max-coupling error at it = 37-1: 0.013929192010394997
# has-converged ?: False
# max-coupling error at it = 37-2: -0.00030229391737912614
# has-converged ?: True
# max-coupling error at it = 38-1: 0.013881053362882922
# has-converged ?: False
# max-coupling error at it = 38-2: -0.00029712833741712963
# has-converged ?: True
# max-coupling error at it = 39-1: 0.013840147005784398
# has-converged ?: False
# max-coupling error at it = 39-2: -0.0002922151055173572
# has-converged ?: True
# max-coupling error at it = 40-1: 0.013805877390270616
# has-converged ?: False
# max-coupling error at it = 40-2: -0.00028753127267511225
# has-converged ?: True
# max-coupling error at it = 41-1: 0.01377769995213729
# has-converged ?: False
# max-coupling error at it = 41-2: -0.0002830561881772553
# has-converged ?: True
# max-coupling error at it = 42-1: 0.013755116445830717
# has-converged ?: False
# max-coupling error at it = 42-2: -0.0002787712539458198
# has-converged ?: True
# max-coupling error at it = 43-1: 0.013737670736797436
# has-converged ?: False
# max-coupling error at it = 43-2: -0.00027465970752893476
# has-converged ?: True
# max-coupling error at it = 44-1: 0.013724945003200428
# has-converged ?: False
# max-coupling error at it = 44-2: -0.0002707064300506712
# has-converged ?: True
# max-coupling error at it = 45-1: 0.01371655630381341
# has-converged ?: False
# max-coupling error at it = 45-2: -0.00026689777595767517
# has-converged ?: True
# max-coupling error at it = 46-1: 0.013712153473915745
# has-converged ?: False
# max-coupling error at it = 46-2: -0.0002632214218427631
# has-converged ?: True
# max-coupling error at it = 47-1: 0.01371141431537648
# has-converged ?: False
# max-coupling error at it = 47-2: -0.00025966623200313066
# has-converged ?: True
# max-coupling error at it = 48-1: 0.013714043050930935
# has-converged ?: False
# max-coupling error at it = 48-2: -0.00025622213870235555
# has-converged ?: True
# max-coupling error at it = 49-1: 0.013719768015985734
# has-converged ?: False
# max-coupling error at it = 49-2: -0.0002528800353864824
# has-converged ?: True
# max-coupling error at it = 50-1: 0.013728339564219594
# has-converged ?: False
# max-coupling error at it = 50-2: -0.0002496316813194177
# has-converged ?: True

# %%
import matplotlib.pyplot as plt

plt.plot(tr_model_ref.grade[0, 0, :], label="grade ref")
plt.plot(tr_model_ref.conc[0, 0, :], label="conc ref")
plt.plot(tr_model_est.grade[0, 0, :], label="grade est")
plt.plot(tr_model_est.conc[0, 0, :], label="conc est")
plt.legend()

# %%
def solve_adj_geochem_explicit(
    tr_model: TransportModel,
    a_tr_model: AdjointTransportModel,
    gch_params: GeochemicalParameters,
    geometry: Geometry,
    a_sources,
    time_params: TimeParameters,
    time_index: int,
) -> None:
    # Adjoint variables
    am_prev = a_tr_model.a_grade[:, :, time_index + 1]
    ac_prev = a_tr_model.a_conc[:, :, time_index + 1]
    # Forward variables
    m_prev_post_tr = tr_model.grade_post_tr[:, :, time_index + 1]
    c_prev_post_tr = tr_model.conc_post_tr[:, :, time_index + 1]
    # Timesteps
    dt_cur = time_params.ldt[time_index]

    # Update concentration
    a_tr_model.a_conc_post_gch[:, :, time_index] += (
        ac_prev
        - am_prev
        * dt_cur
        * gch_params.kv
        * gch_params.As
        * m_prev_post_tr
        / gch_params.Ks
    )

    # Update mineral value
    a_tr_model.a_grade_post_gch[:, :, time_index] = (
        am_prev
        * (
            1
            + gch_params.kv
            * gch_params.As
            * (1.0 - c_prev_post_tr / gch_params.Ks)
            * dt_cur
        )
        + ac_prev
    )


def solve_adj_transport(
    tr_model: TransportModel,
    a_tr_model: AdjointTransportModel,
    geometry: Geometry,
    a_sources: NDArrayFloat,
    time_index: int,
) -> None:
    # This works
    a_tr_model.a_conc[:, :, time_index] = (
        a_tr_model.a_conc_post_gch[:, :, time_index] * (1 + tr_model.diffusion)
        - a_sources[:, :, time_index]
    )
    a_tr_model.a_grade[:, :, time_index] = (
        a_tr_model.a_grade_post_gch[:, :, time_index]
        - a_tr_model.a_conc[:, :, time_index]
    )

# %%
atr_model = AdjointTransportModel(time_params.nt)


def get_a_sources(
    tr_model_ref: TransportModel, tr_model_est: TransportModel
) -> NDArrayFloat:
    _out = tr_model_ref.conc - tr_model_est.conc
    # Modify here to remove some of the adjoint variables
    # _out[:, :, 2:] = 0.0
    return _out


_a_sources = get_a_sources(tr_model_ref, tr_model_est)

# Initialize the adjoint variables
atr_model.a_conc[:, :, -1] -= _a_sources[:, :, -1]
atr_model.a_grade[:, :, -1] = -atr_model.a_conc[:, :, -1]

for it in range(time_params.nt - 1, -1, -1):
    # add_chem_adjoint_sources(tr_model_est, atr_model, geom, _a_sources, time_params, it)
    solve_adj_geochem_explicit(
        tr_model_est, atr_model, gch_params_est, geom, _a_sources, time_params, it
    )
    solve_adj_transport(tr_model_est, atr_model, geom, _a_sources, it)

# %%
plt.plot(atr_model.a_conc[0, 0, :], label="adjoint conc")
plt.legend()

# %%
plt.plot(atr_model.a_grade[0, 0, :], label="adjoint grade")
plt.legend()

# %% [markdown]
# # Gradient computation

# %%
gch_params = gch_params_est


def get_gradient(time_params: TimeParameters):
    return atr_model.a_grade_post_gch[:, :, 0]


adjoint_gradient = get_gradient(time_params=time_params).ravel()
adjoint_gradient
# Out:
# array([-2.97175892e-04, -1.37711690e-04, -3.84157070e-05, -5.84563045e-07,
#        -2.16220264e-05, -1.03197576e-04, -2.46644074e-04, -4.37071288e-04,
#        -6.27123009e-04, -7.44496700e-04, -7.34196282e-04, -6.01332962e-04,
#        -4.06878467e-04, -2.21381446e-04, -8.69175174e-05, -1.46776204e-05,
#        -2.48821558e-06, -4.93423086e-05, -1.58076610e-04, -3.25389588e-04])

# %% [markdown]
# - Objective function definition

# %%
def objfun(x, time_params: TimeParameters) -> float:
    _tr_model = TransportModel(time_params.nt, gch_params_est, tr_params)
    _tr_model.grade[:, :, 0] = x.reshape(nx, ny, order="F")
    solve_forward(time_params, gch_params_est, _tr_model, is_verbose=False)

    _a_sources = get_a_sources(tr_model_ref, _tr_model)
    return float(0.5 * np.sum(_a_sources**2))

# %% [markdown]
# - Evaluate the objective function for the initial guess

# %%
objfun(M1, time_params)
# Out:
# 1.6562893872402133e-06

# %% [markdown]
# - Define a step for the finite differences

# %%
import sys

eps = sys.float_info.epsilon * 1e6
eps
# Out:
# 2.220446049250313e-10

# %% [markdown]
# - We check the gradients by finite differences (with pyrtid and numdifftools, it is supposed to give the same results, the main difference is that pyrtid supports parallel running.)

# %%
def objfun_wrapper(x: NDArrayFloat) -> float:
    return objfun(x, time_params)


fd_gradient_numdifftools = nd.Gradient(objfun_wrapper, step=eps)(M1.ravel("F"))
fd_gradient_pyrtid = finite_gradient(
    np.array([M1]).ravel("F"), objfun, fm_args=(time_params,), eps=eps
)

# %% [markdown]
# - Plot the gradients

# %%
plt.plot(adjoint_gradient, label="adjoint")
plt.plot(fd_gradient_pyrtid, label="fd pyrtid", linestyle="--")
plt.plot(fd_gradient_numdifftools, label="fd numdifftools", linestyle="--")
plt.legend()

# %% [markdown]
# - Plot the residuals

# %%
plt.plot((adjoint_gradient - fd_gradient_pyrtid), label="residuals pyrtid")
plt.plot(
    (adjoint_gradient - fd_gradient_numdifftools),
    linestyle="--",
    label="residuals numdifftools",
)
plt.legend()
